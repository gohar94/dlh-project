# %%
import pandas as pd
import numpy as np
from loaders import *

from scripts.utils import *

# %%
show_config(ConfigRegistry.PIM_ARCH)
# Out:
# architecture:
#   version: 0.3
#   subtree:                           # "subtree" contains abstract hierarchies
#     - name: system_arch              # name of the design
#       attributes:                    # shared attributes that will propagate down all lower levels
#         technology: 32nm
#         latency: 1ns
#       local:
#         - name: DRAM                 # offchip DRAM is the source of all datatypes
#           class: DRAM                # assume DRAM is large enough to store all the data, so no depth specification needed
#           attributes:
#             width: 64                # width in bits
#             datawidth: 16            # datawidth in bits
#             block-size: 4
#       subtree:
#         - name: chip                 # all components below this level are on-chip components
#           local:
#             - name: shared_glb
#               class: smartbuffer_SRAM
#               attributes:
#                 memory_depth: 16384
#                 memory_width: 64
#                 n_banks: 32
#                 block-size: 4
#                 word-bits: 16
#                 read_bandwidth: 16
#                 write_bandwidth: 16
#                 n_rdwr_ports: 2
#                 network_read: D2A_NoC
#                 network_update: A2D_NoC
#             - name: dummy_buffer
#               class: dummy_storage
#               attributes:
#                 depth: 0   # will result in zero area/energy for accelergy
#                 width: 16  # timeloop needs a width even if the memory is not storing anything
#                 network_fill: D2A_NoC
#                 network_drain: A2D_NoC
#             - name: D2A_NoC
#               class: SimpleMulticast         # timeloop class
#               subclass: DAC_SimpleMulticast  # accelergy class
#               attributes:
#                 datawidth: 16
#                 DAC_datawidth: 1  # DAC only converts one bit per cycle
#                 n_DAC_cycles: 16  # number of cycles needed for a DAC to convert a datawidth-bit data
#                 n_PE_cols: 128
#                 n_PE_rows: 128
#                 action_name: transfer
#                 per_datatype_ERT: True
#                 multicast_factor_argument: num_destinations
#             - name: A2D_NoC
#               class: SimpleMulticast         # timeloop class
#               subclass: ADC_SimpleMulticast  # accelergy class
#               attributes:
#                 datawidth: 16
#                 ADC_datawidth: 8
#                 cell_datawidth: 2
#                 n_DAC_cycles: 16    # number of cycles needed for a DAC to convert a datawidth-bit data = datawidth/DAC_datawidth
#                 n_PE_cols: 128
#                 n_PE_rows: 128
#                 action_name: transfer
#                 per_datatype_ERT: True
#                 multicast_factor_argument: num_destinations
#           subtree:
#             - name: PE[0..16383]
#               local:                 # "local" contains physical instantiations
#                 - name: scratchpad
#                   class: memcell_storage  # definitions of the compound classes can be found under "components" folder
#                   attributes:
#                     width: 16       # width in bits
#                     depth: 1
#                     meshX: 128        # number of components in the X dimension (PE rows)
#                     meshY: 128        # number of components in the Y dimension (PE cols)
#                 - name: mac
#                   class: memcell_compute
#                   attributes:
#                     datawidth: 16   # datawidth in bits
#                     meshX: 128        # number of components in the X dimension (PE rows)
#                     meshY: 128        # number of components in the Y dimension (PE cols)

# %%
show_config(ConfigRegistry.PIM_COMPONENTS_DIR)
# Out:
# compound_components:
#   version: 0.3
#   classes:
#     - name: A2D_conversion_system
#       attributes:  # default attributes that can be overridden
#         technology: 32nm
#         latency: 1ns
#         datawidth: 16
#         cell_datawidth: 2
#         n_DAC_cycles: 16
#         ADC_datawidth: 8
#         n_PE_cols: 8
#         # derived parameters (automatically derived, but can be overridden from high-level)
#         nCells: datawidth/cell_datawidth
#         SH_datawidth: ADC_datawidth
#         total_SHs: nCells * n_PE_cols # each physical column has a sample and hold
#         ADC_converts_per_psum: nCells * n_DAC_cycles # temporal: n_DAC_cycles times for each column of cells
#       subcomponents:
#         - name: SH[0..total_SHs-1] # this is all SHs in the system
#           class: sample_and_hold
#           attributes:
#             technology: technology
#             latency: latency
#             datawidth: SH_datawidth
#         - name: ADC #  assume this ADC is fast enough to convert the output of the SHs in one cycle
#           class: ADC
#           attributes:
#             technology: technology
#             latency: latency
#             type: SAR
#             datawidth: ADC_datawidth
#       actions:
#         - name: convert
#           subcomponents:
#             - name: SH[0..nCells-1]
#               actions:
#                 - name: sample_and_hold
#                   action_share: n_DAC_cycles  # number of times the action need to be performed
#             - name: ADC
#               actions:
#                 - name: convert
#                   action_share: ADC_converts_per_psum # number of times the action need to be performed
#
# compound_components:
#   version: 0.3
#   classes:
#     - name: ADC_SimpleMulticast
#       attributes:
#         technology: 45nm
#         latency: 1ns
#         datawidth: 16
#         A2D_convert_width: 16
#         ADC_datawidth: 8
#         cell_datawidth: 2
#         n_DAC_cycles: 16
#       subcomponents:
#         - name: A2D_converter
#           class: A2D_conversion_system
#           attributes:
#             technology: technology
#             latency: latency
#             datawidth: datawidth
#             ADC_datawidth: ADC_datawidth
#             cell_datawidth: cell_datawidth
#             n_DAC_cycles: n_DAC_cycles
#         - name: digital_accumulator
#           class: digital_accumulation_system
#           attributes:
#             technology: technology
#             latency: latency
#             datawidth: datawidth
#             cell_datawidth: cell_datawidth
#             n_DAC_cycles: n_DAC_cycles
#       actions:
#         - name: transfer_Outputs
#           arguments:
#             num_destinations: 1..1 # digital partial sums are only sent to global buffer
#           subcomponents:
#             - name: A2D_converter
#               actions:
#                 - name: convert
#             - name: digital_accumulator
#               actions:
#                 - name: accumulate
# compound_components:
#   version: 0.3
#   classes:
#     - name: D2A_conversion_system
#       attributes:
#         technology: 32nm
#         latency: 1ns
#         datawidth: 16
#         meshX: 128
#         meshY: 128
#         DAC_datawidth: 1
#         cell_datawidth: 2
#         # derived parameters (automatically derived, but can be overridden from high-level)
#         nCells: datawidth/cell_datawidth
#         nArrays: nCells
#         nCycles: datawidth/DAC_datawidth
#         total_DACs: nArrays * meshY # each array has meshY number of DACs
#         DAC_converts_per_psum: nCycles
#       subcomponents:
#         - name: DAC[0..total_DACs-1]
#           class: DAC
#           attributes:
#             technology: technology
#             latency: latency
#             datawidth: DAC_datawidth
#       actions:
#         - name: convert
#           subcomponents:
#             # each row in an array of LMACs need one DAC
#             - name: DAC[0..nArrays-1]
#               actions:
#                 - name: convert
#                   action_share: nCycles
#
# compound_components:
#   version: 0.3
#   classes:
#     - name: DAC_SimpleMulticast
#       attributes:
#         technology: 45nm
#         latency: 1ns
#         datawidth: 16
#         DAC_datawidth: 1
#         cell_datawidth: 2
#         num_converts: datawidth/DAC_datawidth
#       subcomponents:
#         - name: D2A_converter
#           class: D2A_conversion_system
#           attributes:
#             technology: technology
#             latency: latency
#             datawidth: datawidth
#             DAC_datawidth: DAC_datawidth
#             cell_datawidth: cell_datawidth
#       actions:
#         - name: transfer_Inputs
#           arguments:
#             num_destinations: 1..n_PE_cols
#           subcomponents:
#             - name: D2A_converter
#               actions:
#                 - name: convert
#                   action_share: n_PE_cols
# compound_components:
#   version: 0.3
#   classes:
#     - name: digital_accumulation_system
#       attributes:
#         technology: 32nm
#         latency: 1ns
#         datawidth: 16
#         meshX: 128
#         meshY: 128
#         cell_datawidth: 2
#         n_DAC_cycles: 16
#         # derived parameters (automatically derived, but can be overridden from high-level)
#         nCells: datawidth/cell_datawidth
#         nArrays: nCells
#         total_S_As: nArrays  # each array share a shift and add
#         S_A_datawidth: datawidth
#         S_As_per_psum: nCells * n_DAC_cycles # temporal S_A computations
#         buffer_per_psum: n_DAC_cycles -2 # the first and last partial sums are not written into into this buffer
#       subcomponents:
#         - name: S_A
#           class: shift_and_add
#           attributes:
#             technology: technology
#             latency: latency
#             datawidth: S_A_datawidth
#         - name: outputBuffer
#           class: SRAM
#           attributes:
#             technology: technology
#             latency: latency
#             width: 16
#             depth: 128
#             datawidth: 16
#       actions:
#         - name: accumulate
#           subcomponents:
#             - name: S_A # assume this S_A is fast enough to do the computations needed in one cycle
#               actions:
#                 - name: shift_and_add
#                   action_share: S_As_per_psum
#             - name: outputBuffer
#               actions:
#                 - name: read
#                   arguments:
#                     address_delta: 1
#                     data_delta: 1
#                   action_share: buffer_per_psum
#                 - name: write
#                   arguments:
#                     address_delta: 1
#                     data_delta: 1
#                   action_share: buffer_per_psum
# compound_components:
#   version: 0.3
#   classes:
#     - name: memcell_compute
#       attributes:
#         cell_technology: memristor
#         cmos_technology: 32nm
#         cell_datawidth: 2
#         DAC_datawidth: 1
#         datawidth: 16
#         nCells: datawidth/cell_datawidth
#         nCycles: datawidth/DAC_datawidth
#         compute_latency: 100ns
#       subcomponents:
#         - name: cell[0..nCells-1]
#           class: ReRAMcell_compute
#           attributes:
#             technology: cell_technology
#             cellwidth: cell_datawidth
#             latency: 100ns
#       actions:
#         - name: compute
#           subcomponents:
#             - name: cell[0..nCells-1] # spatial
#               actions:
#                 - name: compute
#                   action_share: nCycles # temporal: compute 1 bit input at a time
#
# compound_components:
#   version: 0.3
#   classes:
#   - name: smartbuffer_SRAM
#     attributes:
#       technology: 45nm
#       memory_depth: 12
#       memory_width: 16
#       n_rdwr_ports: 2
#       n_banks: 1
#       n_buffets: 1
#     subcomponents:
#       - name: storage
#         class: SRAM
#         attributes:
#           technology: technology
#           width: memory_width
#           depth: memory_depth
#           n_rdwr_ports: n_rdwr_ports
#           n_banks: n_banks
#       - name: address_generators[0..1]
#         class: intadder
#         attributes:
#           technology: technology
#           width: log(memory_depth)
#     actions:
#       - name: write
#         arguments:
#           data_delta: 0..1
#           address_delta: 0..n_banks
#         subcomponents:
#           - name: storage
#             actions:
#               - name: write
#                 arguments:
#                   data_delta: data_delta
#                   address_delta: address_delta
#           - name: address_generators[0]
#             actions:
#               - name: add
#           - name: address_generators[1]
#             actions:
#               - name: idle
#       - name: read
#         arguments:
#           data_delta: 0..1
#           address_delta: 0..n_banks
#         subcomponents:
#           - name: storage
#             actions:
#               - name: read
#                 arguments:
#                   data_delta: data_delta
#                   address_delta: address_delta
#           - name: address_generators[1]
#             actions:
#               - name: add
#           - name: address_generators[0]
#             actions:
#               - name: idle
#       - name: idle
#         subcomponents:
#           - name: storage
#             actions:
#               - name: idle
#           - name: address_generators[0..1]
#             actions:
#               - name: idle
# compound_components:
#   version: 0.3
#   classes:
#     - name: SRAM_storage
#       attributes:
#         technology: 16nm
#         latency: 1ns
#         depth: 1024
#         width: 16
#         datawidth: 16
#         nports: 1
#         nbanks: 1
#       subcomponents:
#         - name: storage
#           class: SRAM
#           attributes:
#             technology: technology
#             latency: latency
#             depth: depth
#             width: width
#             datawidth: datawidth
#             n_rdwr_ports: nports
#             n_banks: nbanks
#       actions:
#         - name: read
#           subcomponents:
#             - name: storage
#               actions:
#                 - name: read
#                   arguments:
#                     address_delta: 1
#                     data_delta: 1
#         - name: write
#           subcomponents:
#             - name: storage
#               actions:
#                 - name: write
#                   arguments:
#                     address_delta: 1
#                     data_delta: 1
#
#
#     - name: memcell_storage
#       attributes:
#         cmos_technology: 32nm
#         cell_technology: memristor
#         depth: 256
#         width: 16
#         cell_datawidth: 2
#       subcomponents:
#         - name: storage
#           class: ReRAMcell_storage
#           attributes:
#             technology: cell_technology
#             latency: latency
#             cellwidth: cell_datawidth
#       actions:
#         - name: read
#           subcomponents:
#             - name: storage
#               actions:
#                 - name: idle
#
#     - name: dummy_storage
#       attributes:
#         depth: 0
#         width: 0
#       subcomponents:
#         - name: storage
#           class: SRAM
#           attributes:
#             depth: 0
#             width: 0
#             datawidth: 0
#             n_rdwr_ports: 0
#       actions:
#         - name: access
#           subcomponents:
#             - name: storage
#               actions:
#                 - name: idle

# %%
show_config(ConfigRegistry.PIM_CONSTRAINTS)
# Out:
# mapspace:
#   targets:
#     # =======================================
#     # DRAM
#     # =======================================
#     - target: DRAM
#       type: bypassing
#       keep: [Inputs, Outputs]
#       bypass: [Weights]  # weights are stored locally in the memcells, not loaded from DRAM
#     - target: DRAM
#       type: temporal
#       factors: R=1 S=1 M=1 C=1
#       permutation: RSCPQMN
#     # =======================================
#     # Global Buffer Constraints
#     # =======================================
#     - target: shared_glb
#       type: bypassing
#       keep: [Inputs, Outputs]
#       bypass: [Weights] # weights are stored locally in the memcells, not loaded from DRAM
#     - target: shared_glb
#       type: temporal
#       # factors: R=1 S=1 M=1 C=1 # TODO(girfan): Ask TA if this makes sense.
#     # =======================================
#     # Dummy Buffer Constraints
#     # =======================================
#     - target: dummy_buffer
#       type: bypassing
#       keep: []
#       bypass: [Inputs, Outputs, Weights]  # no data should be stored in dummy, it is just a transition buffer
#     - target: dummy_buffer
#       type: spatial
#       factors: Q=1 P=1
#       permutation: RSC M
#       split: 3  # M cannot be mapped in the same dimension as others
#     - target: dummy_buffer
#       type: temporal
#       factors: R=1 S=1 M=1 C=1
#     # =======================================
#     # WS Buffer Constraints
#     # =======================================
#     - target: scratchpad
#       type: bypassing
#       keep: [Weights]
#       bypass: [Inputs, Outputs]
#     - target: scratchpad
#       type: temporal
#       factors: R=1 S=1 M=1 C=1  # single weight tile that does not change

# %%
show_config(ConfigRegistry.PIM_MAPPER)
# Out:
# mapper:
#   optimization-metric: [ delay, energy ]
#   live-status: False
#   num-threads: 8
#   timeout: 15000
#   victory-condition: 800
#   diagnostics: True

# %%
# !accelergyTables -r /home/workspace/final-project/example_designs/simple_pim/processing-in-memory-design/PIM_estimation_tables

pim_accelergy_result = run_accelergy(
    ConfigRegistry.PIM_ARCH,
    ConfigRegistry.PIM_COMPONENTS_DIR
)
print(pim_accelergy_result.ert_verbose)
# Out:
# /home/workspace/final-project/example_designs/simple_pim/processing-in-memory-design/PIM_estimation_tables is already added as a root for table based plug-in
# ERT_summary:
#   version: 0.3
#   table_summary:
#   - name: system_arch.DRAM
#     actions:
#     - name: read
#       energy: 512
#     - name: write
#       energy: 512
#     - name: idle
#       energy: 0
#     primitive_estimation(s):
#     - system_arch.DRAM:
#         estimator: Cacti
#   - name: system_arch.chip.PE[0..16383].scratchpad
#     actions:
#     - name: read
#       energy: 0.0
#     primitive_estimation(s):
#     - action_name: read
#       arguments: null
#       energy: 0.0
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0%
#         estimator: table-based-plug-ins
#   - name: system_arch.chip.PE[0..16383].mac
#     actions:
#     - name: compute
#       energy: 0.23424
#     primitive_estimation(s):
#     - action_name: compute
#       arguments: null
#       energy: 0.23424
#       subaction_estimations:
#       - subcomponent_name: cell[0..7]
#         subaction_name: compute
#         arguments: null
#         energy: 0.00183
#         action_share: 16
#         interpreted_energy: 0.23424
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#   - name: system_arch.chip.shared_glb
#     actions:
#     - name: write
#       average_energy: 21.35907
#       max_energy: 42.2087
#       min_energy: 0.50943
#     - name: read
#       average_energy: 21.10577
#       max_energy: 41.7021
#       min_energy: 0.50943
#     - name: idle
#       energy: 0.00943
#     primitive_estimation(s):
#     - action_name: write
#       arguments:
#         address_delta: 0
#         data_delta: 0
#       energy: 0.50943
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 0
#           data_delta: 0
#         energy: 0.00943
#         action_share: 1
#         interpreted_energy: 0.00943
#         percentage: 1.85%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 98.15%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 0
#         data_delta: 1
#       energy: 29.69892
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 0
#           data_delta: 1
#         energy: 29.19892
#         action_share: 1
#         interpreted_energy: 29.19892
#         percentage: 98.32%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.68%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 1
#         data_delta: 0
#       energy: 0.90036
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 1
#           data_delta: 0
#         energy: 0.40036
#         action_share: 1
#         interpreted_energy: 0.40036
#         percentage: 44.47%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 55.53%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 1
#         data_delta: 1
#       energy: 30.08985
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 1
#           data_delta: 1
#         energy: 29.58985
#         action_share: 1
#         interpreted_energy: 29.58985
#         percentage: 98.34%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.66%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 2
#         data_delta: 0
#       energy: 1.2913
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 2
#           data_delta: 0
#         energy: 0.7913
#         action_share: 1
#         interpreted_energy: 0.7913
#         percentage: 61.28%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 38.72%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 2
#         data_delta: 1
#       energy: 30.48078
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 2
#           data_delta: 1
#         energy: 29.98078
#         action_share: 1
#         interpreted_energy: 29.98078
#         percentage: 98.36%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.64%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 3
#         data_delta: 0
#       energy: 1.68223
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 3
#           data_delta: 0
#         energy: 1.18223
#         action_share: 1
#         interpreted_energy: 1.18223
#         percentage: 70.28%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 29.72%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 3
#         data_delta: 1
#       energy: 30.87171
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 3
#           data_delta: 1
#         energy: 30.37171
#         action_share: 1
#         interpreted_energy: 30.37171
#         percentage: 98.38%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.62%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 4
#         data_delta: 0
#       energy: 2.07316
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 4
#           data_delta: 0
#         energy: 1.57316
#         action_share: 1
#         interpreted_energy: 1.57316
#         percentage: 75.88%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 24.12%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 4
#         data_delta: 1
#       energy: 31.26264
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 4
#           data_delta: 1
#         energy: 30.76264
#         action_share: 1
#         interpreted_energy: 30.76264
#         percentage: 98.4%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.6%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 5
#         data_delta: 0
#       energy: 2.46409
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 5
#           data_delta: 0
#         energy: 1.96409
#         action_share: 1
#         interpreted_energy: 1.96409
#         percentage: 79.71%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 20.29%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 5
#         data_delta: 1
#       energy: 31.65357
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 5
#           data_delta: 1
#         energy: 31.15357
#         action_share: 1
#         interpreted_energy: 31.15357
#         percentage: 98.42%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.58%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 6
#         data_delta: 0
#       energy: 2.85502
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 6
#           data_delta: 0
#         energy: 2.35502
#         action_share: 1
#         interpreted_energy: 2.35502
#         percentage: 82.49%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 17.51%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 6
#         data_delta: 1
#       energy: 32.0445
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 6
#           data_delta: 1
#         energy: 31.5445
#         action_share: 1
#         interpreted_energy: 31.5445
#         percentage: 98.44%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.56%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 7
#         data_delta: 0
#       energy: 3.24595
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 7
#           data_delta: 0
#         energy: 2.74595
#         action_share: 1
#         interpreted_energy: 2.74595
#         percentage: 84.6%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 15.4%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 7
#         data_delta: 1
#       energy: 32.43543
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 7
#           data_delta: 1
#         energy: 31.93543
#         action_share: 1
#         interpreted_energy: 31.93543
#         percentage: 98.46%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.54%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 8
#         data_delta: 0
#       energy: 3.63688
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 8
#           data_delta: 0
#         energy: 3.13688
#         action_share: 1
#         interpreted_energy: 3.13688
#         percentage: 86.25%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 13.75%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 8
#         data_delta: 1
#       energy: 32.82637
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 8
#           data_delta: 1
#         energy: 32.32637
#         action_share: 1
#         interpreted_energy: 32.32637
#         percentage: 98.48%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.52%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 9
#         data_delta: 0
#       energy: 4.02781
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 9
#           data_delta: 0
#         energy: 3.52781
#         action_share: 1
#         interpreted_energy: 3.52781
#         percentage: 87.59%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 12.41%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 9
#         data_delta: 1
#       energy: 33.2173
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 9
#           data_delta: 1
#         energy: 32.7173
#         action_share: 1
#         interpreted_energy: 32.7173
#         percentage: 98.49%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.51%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 10
#         data_delta: 0
#       energy: 4.41874
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 10
#           data_delta: 0
#         energy: 3.91874
#         action_share: 1
#         interpreted_energy: 3.91874
#         percentage: 88.68%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 11.32%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 10
#         data_delta: 1
#       energy: 33.60823
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 10
#           data_delta: 1
#         energy: 33.10823
#         action_share: 1
#         interpreted_energy: 33.10823
#         percentage: 98.51%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.49%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 11
#         data_delta: 0
#       energy: 4.80967
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 11
#           data_delta: 0
#         energy: 4.30967
#         action_share: 1
#         interpreted_energy: 4.30967
#         percentage: 89.6%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 10.4%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 11
#         data_delta: 1
#       energy: 33.99916
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 11
#           data_delta: 1
#         energy: 33.49916
#         action_share: 1
#         interpreted_energy: 33.49916
#         percentage: 98.53%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.47%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 12
#         data_delta: 0
#       energy: 5.2006
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 12
#           data_delta: 0
#         energy: 4.7006
#         action_share: 1
#         interpreted_energy: 4.7006
#         percentage: 90.39%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 9.61%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 12
#         data_delta: 1
#       energy: 34.39009
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 12
#           data_delta: 1
#         energy: 33.89009
#         action_share: 1
#         interpreted_energy: 33.89009
#         percentage: 98.55%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.45%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 13
#         data_delta: 0
#       energy: 5.59153
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 13
#           data_delta: 0
#         energy: 5.09153
#         action_share: 1
#         interpreted_energy: 5.09153
#         percentage: 91.06%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 8.94%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 13
#         data_delta: 1
#       energy: 34.78102
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 13
#           data_delta: 1
#         energy: 34.28102
#         action_share: 1
#         interpreted_energy: 34.28102
#         percentage: 98.56%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.44%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 14
#         data_delta: 0
#       energy: 5.98246
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 14
#           data_delta: 0
#         energy: 5.48246
#         action_share: 1
#         interpreted_energy: 5.48246
#         percentage: 91.64%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 8.36%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 14
#         data_delta: 1
#       energy: 35.17195
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 14
#           data_delta: 1
#         energy: 34.67195
#         action_share: 1
#         interpreted_energy: 34.67195
#         percentage: 98.58%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.42%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 15
#         data_delta: 0
#       energy: 6.37339
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 15
#           data_delta: 0
#         energy: 5.87339
#         action_share: 1
#         interpreted_energy: 5.87339
#         percentage: 92.15%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 7.85%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 15
#         data_delta: 1
#       energy: 35.56288
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 15
#           data_delta: 1
#         energy: 35.06288
#         action_share: 1
#         interpreted_energy: 35.06288
#         percentage: 98.59%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.41%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 16
#         data_delta: 0
#       energy: 6.76432
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 16
#           data_delta: 0
#         energy: 6.26432
#         action_share: 1
#         interpreted_energy: 6.26432
#         percentage: 92.61%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 7.39%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 16
#         data_delta: 1
#       energy: 35.95381
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 16
#           data_delta: 1
#         energy: 35.45381
#         action_share: 1
#         interpreted_energy: 35.45381
#         percentage: 98.61%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.39%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 17
#         data_delta: 0
#       energy: 7.15525
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 17
#           data_delta: 0
#         energy: 6.65525
#         action_share: 1
#         interpreted_energy: 6.65525
#         percentage: 93.01%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 6.99%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 17
#         data_delta: 1
#       energy: 36.34474
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 17
#           data_delta: 1
#         energy: 35.84474
#         action_share: 1
#         interpreted_energy: 35.84474
#         percentage: 98.62%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.38%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 18
#         data_delta: 0
#       energy: 7.54619
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 18
#           data_delta: 0
#         energy: 7.04619
#         action_share: 1
#         interpreted_energy: 7.04619
#         percentage: 93.37%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 6.63%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 18
#         data_delta: 1
#       energy: 36.73567
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 18
#           data_delta: 1
#         energy: 36.23567
#         action_share: 1
#         interpreted_energy: 36.23567
#         percentage: 98.64%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.36%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 19
#         data_delta: 0
#       energy: 7.93712
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 19
#           data_delta: 0
#         energy: 7.43712
#         action_share: 1
#         interpreted_energy: 7.43712
#         percentage: 93.7%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 6.3%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 19
#         data_delta: 1
#       energy: 37.1266
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 19
#           data_delta: 1
#         energy: 36.6266
#         action_share: 1
#         interpreted_energy: 36.6266
#         percentage: 98.65%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.35%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 20
#         data_delta: 0
#       energy: 8.32805
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 20
#           data_delta: 0
#         energy: 7.82805
#         action_share: 1
#         interpreted_energy: 7.82805
#         percentage: 94.0%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 6.0%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 20
#         data_delta: 1
#       energy: 37.51753
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 20
#           data_delta: 1
#         energy: 37.01753
#         action_share: 1
#         interpreted_energy: 37.01753
#         percentage: 98.67%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.33%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 21
#         data_delta: 0
#       energy: 8.71898
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 21
#           data_delta: 0
#         energy: 8.21898
#         action_share: 1
#         interpreted_energy: 8.21898
#         percentage: 94.27%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 5.73%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 21
#         data_delta: 1
#       energy: 37.90846
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 21
#           data_delta: 1
#         energy: 37.40846
#         action_share: 1
#         interpreted_energy: 37.40846
#         percentage: 98.68%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.32%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 22
#         data_delta: 0
#       energy: 9.10991
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 22
#           data_delta: 0
#         energy: 8.60991
#         action_share: 1
#         interpreted_energy: 8.60991
#         percentage: 94.51%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 5.49%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 22
#         data_delta: 1
#       energy: 38.29939
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 22
#           data_delta: 1
#         energy: 37.79939
#         action_share: 1
#         interpreted_energy: 37.79939
#         percentage: 98.69%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.31%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 23
#         data_delta: 0
#       energy: 9.50084
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 23
#           data_delta: 0
#         energy: 9.00084
#         action_share: 1
#         interpreted_energy: 9.00084
#         percentage: 94.74%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 5.26%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 23
#         data_delta: 1
#       energy: 38.69032
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 23
#           data_delta: 1
#         energy: 38.19032
#         action_share: 1
#         interpreted_energy: 38.19032
#         percentage: 98.71%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.29%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 24
#         data_delta: 0
#       energy: 9.89177
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 24
#           data_delta: 0
#         energy: 9.39177
#         action_share: 1
#         interpreted_energy: 9.39177
#         percentage: 94.95%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 5.05%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 24
#         data_delta: 1
#       energy: 39.08126
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 24
#           data_delta: 1
#         energy: 38.58126
#         action_share: 1
#         interpreted_energy: 38.58126
#         percentage: 98.72%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.28%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 25
#         data_delta: 0
#       energy: 10.2827
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 25
#           data_delta: 0
#         energy: 9.7827
#         action_share: 1
#         interpreted_energy: 9.7827
#         percentage: 95.14%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 4.86%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 25
#         data_delta: 1
#       energy: 39.47219
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 25
#           data_delta: 1
#         energy: 38.97219
#         action_share: 1
#         interpreted_energy: 38.97219
#         percentage: 98.73%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
# ...
#         num_destinations: 92
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 93
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 94
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 95
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 96
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 97
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 98
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 99
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 100
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 101
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 102
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 103
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 104
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 105
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 106
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 107
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 108
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 109
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 110
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 111
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 112
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 113
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 114
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 115
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 116
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 117
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 118
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 119
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 120
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 121
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 122
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 123
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 124
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 125
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 126
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 127
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 128
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#   - name: system_arch.chip.A2D_NoC
#     actions:
#     - name: transfer_Outputs
#       energy: 223.20768
#     primitive_estimation(s):
#     - action_name: transfer_Outputs
#       arguments:
#         num_destinations: 1
#       energy: 223.20768
#       subaction_estimations:
#       - subcomponent_name: A2D_converter.SH[0..7]
#         subaction_name: sample_and_hold
#         arguments: null
#         energy: 1.0e-05
#         action_share: 16
#         interpreted_energy: 0.00128
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#       - subcomponent_name: A2D_converter.ADC
#         subaction_name: convert
#         arguments: null
#         energy: 1.66
#         action_share: 128
#         interpreted_energy: 212.48
#         percentage: 95.19%
#         estimator: table-based-plug-ins
#       - subcomponent_name: digital_accumulator.S_A
#         subaction_name: shift_and_add
#         arguments: null
#         energy: 0.0418
#         action_share: 128
#         interpreted_energy: 5.3504
#         percentage: 2.4%
#         estimator: table-based-plug-ins
#       - subcomponent_name: digital_accumulator.outputBuffer
#         subaction_name: read
#         arguments:
#           address_delta: 1
#           data_delta: 1
#         energy: 0.192
#         action_share: 14
#         interpreted_energy: 2.688
#         percentage: 1.2%
#         estimator: table-based-plug-ins
#       - subcomponent_name: digital_accumulator.outputBuffer
#         subaction_name: write
#         arguments:
#           address_delta: 1
#           data_delta: 1
#         energy: 0.192
#         action_share: 14
#         interpreted_energy: 2.688
#         percentage: 1.2%
#         estimator: table-based-plug-ins

# %%
alexnet_layers = [
    ConfigRegistry.ALEXNET_LAYER1,
    ConfigRegistry.ALEXNET_LAYER2,
    ConfigRegistry.ALEXNET_LAYER3,
    ConfigRegistry.ALEXNET_LAYER4,
    ConfigRegistry.ALEXNET_LAYER5,
]

# %%
alexnet_stats = []
alexnet_loops = []

for i, layer in enumerate(alexnet_layers):
    results = run_timeloop_mapper(
        ConfigRegistry.PIM_ARCH,
        ConfigRegistry.PIM_COMPONENTS_DIR,
        pim_accelergy_result.art,
        pim_accelergy_result.ert,
        ConfigRegistry.PIM_CONSTRAINTS,
        ConfigRegistry.PIM_MAPPER,
        layer,
    )
    print(f"Layer: {i+1}")
    stats, loops = results
    print(loops)
    
    alexnet_stats.append(stats)
    alexnet_loops.append(loops)
# Out:
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Found Accelergy ERT (energy reference table), replacing internal energy model.
# Found Accelergy ART (area reference table), replacing internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 2
#   Factorization options along problem dimension M = 12
#   Factorization options along problem dimension R = 2
#   Factorization options along problem dimension S = 2
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension P = 16
#   Factorization options along problem dimension Q = 16
# Mapspace Dimension [IndexFactorization] Size: 24576
# Mapspace Dimension [LoopPermutation] Size: 152409600
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 3072 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# WARNING: no optimization metric(s) specified, using edp as default.
# [  3] Utilization = 0.00 | pJ/Compute =  255.849 | L3[IO] Q5 P11 - L2[IO] S11 R11 M96 C3 - L1[] Q1 - L0[W] Q11 P5
# [  6] Utilization = 0.00 | pJ/Compute =   87.635 | L3[IO] Q5 P11 - L2[IO] S11 R11 M48 - L1[] Q1 M2Y C3X - L0[W] Q11 P5
# [  2] Utilization = 0.00 | pJ/Compute =   93.059 | L3[IO] Q5 P11 - L2[IO] S11 R11 M96 - L1[] Q1 C3X - L0[W] Q11 P5
# [  0] Utilization = 0.00 | pJ/Compute =   82.324 | L3[IO] Q5 P11 - L2[IO] S11 R11 - L1[] Q1 M96Y C3X - L0[W] Q11 P5
# [  1] Utilization = 0.00 | pJ/Compute =  245.114 | L3[IO] Q5 P11 - L2[IO] S11 R11 C3 - L1[] Q1 M96Y - L0[W] Q11 P5
# [  4] Utilization = 0.00 | pJ/Compute =   82.437 | L3[IO] Q5 P11 - L2[IO] S11 R11 M2 - L1[] Q1 M48Y C3X - L0[W] Q11 P5
# [  5] Utilization = 0.00 | pJ/Compute =  245.227 | L3[IO] Q5 P11 - L2[IO] S11 R11 M2 C3 - L1[] Q1 M48Y - L0[W] Q11 P5
# [  7] Utilization = 0.00 | pJ/Compute =  250.425 | L3[IO] Q5 P11 - L2[IO] S11 R11 M48 C3 - L1[] Q1 M2Y - L0[W] Q11 P5
# [  3] Utilization = 0.00 | pJ/Compute =  248.617 | L3[IO] Q5 P11 - L2[IO] S11 R11 M32 C3 - L1[] Q1 M3Y - L0[W] Q11 P5
# [  6] Utilization = 0.00 | pJ/Compute =   84.923 | L3[IO] Q5 P11 - L2[IO] S11 R11 M24 - L1[] Q1 M4Y C3X - L0[W] Q11 P5
# [  6] Utilization = 0.00 | pJ/Compute =   13.677 | L3[IO] Q11 P11 - L2[IO] P5 R11 M48 - L1[] Q5 M2Y C3X S11X - L0[W] Q1
# [  2] Utilization = 0.00 | pJ/Compute =   85.827 | L3[IO] Q5 P11 - L2[IO] S11 R11 M32 - L1[] Q1 M3Y C3X - L0[W] Q11 P5
# [  6] Utilization = 0.01 | pJ/Compute =    9.546 | L3[IO] Q11 - L2[IO] P55 S11 M12 - L1[] Q1 M8Y C3X R11X - L0[W] Q5
# [  2] Utilization = 0.00 | pJ/Compute =   19.101 | L3[IO] Q11 P11 - L2[IO] P5 R11 M96 - L1[] Q5 C3X S11X - L0[W] Q1
# [  2] Utilization = 0.01 | pJ/Compute =    9.998 | L3[IO] Q11 - L2[IO] P55 S11 M16 - L1[] Q1 M6Y C3X R11X - L0[W] Q5
# [  3] Utilization = 0.00 | pJ/Compute =   33.900 | L3[IO] Q11 P11 - L2[IO] P5 R11 M96 C3 - L1[] Q5 S11X - L0[W] Q1
# [  7] Utilization = 0.00 | pJ/Compute =  247.713 | L3[IO] Q5 P11 - L2[IO] S11 R11 M24 C3 - L1[] Q1 M4Y - L0[W] Q11 P5
# [  1] Utilization = 0.01 | pJ/Compute =   23.165 | L3[IO] Q11 P11 - L2[IO] P5 R11 C3 - L1[] Q5 M96Y S11X - L0[W] Q1
# [  4] Utilization = 0.02 | pJ/Compute =    8.479 | L3[IO] Q11 P11 - L2[IO] P5 R11 M2 - L1[] Q5 M48Y C3X S11X - L0[W] Q1
# [  0] Utilization = 0.03 | pJ/Compute =    8.366 | L3[IO] Q11 P11 - L2[IO] P5 R11 - L1[] Q5 M96Y C3X S11X - L0[W] Q1
# [  7] Utilization = 0.00 | pJ/Compute =   28.476 | L3[IO] Q11 P11 - L2[IO] P5 R11 M48 C3 - L1[] Q5 M2Y S11X - L0[W] Q1
# [  5] Utilization = 0.01 | pJ/Compute =   23.278 | L3[IO] Q11 P11 - L2[IO] P5 R11 M2 C3 - L1[] Q5 M48Y S11X - L0[W] Q1
# [  3] Utilization = 0.00 | pJ/Compute =   24.797 | L3[IO] Q11 - L2[IO] P55 S11 M16 C3 - L1[] Q1 M6Y R11X - L0[W] Q5
# [  3] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  7] Utilization = 0.00 | pJ/Compute =   24.345 | L3[IO] Q11 - L2[IO] P55 S11 M12 C3 - L1[] Q1 M8Y R11X - L0[W] Q5
# [  2] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  6] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  0] Utilization = 0.03 | pJ/Compute =    8.303 | L3[IO] P11 - L2[IO] Q5 S11 - L1[] Q1 M96Y C3X R11X - L0[W] Q11 P5
# [  1] Utilization = 0.01 | pJ/Compute =    3.549 | L3[IO] Q11 P11 - L2[IO] M6 C3 - L1[] Q5 P5 M16Y S11X R11X - L0[W] Q1
# [  4] Utilization = 0.02 | pJ/Compute =    8.416 | L3[IO] P11 - L2[IO] Q5 S11 M2 - L1[] Q1 M48Y C3X R11X - L0[W] Q11 P5
# [  7] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  5] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  1] Utilization = 0.06 | pJ/Compute =    2.984 | L3[IO] Q11 P55 - L2[IO] C3 - L1[] Q5 M96Y S11X R11X - L0[W] Q1
# [  0] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  4] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  1] Utilization = 0.06 | pJ/Compute =    2.947 | L3[IO] Q5 P55 - L2[IO] C3 - L1[] Q11 M96Y S11X R11X - L0[W] Q1
# [  1] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# ===============================================
#                BEGIN DIAGNOSTICS
# -----------------------------------------------
# Fail class: Fanout
#
#   Level: dummy_buffer
#     Fail count: 1206
#     Sample mapping that experienced this fail class:
#
#       DRAM [ Inputs:154587 (154587) Outputs:290400 (290400) ]
#       -------------------------------------------------------
#       | for Q in [0:1)
#
#       shared_glb [ Inputs:154587 (154587) Outputs:290400 (290400) ]
#       -------------------------------------------------------------
#       |   for M in [0:6)
#       |     for P in [0:55)
#       |       for Q in [0:11)
#
#       dummy_buffer [ ]
#       ----------------
#       |         for Q in [0:5)
#       |           for M in [0:16) (Spatial-Y)
#       |             for C in [0:3) (Spatial-X)
#       |               for S in [0:11) (Spatial-X)
#       |                 for R in [0:11) (Spatial-X)
#
#       scratchpad [ Weights:1 (1) ]
#       ----------------------------
#       |                   for Q in [0:1)
#
#     Fail reason: mapped fanoutX 363 exceeds hardware fanoutX 128
#
# Fail class: Capacity
#
#   Level: shared_glb
#     Fail count: 204
#     Sample mapping that experienced this fail class:
#
#       DRAM [ Inputs:154587 (154587) Outputs:290400 (290400) ]
#       -------------------------------------------------------
#       | for Q in [0:1)
#
#       shared_glb [ Inputs:154587 (154587) Outputs:290400 (290400) ]
#       -------------------------------------------------------------
#       |   for Q in [0:55)
#       |     for P in [0:5)
#       |       for S in [0:11)
#       |         for R in [0:11)
#
#       dummy_buffer [ ]
#       ----------------
#       |           for Q in [0:1)
#       |             for M in [0:96) (Spatial-Y)
#       |               for C in [0:3) (Spatial-X)
#
#       scratchpad [ Weights:1 (1) ]
#       ----------------------------
#       |                 for P in [0:11)
#
#     Fail reason: mapped tile size 444987 exceeds buffer capacity 65536
#
# -----------------------------------------------
#                  END DIAGNOSTICS
# ===============================================
#
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.06 | pJ/Compute =    2.947
# Layer: 1
#
# DRAM [ Inputs:154587 (154587) Outputs:290400 (290400) ]
# -------------------------------------------------------
# | for Q in [0:5)
# |   for P in [0:55)
#
# shared_glb [ Inputs:1683 (1683) Outputs:1056 (1056) ]
# -----------------------------------------------------
# |     for C in [0:3)
#
# dummy_buffer [ ]
# ----------------
# |       for Q in [0:11)
# |         for M in [0:96) (Spatial-Y)
# |           for S in [0:11) (Spatial-X)
# |             for R in [0:11) (Spatial-X)
#
# scratchpad [ Weights:1 (1) ]
# ----------------------------
# |               for Q in [0:1)
#
#
# Buffer and Arithmetic Levels
# ----------------------------
# Level 0
# -------
# === mac ===
#
#     SPECS
#     -----
#     Word bits             : 16
#     Instances             : 16384 (128*128)
#     Compute energy        : 0.23 pJ
#
#     STATS
#     -----
#     Utilized instances      : 11616
#     Computes (total)        : 105415200
#     Cycles                  : 9075
#     Energy (total)          : 24692456.45 pJ
#     Area (total)            : 200.54 um^2
#
# Level 1
# -------
# === scratchpad ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 1
#         Word bits                   : 16
#         Block size                  : 1
#         Cluster size                : 1
#         Instances                   : 16384 (128*128)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
#         Effective size              : 1
#         Min utilization             : 0.00
#         Vector access energy        : 0.00 pJ
#         Vector access energy source : ERT
#         Area                        : 0.00 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#
#     STATS
#     -----
#     Cycles               : 9075
#     Bandwidth throttling : 1.00
#     Weights:
#         Partition size                           : 3
#         Utilized capacity                        : 1
#         Utilized instances (max)                 : 11616
#         Utilized clusters (max)                  : 11616
#         Scalar reads (per-instance)              : 9075
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 9075
#         Energy (per-scalar-access)               : 0.00 pJ
#         Energy (per-instance)                    : 0.00 pJ
#         Energy (total)                           : 0.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 1.00 words/cycle
#         Shared Bandwidth (total)                 : 11616.00 words/cycle
#         Read Bandwidth (per-instance)            : 1.00 words/cycle
#         Read Bandwidth (total)                   : 11616.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.00 words/cycle
#
# Level 2
# -------
# === dummy_buffer ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 0
#         Word bits                   : 16
#         Block size                  : 1
#         Cluster size                : 1
#         Instances                   : 1 (1*1)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
#         Effective size              : 0
#         Min utilization             : 0.00
#         Vector access energy        : 0.00 pJ
#         Vector access energy source : ERT
#         Area                        : 0.00 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#
#     STATS
#     -----
#     Cycles               : 9075
#     Bandwidth throttling : 1.00
#
# Level 3
# -------
# === shared_glb ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 65536
#         Word bits                   : 16
#         Block size                  : 4
#         Cluster size                : 1
#         Instances                   : 1 (1*1)
#         Shared bandwidth            : -
#         Read bandwidth              : 16.00
#         Write bandwidth             : 16.00
#         Multiple buffering          : 1.00
#         Effective size              : 65536
#         Min utilization             : 0.00
#         Vector access energy        : 42.21 pJ
#         Vector access energy source : ERT
#         Area                        : 590948.00 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#
#     STATS
#     -----
#     Cycles               : 104930
#     Bandwidth throttling : 0.09
#     Inputs:
#         Partition size                           : 154587
#         Utilized capacity                        : 1683
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 1098075
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 173655
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 1271730
#         Energy (per-scalar-access)               : 10.44 pJ
#         Energy (per-instance)                    : 13280467.29 pJ
#         Energy (total)                           : 13280467.29 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 12.12 words/cycle
#         Shared Bandwidth (total)                 : 12.12 words/cycle
#         Read Bandwidth (per-instance)            : 10.46 words/cycle
#         Read Bandwidth (total)                   : 10.46 words/cycle
#         Write Bandwidth (per-instance)           : 1.65 words/cycle
#         Write Bandwidth (total)                  : 1.65 words/cycle
#     Outputs:
#         Partition size                           : 290400
#         Utilized capacity                        : 1056
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 580800
#         Scalar updates (per-instance)            : 871200
#         Scalar fills (per-instance)              : 290400
#         Temporal reductions (per-instance)       : 580800
#         Address generations (per-cluster)        : 1161600
#         Energy (per-scalar-access)               : 10.51 pJ
#         Energy (per-instance)                    : 18312551.40 pJ
#         Energy (total)                           : 18312551.40 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 16.61 words/cycle
#         Shared Bandwidth (total)                 : 16.61 words/cycle
#         Read Bandwidth (per-instance)            : 5.54 words/cycle
#         Read Bandwidth (total)                   : 5.54 words/cycle
#         Write Bandwidth (per-instance)           : 11.07 words/cycle
#         Write Bandwidth (total)                  : 11.07 words/cycle
#
# Level 4
# -------
# === DRAM ===
#
#     SPECS
#     -----
#         Technology                  : DRAM
#         Size                        : -
#         Word bits                   : 16
#         Block size                  : 4
#         Cluster size                : 1
#         Instances                   : 1 (1*1)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
#         Effective size              : -
#         Min utilization             : 0.00
#         Vector access energy        : 512.00 pJ
#         Vector access energy source : ERT
#         Area                        : 0.00 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#
#     STATS
#     -----
#     Cycles               : 9075
#     Bandwidth throttling : 1.00
#     Inputs:
#         Partition size                           : 154587
#         Utilized capacity                        : 154587
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 173655
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 173655
#         Energy (per-scalar-access)               : 128.00 pJ
#         Energy (per-instance)                    : 22227968.00 pJ
#         Energy (total)                           : 22227968.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 19.14 words/cycle
#         Shared Bandwidth (total)                 : 19.14 words/cycle
#         Read Bandwidth (per-instance)            : 19.14 words/cycle
#         Read Bandwidth (total)                   : 19.14 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.00 words/cycle
#     Outputs:
#         Partition size                           : 290400
#         Utilized capacity                        : 290400
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 0
#         Scalar updates (per-instance)            : 290400
#         Scalar fills (per-instance)              : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 290400
#         Energy (per-scalar-access)               : 128.00 pJ
#         Energy (per-instance)                    : 37171200.00 pJ
#         Energy (total)                           : 37171200.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 32.00 words/cycle
#         Shared Bandwidth (total)                 : 32.00 words/cycle
#         Read Bandwidth (per-instance)            : 0.00 words/cycle
#         Read Bandwidth (total)                   : 0.00 words/cycle
#         Write Bandwidth (per-instance)           : 32.00 words/cycle
#         Write Bandwidth (total)                  : 32.00 words/cycle
#
# Networks
# --------
# Network 0
# ---------
# A2D_NoC
#
#     SPECS
#     -----
#         Type            : SimpleMulticast
#         ConnectionType  : 2
#         Word bits       : 16
#         Action Name       : transfer
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 0
#         Multicast factor                        : 0
#         Ingresses                               : 0.00
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#     Inputs:
#         Fanout                                  : 1
#         Multicast factor                        : 1
#         Ingresses                               : 1098075.00
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Multicast factor                        : 1
#         Ingresses                               : 871200.00
#         Energy (per-instance)                   : 194458530.82 pJ
#         Energy (total)                          : 194458530.82 pJ
#
# Network 1
# ---------
# D2A_NoC
#
#     SPECS
#     -----
#         Type            : SimpleMulticast
#         ConnectionType  : 1
#         Word bits       : 16
#         Action Name       : transfer
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 0
#         Multicast factor                        : 0
#         Ingresses                               : 0.00
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#     Inputs:
#         Fanout                                  : 1
#         Multicast factor                        : 1
#         Ingresses                               : 1098075.00
#         Energy (per-instance)                   : 463826.88 pJ
#         Energy (total)                          : 463826.88 pJ
#     Outputs:
#         Fanout                                  : 1
#         Multicast factor                        : 1
#         Ingresses                               : 871200.00
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#
# Network 2
# ---------
# DRAM <==> shared_glb
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 0
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 0
#         Ingresses                               : 0.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.00
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Inputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 173655.00
#             @multicast 1 @scatter 1: 173655.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 290400.00
#             @multicast 1 @scatter 1: 290400.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
# Network 3
# ---------
# dummy_buffer <==> scratchpad
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 0
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 0
#         Ingresses                               : 0.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.00
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Inputs:
#         Fanout                                  : 11616
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 96
#         Ingresses                               : 1098075.00
#             @multicast 96 @scatter 121: 1098075.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 1094.49
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 11616
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 121
#         Ingresses                               : 871200.00
#             @multicast 121 @scatter 96: 871200.00
#         Link transfers                          : 0
#         Spatial reductions                      : 104544000
#         Average number of hops                  : 1224.64
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
# Network 4
# ---------
# scratchpad <==> mac
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 9075.00
#             @multicast 1 @scatter 1: 9075.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Inputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 9075.00
#             @multicast 1 @scatter 1: 9075.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 9075.00
#             @multicast 1 @scatter 1: 9075.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
#
# Operational Intensity Stats
# ---------------------------
#     Total elementwise ops                   : 105415200
#     Total reduction ops                     : 105124800
#     Total ops                               : 210540000
#     Total memory accesses required          : 444988
#     Optimal Op per Byte                     : 236.57
#
# === scratchpad ===
#     Total scalar accesses                   : 105415200
#     Op per Byte                             : 1.00
# === dummy_buffer ===
# === shared_glb ===
#     Total scalar accesses                   : 3014130
#     Op per Byte                             : 34.93
# === DRAM ===
#     Total scalar accesses                   : 464055
#     Op per Byte                             : 226.85
#
#
# Summary Stats
# -------------
# GFLOPs (@1GHz): 2006.48
# Utilization: 0.06
# Cycles: 104930
# Energy: 310.61 uJ
# EDP(J*cycle): 3.26e+01
# Area: 0.00 mm^2
#
# Computes = 105415200
# pJ/Compute
#     mac                          = 0.23
#     scratchpad                   = 0.00
#     dummy_buffer                 = 0.00
#     shared_glb                   = 0.30
#     DRAM                         = 0.56
#     A2D_NoC                      = 1.84
#     D2A_NoC                      = 0.00
#     DRAM <==> shared_glb         = 0.00
#     dummy_buffer <==> scratchpad = 0.00
#     scratchpad <==> mac          = 0.00
#     Total                        = 2.95
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Found Accelergy ERT (energy reference table), replacing internal energy model.
# Found Accelergy ART (area reference table), replacing internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 12
#   Factorization options along problem dimension M = 9
#   Factorization options along problem dimension R = 2
#   Factorization options along problem dimension S = 2
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension P = 20
#   Factorization options along problem dimension Q = 20
# Mapspace Dimension [IndexFactorization] Size: 172800
# Mapspace Dimension [LoopPermutation] Size: 152409600
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 21600 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# WARNING: no optimization metric(s) specified, using edp as default.
# [  1] Utilization = 0.00 | pJ/Compute =    9.201 | L3[IO] Q27 P3 - L2[IO] M128 C32 - L1[] P9 M2Y C3X S5X R5X - L0[W] Q1
# [  3] Utilization = 0.00 | pJ/Compute =    8.360 | L3[IO] Q27 P3 - L2[IO] M128 C24 - L1[] P9 M2Y C4X S5X R5X - L0[W] Q1
# [  5] Utilization = 0.01 | pJ/Compute =   41.098 | L3[IO] P9 - L2[IO] S5 R5 M2 C16 - L1[] P3 M128Y C6X - L0[W] Q27
# [  7] Utilization = 0.01 | pJ/Compute =   30.924 | L3[IO] P9 - L2[IO] S5 R5 M2 C12 - L1[] P3 M128Y C8X - L0[W] Q27
# [  6] Utilization = 0.01 | pJ/Compute =   20.750 | L3[IO] P9 - L2[IO] S5 R5 M2 C8 - L1[] P3 M128Y C12X - L0[W] Q27
# [  4] Utilization = 0.01 | pJ/Compute =   15.663 | L3[IO] P9 - L2[IO] S5 R5 M2 C6 - L1[] P3 M128Y C16X - L0[W] Q27
# [  1] Utilization = 0.01 | pJ/Compute =   17.959 | L3[IO] Q3 P3 - L2[IO] S5 M32 C32 - L1[] Q9 M8Y C3X R5X - L0[W] P9
# [  2] Utilization = 0.02 | pJ/Compute =   10.575 | L3[IO] P9 - L2[IO] S5 R5 M2 C4 - L1[] P3 M128Y C24X - L0[W] Q27
# [  3] Utilization = 0.01 | pJ/Compute =   13.889 | L3[IO] Q3 P3 - L2[IO] S5 M32 C24 - L1[] Q9 M8Y C4X R5X - L0[W] P9
# [  0] Utilization = 0.03 | pJ/Compute =    8.032 | L3[IO] P9 - L2[IO] S5 R5 M2 C3 - L1[] P3 M128Y C32X - L0[W] Q27
# [  5] Utilization = 0.01 | pJ/Compute =    9.819 | L3[IO] Q3 P3 - L2[IO] S5 M32 C16 - L1[] Q9 M8Y C6X R5X - L0[W] P9
# [  7] Utilization = 0.01 | pJ/Compute =    7.784 | L3[IO] Q3 P3 - L2[IO] S5 M32 C12 - L1[] Q9 M8Y C8X R5X - L0[W] P9
# [  1] Utilization = 0.01 | pJ/Compute =   16.772 | L3[IO] Q3 P3 - L2[IO] Q9 R5 M4 C32 - L1[] P3 M64Y C3X S5X - L0[W] P3
# [  3] Utilization = 0.01 | pJ/Compute =   12.702 | L3[IO] Q3 P3 - L2[IO] Q9 R5 M4 C24 - L1[] P3 M64Y C4X S5X - L0[W] P3
# [  6] Utilization = 0.01 | pJ/Compute =    5.749 | L3[IO] Q3 P3 - L2[IO] S5 M32 C8 - L1[] Q9 M8Y C12X R5X - L0[W] P9
# [  5] Utilization = 0.02 | pJ/Compute =    8.633 | L3[IO] Q3 P3 - L2[IO] Q9 R5 M4 C16 - L1[] P3 M64Y C6X S5X - L0[W] P3
# [  4] Utilization = 0.01 | pJ/Compute =    4.732 | L3[IO] Q3 P3 - L2[IO] S5 M32 C6 - L1[] Q9 M8Y C16X R5X - L0[W] P9
# [  7] Utilization = 0.02 | pJ/Compute =    6.598 | L3[IO] Q3 P3 - L2[IO] Q9 R5 M4 C12 - L1[] P3 M64Y C8X S5X - L0[W] P3
# [  1] Utilization = 0.02 | pJ/Compute =    8.595 | L3[IO] Q3 P3 - L2[IO] P3 S5 M2 C16 - L1[] P3 M128Y C6X R5X - L0[W] Q9
# [  6] Utilization = 0.03 | pJ/Compute =    4.563 | L3[IO] Q3 P3 - L2[IO] Q9 R5 M4 C8 - L1[] P3 M64Y C12X S5X - L0[W] P3
# [  3] Utilization = 0.03 | pJ/Compute =    6.524 | L3[IO] Q3 P3 - L2[IO] P3 S5 M2 C12 - L1[] P3 M128Y C8X R5X - L0[W] Q9
# [  2] Utilization = 0.01 | pJ/Compute =    3.714 | L3[IO] Q3 P3 - L2[IO] S5 M32 C4 - L1[] Q9 M8Y C24X R5X - L0[W] P9
# [  5] Utilization = 0.02 | pJ/Compute =    3.940 | L3[IO] Q9 P3 - L2[IO] M8 C32 - L1[] Q3 P3 M32Y C3X S5X R5X - L0[W] P3
# [  4] Utilization = 0.04 | pJ/Compute =    3.545 | L3[IO] Q3 P3 - L2[IO] Q9 R5 M4 C6 - L1[] P3 M64Y C16X S5X - L0[W] P3
# [  7] Utilization = 0.02 | pJ/Compute =    3.126 | L3[IO] Q9 P3 - L2[IO] M8 C24 - L1[] Q3 P3 M32Y C4X S5X R5X - L0[W] P3
# [  5] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  2] Utilization = 0.04 | pJ/Compute =    2.528 | L3[IO] Q3 P3 - L2[IO] Q9 R5 M4 C4 - L1[] P3 M64Y C24X S5X - L0[W] P3
# [  1] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  7] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  6] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  3] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  0] Utilization = 0.05 | pJ/Compute =    3.466 | L3[IO] Q3 P3 - L2[IO] P3 S5 M2 C6 - L1[] P3 M128Y C16X R5X - L0[W] Q9
# [  4] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  2] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  0] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# ===============================================
#                BEGIN DIAGNOSTICS
# -----------------------------------------------
# Fail class: Fanout
#
#   Level: dummy_buffer
#     Fail count: 9702
#     Sample mapping that experienced this fail class:
#
#       DRAM [ Inputs:92256 (92256) Outputs:186624 (186624) ]
#       -----------------------------------------------------
#       | for Q in [0:3)
#       |   for P in [0:3)
#
#       shared_glb [ Inputs:16224 (16224) Outputs:20736 (20736) ]
#       ---------------------------------------------------------
#       |     for M in [0:8)
#       |       for Q in [0:3)
#       |         for R in [0:5)
#       |           for P in [0:3)
#       |             for C in [0:3)
#
#       dummy_buffer [ ]
#       ----------------
#       |               for Q in [0:1)
#       |                 for M in [0:32) (Spatial-Y)
#       |                   for C in [0:32) (Spatial-X)
#       |                     for S in [0:5) (Spatial-X)
#
#       scratchpad [ Weights:1 (1) ]
#       ----------------------------
#       |                       for Q in [0:3)
#       |                         for P in [0:3)
#
#     Fail reason: mapped fanoutX 160 exceeds hardware fanoutX 128
#
# Fail class: Capacity
#
#   Level: shared_glb
#     Fail count: 102
#     Sample mapping that experienced this fail class:
#
#       DRAM [ Inputs:92256 (92256) Outputs:186624 (186624) ]
#       -----------------------------------------------------
#       | for Q in [0:3)
#
#       shared_glb [ Inputs:38688 (38688) Outputs:62208 (62208) ]
#       ---------------------------------------------------------
#       |   for Q in [0:3)
#       |     for P in [0:27)
#       |       for S in [0:5)
#       |         for R in [0:5)
#       |           for M in [0:4)
#       |             for C in [0:3)
#
#       dummy_buffer [ ]
#       ----------------
#       |               for Q in [0:3)
#       |                 for M in [0:64) (Spatial-Y)
#       |                   for C in [0:32) (Spatial-X)
#
#       scratchpad [ Weights:1 (1) ]
#       ----------------------------
#       |                     for Q in [0:1)
#
#     Fail reason: mapped tile size 100896 exceeds buffer capacity 65536
#
# -----------------------------------------------
#                  END DIAGNOSTICS
# ===============================================
#
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.04 | pJ/Compute =    2.528
# Layer: 2
#
# DRAM [ Inputs:92256 (92256) Outputs:186624 (186624) ]
# -----------------------------------------------------
# | for Q in [0:3)
# |   for P in [0:3)
#
# shared_glb [ Inputs:16224 (16224) Outputs:20736 (20736) ]
# ---------------------------------------------------------
# |     for Q in [0:9)
# |       for R in [0:5)
# |         for M in [0:4)
# |           for C in [0:4)
#
# dummy_buffer [ ]
# ----------------
# |             for P in [0:3)
# |               for M in [0:64) (Spatial-Y)
# |                 for C in [0:24) (Spatial-X)
# |                   for S in [0:5) (Spatial-X)
#
# scratchpad [ Weights:1 (1) ]
# ----------------------------
# |                     for P in [0:3)
#
#
# Buffer and Arithmetic Levels
# ----------------------------
# Level 0
# -------
# === mac ===
#
#     SPECS
#     -----
#     Word bits             : 16
#     Instances             : 16384 (128*128)
#     Compute energy        : 0.23 pJ
#
#     STATS
#     -----
#     Utilized instances      : 7680
#     Computes (total)        : 447897600
#     Cycles                  : 58320
#     Energy (total)          : 104915533.82 pJ
#     Area (total)            : 200.54 um^2
#
# Level 1
# -------
# === scratchpad ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 1
#         Word bits                   : 16
#         Block size                  : 1
#         Cluster size                : 1
#         Instances                   : 16384 (128*128)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
#         Effective size              : 1
#         Min utilization             : 0.00
#         Vector access energy        : 0.00 pJ
#         Vector access energy source : ERT
#         Area                        : 0.00 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#       for P in [0:3)
#
#     STATS
#     -----
#     Cycles               : 58320
#     Bandwidth throttling : 1.00
#     Weights:
#         Partition size                           : 80
#         Utilized capacity                        : 1
#         Utilized instances (max)                 : 7680
#         Utilized clusters (max)                  : 7680
#         Scalar reads (per-instance)              : 58320
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 58320
#         Energy (per-scalar-access)               : 0.00 pJ
#         Energy (per-instance)                    : 0.00 pJ
#         Energy (total)                           : 0.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 1.00 words/cycle
#         Shared Bandwidth (total)                 : 7680.00 words/cycle
#         Read Bandwidth (per-instance)            : 1.00 words/cycle
#         Read Bandwidth (total)                   : 7680.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.00 words/cycle
#
# Level 2
# -------
# === dummy_buffer ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 0
#         Word bits                   : 16
#         Block size                  : 1
#         Cluster size                : 1
#         Instances                   : 1 (1*1)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
#         Effective size              : 0
#         Min utilization             : 0.00
#         Vector access energy        : 0.00 pJ
#         Vector access energy source : ERT
#         Area                        : 0.00 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#
#     STATS
#     -----
#     Cycles               : 58320
#     Bandwidth throttling : 1.00
#
# Level 3
# -------
# === shared_glb ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 65536
#         Word bits                   : 16
#         Block size                  : 4
#         Cluster size                : 1
#         Instances                   : 1 (1*1)
#         Shared bandwidth            : -
#         Read bandwidth              : 16.00
#         Write bandwidth             : 16.00
#         Multiple buffering          : 1.00
#         Effective size              : 65536
#         Min utilization             : 0.00
#         Vector access energy        : 42.21 pJ
#         Vector access energy source : ERT
#         Area                        : 590948.00 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#
#     STATS
#     -----
#     Cycles               : 659016
#     Bandwidth throttling : 0.09
#     Inputs:
#         Partition size                           : 92256
#         Utilized capacity                        : 16224
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 6998400
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 116064
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 7114464
#         Energy (per-scalar-access)               : 10.43 pJ
#         Energy (per-instance)                    : 74186721.80 pJ
#         Energy (total)                           : 74186721.80 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 10.80 words/cycle
#         Shared Bandwidth (total)                 : 10.80 words/cycle
#         Read Bandwidth (per-instance)            : 10.62 words/cycle
#         Read Bandwidth (total)                   : 10.62 words/cycle
#         Write Bandwidth (per-instance)           : 0.18 words/cycle
#         Write Bandwidth (total)                  : 0.18 words/cycle
#     Outputs:
#         Partition size                           : 186624
#         Utilized capacity                        : 20736
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 3545856
#         Scalar updates (per-instance)            : 3732480
#         Scalar fills (per-instance)              : 186624
#         Temporal reductions (per-instance)       : 3545856
#         Address generations (per-cluster)        : 3919104
#         Energy (per-scalar-access)               : 10.49 pJ
#         Energy (per-instance)                    : 78322481.63 pJ
#         Energy (total)                           : 78322481.63 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 11.33 words/cycle
#         Shared Bandwidth (total)                 : 11.33 words/cycle
#         Read Bandwidth (per-instance)            : 5.38 words/cycle
#         Read Bandwidth (total)                   : 5.38 words/cycle
#         Write Bandwidth (per-instance)           : 5.95 words/cycle
#         Write Bandwidth (total)                  : 5.95 words/cycle
#
# Level 4
# -------
# === DRAM ===
#
#     SPECS
#     -----
#         Technology                  : DRAM
#         Size                        : -
#         Word bits                   : 16
#         Block size                  : 4
#         Cluster size                : 1
#         Instances                   : 1 (1*1)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
#         Effective size              : -
#         Min utilization             : 0.00
#         Vector access energy        : 512.00 pJ
#         Vector access energy source : ERT
#         Area                        : 0.00 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#
#     STATS
#     -----
#     Cycles               : 58320
#     Bandwidth throttling : 1.00
#     Inputs:
#         Partition size                           : 92256
#         Utilized capacity                        : 92256
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 116064
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 0
# ...
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 16.15 words/cycle
#         Shared Bandwidth (total)                 : 16.15 words/cycle
#         Read Bandwidth (per-instance)            : 7.93 words/cycle
#         Read Bandwidth (total)                   : 7.93 words/cycle
#         Write Bandwidth (per-instance)           : 8.22 words/cycle
#         Write Bandwidth (total)                  : 8.22 words/cycle
#
# Level 4
# -------
# === DRAM ===
#
#     SPECS
#     -----
#         Technology                  : DRAM
#         Size                        : -
#         Word bits                   : 16
#         Block size                  : 4
#         Cluster size                : 1
#         Instances                   : 1 (1*1)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
#         Effective size              : -
#         Min utilization             : 0.00
#         Vector access energy        : 512.00 pJ
#         Vector access energy source : ERT
#         Area                        : 0.00 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#
#     STATS
#     -----
#     Cycles               : 36504
#     Bandwidth throttling : 1.00
#     Inputs:
#         Partition size                           : 86400
#         Utilized capacity                        : 86400
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 86400
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 86400
#         Energy (per-scalar-access)               : 128.00 pJ
#         Energy (per-instance)                    : 11059200.00 pJ
#         Energy (total)                           : 11059200.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 2.37 words/cycle
#         Shared Bandwidth (total)                 : 2.37 words/cycle
#         Read Bandwidth (per-instance)            : 2.37 words/cycle
#         Read Bandwidth (total)                   : 2.37 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.00 words/cycle
#     Outputs:
#         Partition size                           : 43264
#         Utilized capacity                        : 43264
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 0
#         Scalar updates (per-instance)            : 43264
#         Scalar fills (per-instance)              : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 43264
#         Energy (per-scalar-access)               : 128.00 pJ
#         Energy (per-instance)                    : 5537792.00 pJ
#         Energy (total)                           : 5537792.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 1.19 words/cycle
#         Shared Bandwidth (total)                 : 1.19 words/cycle
#         Read Bandwidth (per-instance)            : 0.00 words/cycle
#         Read Bandwidth (total)                   : 0.00 words/cycle
#         Write Bandwidth (per-instance)           : 1.19 words/cycle
#         Write Bandwidth (total)                  : 1.19 words/cycle
#
# Networks
# --------
# Network 0
# ---------
# A2D_NoC
#
#     SPECS
#     -----
#         Type            : SimpleMulticast
#         ConnectionType  : 2
#         Word bits       : 16
#         Action Name       : transfer
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 0
#         Multicast factor                        : 0
#         Ingresses                               : 0.00
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#     Inputs:
#         Fanout                                  : 1
#         Multicast factor                        : 1
#         Ingresses                               : 2336256.00
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Multicast factor                        : 1
#         Ingresses                               : 2336256.00
#         Energy (per-instance)                   : 521470281.65 pJ
#         Energy (total)                          : 521470281.65 pJ
#
# Network 1
# ---------
# D2A_NoC
#
#     SPECS
#     -----
#         Type            : SimpleMulticast
#         ConnectionType  : 1
#         Word bits       : 16
#         Action Name       : transfer
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 0
#         Multicast factor                        : 0
#         Ingresses                               : 0.00
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#     Inputs:
#         Fanout                                  : 1
#         Multicast factor                        : 1
#         Ingresses                               : 2336256.00
#         Energy (per-instance)                   : 986834.53 pJ
#         Energy (total)                          : 986834.53 pJ
#     Outputs:
#         Fanout                                  : 1
#         Multicast factor                        : 1
#         Ingresses                               : 2336256.00
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#
# Network 2
# ---------
# DRAM <==> shared_glb
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 0
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 0
#         Ingresses                               : 0.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.00
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Inputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 86400.00
#             @multicast 1 @scatter 1: 86400.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 43264.00
#             @multicast 1 @scatter 1: 43264.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
# Network 3
# ---------
# dummy_buffer <==> scratchpad
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 0
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 0
#         Ingresses                               : 0.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.00
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Inputs:
#         Fanout                                  : 4096
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 64
#         Ingresses                               : 2336256.00
#             @multicast 64 @scatter 64: 2336256.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 532.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 4096
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 64
#         Ingresses                               : 2336256.00
#             @multicast 64 @scatter 64: 2336256.00
#         Link transfers                          : 0
#         Spatial reductions                      : 147184128
#         Average number of hops                  : 532.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
# Network 4
# ---------
# scratchpad <==> mac
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 36504.00
#             @multicast 1 @scatter 1: 36504.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Inputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 36504.00
#             @multicast 1 @scatter 1: 36504.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 36504.00
#             @multicast 1 @scatter 1: 36504.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
#
# Operational Intensity Stats
# ---------------------------
#     Total elementwise ops                   : 149520384
#     Total reduction ops                     : 149477120
#     Total ops                               : 298997504
#     Total memory accesses required          : 129665
#     Optimal Op per Byte                     : 1152.96
#
# === scratchpad ===
#     Total scalar accesses                   : 149520384
#     Op per Byte                             : 1.00
# === dummy_buffer ===
# === shared_glb ===
#     Total scalar accesses                   : 7095168
#     Op per Byte                             : 21.07
# === DRAM ===
#     Total scalar accesses                   : 129664
#     Op per Byte                             : 1152.97
#
#
# Summary Stats
# -------------
# GFLOPs (@1GHz): 1033.42
# Utilization: 0.03
# Cycles: 289328
# Energy: 648.36 uJ
# EDP(J*cycle): 1.88e+02
# Area: 0.00 mm^2
#
# Computes = 149520384
# pJ/Compute
#     mac                          = 0.23
#     scratchpad                   = 0.00
#     dummy_buffer                 = 0.00
#     shared_glb                   = 0.50
#     DRAM                         = 0.11
#     A2D_NoC                      = 3.49
#     D2A_NoC                      = 0.01
#     DRAM <==> shared_glb         = 0.00
#     dummy_buffer <==> scratchpad = 0.00
#     scratchpad <==> mac          = 0.00
#     Total                        = 4.34

# %%
fname = './results/alexnet_pim/mapper/'

extract_numbers(alexnet_stats, fname + 'stats.pkl')
_ = load_data(fname + 'stats.pkl')

save_loop_nests(alexnet_loops, fname + 'loops.txt')

# %%
for i, (stats, loops) in enumerate(alexnet_pim_layerwise_results):
    print(f"Layer: {i+1}")
    log = False
    for line in stats.split("\n"):
        if "Summary Stats" in line:
            log = True
        if log:
            print(line)
# Out:
# Layer: 1
# Summary Stats
# -------------
# GFLOPs (@1GHz): 2006.48
# Utilization: 0.06
# Cycles: 104930
# Energy: 310.61 uJ
# EDP(J*cycle): 3.26e+01
# Area: 0.00 mm^2
#
# Computes = 105415200
# pJ/Compute
#     mac                          = 0.23
#     scratchpad                   = 0.00
#     dummy_buffer                 = 0.00
#     shared_glb                   = 0.30
#     DRAM                         = 0.56
#     A2D_NoC                      = 1.84
#     D2A_NoC                      = 0.00
#     DRAM <==> shared_glb         = 0.00
#     dummy_buffer <==> scratchpad = 0.00
#     scratchpad <==> mac          = 0.00
#     Total                        = 2.95
#
#
# Layer: 2
# Summary Stats
# -------------
# GFLOPs (@1GHz): 1359.01
# Utilization: 0.04
# Cycles: 659016
# Energy: 1132.24 uJ
# EDP(J*cycle): 7.46e+02
# Area: 0.00 mm^2
#
# Computes = 447897600
# pJ/Compute
#     mac                          = 0.23
#     scratchpad                   = 0.00
#     dummy_buffer                 = 0.00
#     shared_glb                   = 0.34
#     DRAM                         = 0.09
#     A2D_NoC                      = 1.86
#     D2A_NoC                      = 0.01
#     DRAM <==> shared_glb         = 0.00
#     dummy_buffer <==> scratchpad = 0.00
#     scratchpad <==> mac          = 0.00
#     Total                        = 2.53
#
#
# Layer: 3
# Summary Stats
# -------------
# GFLOPs (@1GHz): 1390.79
# Utilization: 0.04
# Cycles: 214968
# Energy: 361.90 uJ
# EDP(J*cycle): 7.78e+01
# Area: 0.00 mm^2
#
# Computes = 149520384
# pJ/Compute
#     mac                          = 0.23
#     scratchpad                   = 0.00
#     dummy_buffer                 = 0.00
#     shared_glb                   = 0.33
#     DRAM                         = 0.10
#     A2D_NoC                      = 1.74
#     D2A_NoC                      = 0.01
#     DRAM <==> shared_glb         = 0.00
#     dummy_buffer <==> scratchpad = 0.00
#     scratchpad <==> mac          = 0.00
#     Total                        = 2.42
#
#
# Layer: 4
# Summary Stats
# -------------
# GFLOPs (@1GHz): 1650.39
# Utilization: 0.05
# Cycles: 271752
# Energy: 605.26 uJ
# EDP(J*cycle): 1.64e+02
# Area: 0.00 mm^2
#
# Computes = 224280576
# pJ/Compute
#     mac                          = 0.23
#     scratchpad                   = 0.00
#     dummy_buffer                 = 0.00
#     shared_glb                   = 0.31
#     DRAM                         = 0.09
#     A2D_NoC                      = 2.07
#     D2A_NoC                      = 0.00
#     DRAM <==> shared_glb         = 0.00
#     dummy_buffer <==> scratchpad = 0.00
#     scratchpad <==> mac          = 0.00
#     Total                        = 2.70
#
#
# Layer: 5
# Summary Stats
# -------------
# GFLOPs (@1GHz): 1033.42
# Utilization: 0.03
# Cycles: 289328
# Energy: 648.36 uJ
# EDP(J*cycle): 1.88e+02
# Area: 0.00 mm^2
#
# Computes = 149520384
# pJ/Compute
#     mac                          = 0.23
#     scratchpad                   = 0.00
#     dummy_buffer                 = 0.00
#     shared_glb                   = 0.50
#     DRAM                         = 0.11
#     A2D_NoC                      = 3.49
#     D2A_NoC                      = 0.01
#     DRAM <==> shared_glb         = 0.00
#     dummy_buffer <==> scratchpad = 0.00
#     scratchpad <==> mac          = 0.00
#     Total                        = 4.34

# %%
total_cycles = 0
for i, (stats, loops) in enumerate(alexnet_pim_layerwise_results):
    for line in stats.split("\n"):
        if "Cycles: " in line:
            cycles = int(line[len("Cycles: "):])
            total_cycles += cycles
            print(f"Cycles in layer {i+1}: {cycles}")
            break
print(f"Total cycles: {total_cycles}")
# Out:
# Cycles in layer 1: 104930
# Cycles in layer 2: 659016
# Cycles in layer 3: 214968
# Cycles in layer 4: 271752
# Cycles in layer 5: 289328
# Total cycles: 1539994

# %%
total_energy = 0
for i, (stats, loops) in enumerate(alexnet_pim_layerwise_results):
    for line in stats.split("\n"):
        if "Energy: " in line:
            energy = float(line[len("Energy: "):].split(' uJ')[0])
            total_energy += energy
            print(f"Energy in layer {i+1}: {energy}")
            break
print(f"Total energy: {total_energy} uJ")
# Out:
# Energy in layer 1: 310.61
# Energy in layer 2: 1132.24
# Energy in layer 3: 361.9
# Energy in layer 4: 605.26
# Energy in layer 5: 648.36
# Total energy: 3058.3700000000003 uJ
