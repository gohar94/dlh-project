# %%
import pandas as pd
import numpy as np
from loaders import *

# %%
show_config(ConfigRegistry.PIM_ARCH)
# Out:
# architecture:
#   version: 0.3
#   subtree:                           # "subtree" contains abstract hierarchies
#     - name: system_arch              # name of the design
#       attributes:                    # shared attributes that will propagate down all lower levels
#         technology: 32nm
#         latency: 1ns
#       local:
#         - name: DRAM                 # offchip DRAM is the source of all datatypes
#           class: DRAM                # assume DRAM is large enough to store all the data, so no depth specification needed
#           attributes:
#             width: 64                # width in bits
#             datawidth: 16            # datawidth in bits
#             block-size: 4
#       subtree:
#         - name: chip                 # all components below this level are on-chip components
#           local:
#             - name: shared_glb
#               class: smartbuffer_SRAM
#               attributes:
#                 memory_depth: 16384
#                 memory_width: 64
#                 n_banks: 32
#                 block-size: 4
#                 word-bits: 16
#                 read_bandwidth: 16
#                 write_bandwidth: 16
#                 n_rdwr_ports: 2
#                 network_read: D2A_NoC
#                 network_update: A2D_NoC
#             - name: dummy_buffer
#               class: dummy_storage
#               attributes:
#                 depth: 0   # will result in zero area/energy for accelergy
#                 width: 16  # timeloop needs a width even if the memory is not storing anything
#                 network_fill: D2A_NoC
#                 network_drain: A2D_NoC
#             - name: D2A_NoC
#               class: SimpleMulticast         # timeloop class
#               subclass: DAC_SimpleMulticast  # accelergy class
#               attributes:
#                 datawidth: 16
#                 DAC_datawidth: 1  # DAC only converts one bit per cycle
#                 n_DAC_cycles: 16  # number of cycles needed for a DAC to convert a datawidth-bit data
#                 n_PE_cols: 128
#                 n_PE_rows: 128
#                 action_name: transfer
#                 per_datatype_ERT: True
#                 multicast_factor_argument: num_destinations
#             - name: A2D_NoC
#               class: SimpleMulticast         # timeloop class
#               subclass: ADC_SimpleMulticast  # accelergy class
#               attributes:
#                 datawidth: 16
#                 ADC_datawidth: 8
#                 cell_datawidth: 2
#                 n_DAC_cycles: 16    # number of cycles needed for a DAC to convert a datawidth-bit data = datawidth/DAC_datawidth
#                 n_PE_cols: 128
#                 n_PE_rows: 128
#                 action_name: transfer
#                 per_datatype_ERT: True
#                 multicast_factor_argument: num_destinations
#           subtree:
#             - name: PE[0..16383]
#               local:                 # "local" contains physical instantiations
#                 - name: scratchpad
#                   class: memcell_storage  # definitions of the compound classes can be found under "components" folder
#                   attributes:
#                     width: 16       # width in bits
#                     depth: 1
#                     meshX: 128        # number of components in the X dimension (PE rows)
#                     meshY: 128        # number of components in the Y dimension (PE cols)
#                 - name: mac
#                   class: memcell_compute
#                   attributes:
#                     datawidth: 16   # datawidth in bits
#                     meshX: 128        # number of components in the X dimension (PE rows)
#                     meshY: 128        # number of components in the Y dimension (PE cols)

# %%
show_config(ConfigRegistry.PIM_COMPONENTS_DIR)
# Out:
# compound_components:
#   version: 0.3
#   classes:
#     - name: A2D_conversion_system
#       attributes:  # default attributes that can be overridden
#         technology: 32nm
#         latency: 1ns
#         datawidth: 16
#         cell_datawidth: 2
#         n_DAC_cycles: 16
#         ADC_datawidth: 8
#         n_PE_cols: 8
#         # derived parameters (automatically derived, but can be overridden from high-level)
#         nCells: datawidth/cell_datawidth
#         SH_datawidth: ADC_datawidth
#         total_SHs: nCells * n_PE_cols # each physical column has a sample and hold
#         ADC_converts_per_psum: nCells * n_DAC_cycles # temporal: n_DAC_cycles times for each column of cells
#       subcomponents:
#         - name: SH[0..total_SHs-1] # this is all SHs in the system
#           class: sample_and_hold
#           attributes:
#             technology: technology
#             latency: latency
#             datawidth: SH_datawidth
#         - name: ADC #  assume this ADC is fast enough to convert the output of the SHs in one cycle
#           class: ADC
#           attributes:
#             technology: technology
#             latency: latency
#             type: SAR
#             datawidth: ADC_datawidth
#       actions:
#         - name: convert
#           subcomponents:
#             - name: SH[0..nCells-1]
#               actions:
#                 - name: sample_and_hold
#                   action_share: n_DAC_cycles  # number of times the action need to be performed
#             - name: ADC
#               actions:
#                 - name: convert
#                   action_share: ADC_converts_per_psum # number of times the action need to be performed
#
# compound_components:
#   version: 0.3
#   classes:
#     - name: ADC_SimpleMulticast
#       attributes:
#         technology: 45nm
#         latency: 1ns
#         datawidth: 16
#         A2D_convert_width: 16
#         ADC_datawidth: 8
#         cell_datawidth: 2
#         n_DAC_cycles: 16
#       subcomponents:
#         - name: A2D_converter
#           class: A2D_conversion_system
#           attributes:
#             technology: technology
#             latency: latency
#             datawidth: datawidth
#             ADC_datawidth: ADC_datawidth
#             cell_datawidth: cell_datawidth
#             n_DAC_cycles: n_DAC_cycles
#         - name: digital_accumulator
#           class: digital_accumulation_system
#           attributes:
#             technology: technology
#             latency: latency
#             datawidth: datawidth
#             cell_datawidth: cell_datawidth
#             n_DAC_cycles: n_DAC_cycles
#       actions:
#         - name: transfer_Outputs
#           arguments:
#             num_destinations: 1..1 # digital partial sums are only sent to global buffer
#           subcomponents:
#             - name: A2D_converter
#               actions:
#                 - name: convert
#             - name: digital_accumulator
#               actions:
#                 - name: accumulate
# compound_components:
#   version: 0.3
#   classes:
#     - name: D2A_conversion_system
#       attributes:
#         technology: 32nm
#         latency: 1ns
#         datawidth: 16
#         meshX: 128
#         meshY: 128
#         DAC_datawidth: 1
#         cell_datawidth: 2
#         # derived parameters (automatically derived, but can be overridden from high-level)
#         nCells: datawidth/cell_datawidth
#         nArrays: nCells
#         nCycles: datawidth/DAC_datawidth
#         total_DACs: nArrays * meshY # each array has meshY number of DACs
#         DAC_converts_per_psum: nCycles
#       subcomponents:
#         - name: DAC[0..total_DACs-1]
#           class: DAC
#           attributes:
#             technology: technology
#             latency: latency
#             datawidth: DAC_datawidth
#       actions:
#         - name: convert
#           subcomponents:
#             # each row in an array of LMACs need one DAC
#             - name: DAC[0..nArrays-1]
#               actions:
#                 - name: convert
#                   action_share: nCycles
#
# compound_components:
#   version: 0.3
#   classes:
#     - name: DAC_SimpleMulticast
#       attributes:
#         technology: 45nm
#         latency: 1ns
#         datawidth: 16
#         DAC_datawidth: 1
#         cell_datawidth: 2
#         num_converts: datawidth/DAC_datawidth
#       subcomponents:
#         - name: D2A_converter
#           class: D2A_conversion_system
#           attributes:
#             technology: technology
#             latency: latency
#             datawidth: datawidth
#             DAC_datawidth: DAC_datawidth
#             cell_datawidth: cell_datawidth
#       actions:
#         - name: transfer_Inputs
#           arguments:
#             num_destinations: 1..n_PE_cols
#           subcomponents:
#             - name: D2A_converter
#               actions:
#                 - name: convert
#                   action_share: n_PE_cols
# compound_components:
#   version: 0.3
#   classes:
#     - name: digital_accumulation_system
#       attributes:
#         technology: 32nm
#         latency: 1ns
#         datawidth: 16
#         meshX: 128
#         meshY: 128
#         cell_datawidth: 2
#         n_DAC_cycles: 16
#         # derived parameters (automatically derived, but can be overridden from high-level)
#         nCells: datawidth/cell_datawidth
#         nArrays: nCells
#         total_S_As: nArrays  # each array share a shift and add
#         S_A_datawidth: datawidth
#         S_As_per_psum: nCells * n_DAC_cycles # temporal S_A computations
#         buffer_per_psum: n_DAC_cycles -2 # the first and last partial sums are not written into into this buffer
#       subcomponents:
#         - name: S_A
#           class: shift_and_add
#           attributes:
#             technology: technology
#             latency: latency
#             datawidth: S_A_datawidth
#         - name: outputBuffer
#           class: SRAM
#           attributes:
#             technology: technology
#             latency: latency
#             width: 16
#             depth: 128
#             datawidth: 16
#       actions:
#         - name: accumulate
#           subcomponents:
#             - name: S_A # assume this S_A is fast enough to do the computations needed in one cycle
#               actions:
#                 - name: shift_and_add
#                   action_share: S_As_per_psum
#             - name: outputBuffer
#               actions:
#                 - name: read
#                   arguments:
#                     address_delta: 1
#                     data_delta: 1
#                   action_share: buffer_per_psum
#                 - name: write
#                   arguments:
#                     address_delta: 1
#                     data_delta: 1
#                   action_share: buffer_per_psum
# compound_components:
#   version: 0.3
#   classes:
#     - name: memcell_compute
#       attributes:
#         cell_technology: memristor
#         cmos_technology: 32nm
#         cell_datawidth: 2
#         DAC_datawidth: 1
#         datawidth: 16
#         nCells: datawidth/cell_datawidth
#         nCycles: datawidth/DAC_datawidth
#         compute_latency: 100ns
#       subcomponents:
#         - name: cell[0..nCells-1]
#           class: ReRAMcell_compute
#           attributes:
#             technology: cell_technology
#             cellwidth: cell_datawidth
#             latency: 100ns
#       actions:
#         - name: compute
#           subcomponents:
#             - name: cell[0..nCells-1] # spatial
#               actions:
#                 - name: compute
#                   action_share: nCycles # temporal: compute 1 bit input at a time
#
# compound_components:
#   version: 0.3
#   classes:
#   - name: smartbuffer_SRAM
#     attributes:
#       technology: 45nm
#       memory_depth: 12
#       memory_width: 16
#       n_rdwr_ports: 2
#       n_banks: 1
#       n_buffets: 1
#     subcomponents:
#       - name: storage
#         class: SRAM
#         attributes:
#           technology: technology
#           width: memory_width
#           depth: memory_depth
#           n_rdwr_ports: n_rdwr_ports
#           n_banks: n_banks
#       - name: address_generators[0..1]
#         class: intadder
#         attributes:
#           technology: technology
#           width: log(memory_depth)
#     actions:
#       - name: write
#         arguments:
#           data_delta: 0..1
#           address_delta: 0..n_banks
#         subcomponents:
#           - name: storage
#             actions:
#               - name: write
#                 arguments:
#                   data_delta: data_delta
#                   address_delta: address_delta
#           - name: address_generators[0]
#             actions:
#               - name: add
#           - name: address_generators[1]
#             actions:
#               - name: idle
#       - name: read
#         arguments:
#           data_delta: 0..1
#           address_delta: 0..n_banks
#         subcomponents:
#           - name: storage
#             actions:
#               - name: read
#                 arguments:
#                   data_delta: data_delta
#                   address_delta: address_delta
#           - name: address_generators[1]
#             actions:
#               - name: add
#           - name: address_generators[0]
#             actions:
#               - name: idle
#       - name: idle
#         subcomponents:
#           - name: storage
#             actions:
#               - name: idle
#           - name: address_generators[0..1]
#             actions:
#               - name: idle
# compound_components:
#   version: 0.3
#   classes:
#     - name: SRAM_storage
#       attributes:
#         technology: 16nm
#         latency: 1ns
#         depth: 1024
#         width: 16
#         datawidth: 16
#         nports: 1
#         nbanks: 1
#       subcomponents:
#         - name: storage
#           class: SRAM
#           attributes:
#             technology: technology
#             latency: latency
#             depth: depth
#             width: width
#             datawidth: datawidth
#             n_rdwr_ports: nports
#             n_banks: nbanks
#       actions:
#         - name: read
#           subcomponents:
#             - name: storage
#               actions:
#                 - name: read
#                   arguments:
#                     address_delta: 1
#                     data_delta: 1
#         - name: write
#           subcomponents:
#             - name: storage
#               actions:
#                 - name: write
#                   arguments:
#                     address_delta: 1
#                     data_delta: 1
#
#
#     - name: memcell_storage
#       attributes:
#         cmos_technology: 32nm
#         cell_technology: memristor
#         depth: 256
#         width: 16
#         cell_datawidth: 2
#       subcomponents:
#         - name: storage
#           class: ReRAMcell_storage
#           attributes:
#             technology: cell_technology
#             latency: latency
#             cellwidth: cell_datawidth
#       actions:
#         - name: read
#           subcomponents:
#             - name: storage
#               actions:
#                 - name: idle
#
#     - name: dummy_storage
#       attributes:
#         depth: 0
#         width: 0
#       subcomponents:
#         - name: storage
#           class: SRAM
#           attributes:
#             depth: 0
#             width: 0
#             datawidth: 0
#             n_rdwr_ports: 0
#       actions:
#         - name: access
#           subcomponents:
#             - name: storage
#               actions:
#                 - name: idle

# %%
show_config(ConfigRegistry.PIM_CONSTRAINTS)
# Out:
# mapspace:
#   targets:
#     # =======================================
#     # DRAM
#     # =======================================
#     - target: DRAM
#       type: bypassing
#       keep: [Inputs, Outputs]
#       bypass: [Weights]  # weights are stored locally in the memcells, not loaded from DRAM
#     - target: DRAM
#       type: temporal
#       factors: R=1 S=1 M=1 C=1
#       permutation: RSCPQMN
#     # =======================================
#     # Global Buffer Constraints
#     # =======================================
#     - target: shared_glb
#       type: bypassing
#       keep: [Inputs, Outputs]
#       bypass: [Weights] # weights are stored locally in the memcells, not loaded from DRAM
#     - target: shared_glb
#       type: temporal
#       # factors: R=1 S=1 M=1 C=1 # TODO(girfan): Ask TA if this makes sense.
#     # =======================================
#     # Dummy Buffer Constraints
#     # =======================================
#     - target: dummy_buffer
#       type: bypassing
#       keep: []
#       bypass: [Inputs, Outputs, Weights]  # no data should be stored in dummy, it is just a transition buffer
#     - target: dummy_buffer
#       type: spatial
#       factors: Q=1 P=1
#       permutation: RSC M
#       split: 3  # M cannot be mapped in the same dimension as others
#     - target: dummy_buffer
#       type: temporal
#       factors: R=1 S=1 M=1 C=1
#     # =======================================
#     # WS Buffer Constraints
#     # =======================================
#     - target: scratchpad
#       type: bypassing
#       keep: [Weights]
#       bypass: [Inputs, Outputs]
#     - target: scratchpad
#       type: temporal
#       factors: R=1 S=1 M=1 C=1  # single weight tile that does not change

# %%
show_config(ConfigRegistry.PIM_MAPPER)
# Out:
# mapper:
#   optimization-metric: [ delay, energy ]
#   live-status: False
#   num-threads: 8
#   timeout: 15000
#   victory-condition: 800
#   diagnostics: True

# %%
# !accelergyTables -r /home/workspace/final-project/example_designs/simple_pim/processing-in-memory-design/PIM_estimation_tables

pim_accelergy_result = run_accelergy(
    ConfigRegistry.PIM_ARCH,
    ConfigRegistry.PIM_COMPONENTS_DIR
)
print(pim_accelergy_result.ert_verbose)
# Out:
# /home/workspace/final-project/example_designs/simple_pim/processing-in-memory-design/PIM_estimation_tables is added as a new root for table based plug-in.
# ERT_summary:
#   version: 0.3
#   table_summary:
#   - name: system_arch.DRAM
#     actions:
#     - name: read
#       energy: 512
#     - name: write
#       energy: 512
#     - name: idle
#       energy: 0
#     primitive_estimation(s):
#     - system_arch.DRAM:
#         estimator: Cacti
#   - name: system_arch.chip.PE[0..16383].scratchpad
#     actions:
#     - name: read
#       energy: 0.0
#     primitive_estimation(s):
#     - action_name: read
#       arguments: null
#       energy: 0.0
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0%
#         estimator: table-based-plug-ins
#   - name: system_arch.chip.PE[0..16383].mac
#     actions:
#     - name: compute
#       energy: 0.23424
#     primitive_estimation(s):
#     - action_name: compute
#       arguments: null
#       energy: 0.23424
#       subaction_estimations:
#       - subcomponent_name: cell[0..7]
#         subaction_name: compute
#         arguments: null
#         energy: 0.00183
#         action_share: 16
#         interpreted_energy: 0.23424
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#   - name: system_arch.chip.shared_glb
#     actions:
#     - name: write
#       average_energy: 21.35907
#       max_energy: 42.2087
#       min_energy: 0.50943
#     - name: read
#       average_energy: 21.10577
#       max_energy: 41.7021
#       min_energy: 0.50943
#     - name: idle
#       energy: 0.00943
#     primitive_estimation(s):
#     - action_name: write
#       arguments:
#         address_delta: 0
#         data_delta: 0
#       energy: 0.50943
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 0
#           data_delta: 0
#         energy: 0.00943
#         action_share: 1
#         interpreted_energy: 0.00943
#         percentage: 1.85%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 98.15%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 0
#         data_delta: 1
#       energy: 29.69892
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 0
#           data_delta: 1
#         energy: 29.19892
#         action_share: 1
#         interpreted_energy: 29.19892
#         percentage: 98.32%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.68%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 1
#         data_delta: 0
#       energy: 0.90036
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 1
#           data_delta: 0
#         energy: 0.40036
#         action_share: 1
#         interpreted_energy: 0.40036
#         percentage: 44.47%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 55.53%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 1
#         data_delta: 1
#       energy: 30.08985
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 1
#           data_delta: 1
#         energy: 29.58985
#         action_share: 1
#         interpreted_energy: 29.58985
#         percentage: 98.34%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.66%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 2
#         data_delta: 0
#       energy: 1.2913
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 2
#           data_delta: 0
#         energy: 0.7913
#         action_share: 1
#         interpreted_energy: 0.7913
#         percentage: 61.28%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 38.72%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 2
#         data_delta: 1
#       energy: 30.48078
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 2
#           data_delta: 1
#         energy: 29.98078
#         action_share: 1
#         interpreted_energy: 29.98078
#         percentage: 98.36%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.64%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 3
#         data_delta: 0
#       energy: 1.68223
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 3
#           data_delta: 0
#         energy: 1.18223
#         action_share: 1
#         interpreted_energy: 1.18223
#         percentage: 70.28%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 29.72%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 3
#         data_delta: 1
#       energy: 30.87171
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 3
#           data_delta: 1
#         energy: 30.37171
#         action_share: 1
#         interpreted_energy: 30.37171
#         percentage: 98.38%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.62%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 4
#         data_delta: 0
#       energy: 2.07316
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 4
#           data_delta: 0
#         energy: 1.57316
#         action_share: 1
#         interpreted_energy: 1.57316
#         percentage: 75.88%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 24.12%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 4
#         data_delta: 1
#       energy: 31.26264
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 4
#           data_delta: 1
#         energy: 30.76264
#         action_share: 1
#         interpreted_energy: 30.76264
#         percentage: 98.4%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.6%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 5
#         data_delta: 0
#       energy: 2.46409
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 5
#           data_delta: 0
#         energy: 1.96409
#         action_share: 1
#         interpreted_energy: 1.96409
#         percentage: 79.71%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 20.29%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 5
#         data_delta: 1
#       energy: 31.65357
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 5
#           data_delta: 1
#         energy: 31.15357
#         action_share: 1
#         interpreted_energy: 31.15357
#         percentage: 98.42%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.58%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 6
#         data_delta: 0
#       energy: 2.85502
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 6
#           data_delta: 0
#         energy: 2.35502
#         action_share: 1
#         interpreted_energy: 2.35502
#         percentage: 82.49%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 17.51%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 6
#         data_delta: 1
#       energy: 32.0445
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 6
#           data_delta: 1
#         energy: 31.5445
#         action_share: 1
#         interpreted_energy: 31.5445
#         percentage: 98.44%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.56%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 7
#         data_delta: 0
#       energy: 3.24595
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 7
#           data_delta: 0
#         energy: 2.74595
#         action_share: 1
#         interpreted_energy: 2.74595
#         percentage: 84.6%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 15.4%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 7
#         data_delta: 1
#       energy: 32.43543
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 7
#           data_delta: 1
#         energy: 31.93543
#         action_share: 1
#         interpreted_energy: 31.93543
#         percentage: 98.46%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.54%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 8
#         data_delta: 0
#       energy: 3.63688
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 8
#           data_delta: 0
#         energy: 3.13688
#         action_share: 1
#         interpreted_energy: 3.13688
#         percentage: 86.25%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 13.75%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 8
#         data_delta: 1
#       energy: 32.82637
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 8
#           data_delta: 1
#         energy: 32.32637
#         action_share: 1
#         interpreted_energy: 32.32637
#         percentage: 98.48%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.52%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 9
#         data_delta: 0
#       energy: 4.02781
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 9
#           data_delta: 0
#         energy: 3.52781
#         action_share: 1
#         interpreted_energy: 3.52781
#         percentage: 87.59%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 12.41%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 9
#         data_delta: 1
#       energy: 33.2173
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 9
#           data_delta: 1
#         energy: 32.7173
#         action_share: 1
#         interpreted_energy: 32.7173
#         percentage: 98.49%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.51%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 10
#         data_delta: 0
#       energy: 4.41874
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 10
#           data_delta: 0
#         energy: 3.91874
#         action_share: 1
#         interpreted_energy: 3.91874
#         percentage: 88.68%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 11.32%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 10
#         data_delta: 1
#       energy: 33.60823
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 10
#           data_delta: 1
#         energy: 33.10823
#         action_share: 1
#         interpreted_energy: 33.10823
#         percentage: 98.51%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.49%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 11
#         data_delta: 0
#       energy: 4.80967
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 11
#           data_delta: 0
#         energy: 4.30967
#         action_share: 1
#         interpreted_energy: 4.30967
#         percentage: 89.6%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 10.4%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 11
#         data_delta: 1
#       energy: 33.99916
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 11
#           data_delta: 1
#         energy: 33.49916
#         action_share: 1
#         interpreted_energy: 33.49916
#         percentage: 98.53%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.47%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 12
#         data_delta: 0
#       energy: 5.2006
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 12
#           data_delta: 0
#         energy: 4.7006
#         action_share: 1
#         interpreted_energy: 4.7006
#         percentage: 90.39%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 9.61%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 12
#         data_delta: 1
#       energy: 34.39009
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 12
#           data_delta: 1
#         energy: 33.89009
#         action_share: 1
#         interpreted_energy: 33.89009
#         percentage: 98.55%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.45%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 13
#         data_delta: 0
#       energy: 5.59153
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 13
#           data_delta: 0
#         energy: 5.09153
#         action_share: 1
#         interpreted_energy: 5.09153
#         percentage: 91.06%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 8.94%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 13
#         data_delta: 1
#       energy: 34.78102
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 13
#           data_delta: 1
#         energy: 34.28102
#         action_share: 1
#         interpreted_energy: 34.28102
#         percentage: 98.56%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.44%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 14
#         data_delta: 0
#       energy: 5.98246
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 14
#           data_delta: 0
#         energy: 5.48246
#         action_share: 1
#         interpreted_energy: 5.48246
#         percentage: 91.64%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 8.36%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 14
#         data_delta: 1
#       energy: 35.17195
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 14
#           data_delta: 1
#         energy: 34.67195
#         action_share: 1
#         interpreted_energy: 34.67195
#         percentage: 98.58%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.42%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 15
#         data_delta: 0
#       energy: 6.37339
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 15
#           data_delta: 0
#         energy: 5.87339
#         action_share: 1
#         interpreted_energy: 5.87339
#         percentage: 92.15%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 7.85%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 15
#         data_delta: 1
#       energy: 35.56288
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 15
#           data_delta: 1
#         energy: 35.06288
#         action_share: 1
#         interpreted_energy: 35.06288
#         percentage: 98.59%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.41%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 16
#         data_delta: 0
#       energy: 6.76432
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 16
#           data_delta: 0
#         energy: 6.26432
#         action_share: 1
#         interpreted_energy: 6.26432
#         percentage: 92.61%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 7.39%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 16
#         data_delta: 1
#       energy: 35.95381
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 16
#           data_delta: 1
#         energy: 35.45381
#         action_share: 1
#         interpreted_energy: 35.45381
#         percentage: 98.61%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.39%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 17
#         data_delta: 0
#       energy: 7.15525
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 17
#           data_delta: 0
#         energy: 6.65525
#         action_share: 1
#         interpreted_energy: 6.65525
#         percentage: 93.01%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 6.99%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 17
#         data_delta: 1
#       energy: 36.34474
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 17
#           data_delta: 1
#         energy: 35.84474
#         action_share: 1
#         interpreted_energy: 35.84474
#         percentage: 98.62%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.38%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 18
#         data_delta: 0
#       energy: 7.54619
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 18
#           data_delta: 0
#         energy: 7.04619
#         action_share: 1
#         interpreted_energy: 7.04619
#         percentage: 93.37%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 6.63%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 18
#         data_delta: 1
#       energy: 36.73567
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 18
#           data_delta: 1
#         energy: 36.23567
#         action_share: 1
#         interpreted_energy: 36.23567
#         percentage: 98.64%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.36%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 19
#         data_delta: 0
#       energy: 7.93712
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 19
#           data_delta: 0
#         energy: 7.43712
#         action_share: 1
#         interpreted_energy: 7.43712
#         percentage: 93.7%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 6.3%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 19
#         data_delta: 1
#       energy: 37.1266
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 19
#           data_delta: 1
#         energy: 36.6266
#         action_share: 1
#         interpreted_energy: 36.6266
#         percentage: 98.65%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.35%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 20
#         data_delta: 0
#       energy: 8.32805
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 20
#           data_delta: 0
#         energy: 7.82805
#         action_share: 1
#         interpreted_energy: 7.82805
#         percentage: 94.0%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 6.0%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 20
#         data_delta: 1
#       energy: 37.51753
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 20
#           data_delta: 1
#         energy: 37.01753
#         action_share: 1
#         interpreted_energy: 37.01753
#         percentage: 98.67%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.33%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 21
#         data_delta: 0
#       energy: 8.71898
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 21
#           data_delta: 0
#         energy: 8.21898
#         action_share: 1
#         interpreted_energy: 8.21898
#         percentage: 94.27%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 5.73%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 21
#         data_delta: 1
#       energy: 37.90846
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 21
#           data_delta: 1
#         energy: 37.40846
#         action_share: 1
#         interpreted_energy: 37.40846
#         percentage: 98.68%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.32%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 22
#         data_delta: 0
#       energy: 9.10991
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 22
#           data_delta: 0
#         energy: 8.60991
#         action_share: 1
#         interpreted_energy: 8.60991
#         percentage: 94.51%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 5.49%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 22
#         data_delta: 1
#       energy: 38.29939
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 22
#           data_delta: 1
#         energy: 37.79939
#         action_share: 1
#         interpreted_energy: 37.79939
#         percentage: 98.69%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.31%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 23
#         data_delta: 0
#       energy: 9.50084
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 23
#           data_delta: 0
#         energy: 9.00084
#         action_share: 1
#         interpreted_energy: 9.00084
#         percentage: 94.74%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 5.26%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 23
#         data_delta: 1
#       energy: 38.69032
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 23
#           data_delta: 1
#         energy: 38.19032
#         action_share: 1
#         interpreted_energy: 38.19032
#         percentage: 98.71%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.29%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 24
#         data_delta: 0
#       energy: 9.89177
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 24
#           data_delta: 0
#         energy: 9.39177
#         action_share: 1
#         interpreted_energy: 9.39177
#         percentage: 94.95%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 5.05%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 24
#         data_delta: 1
#       energy: 39.08126
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 24
#           data_delta: 1
#         energy: 38.58126
#         action_share: 1
#         interpreted_energy: 38.58126
#         percentage: 98.72%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 1.28%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 25
#         data_delta: 0
#       energy: 10.2827
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 25
#           data_delta: 0
#         energy: 9.7827
#         action_share: 1
#         interpreted_energy: 9.7827
#         percentage: 95.14%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.5
#         action_share: 1
#         interpreted_energy: 0.5
#         percentage: 4.86%
#         estimator: table-based-plug-ins
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.0
#         action_share: 1
#         interpreted_energy: 0.0
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#     - action_name: write
#       arguments:
#         address_delta: 25
#         data_delta: 1
#       energy: 39.47219
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 25
#           data_delta: 1
#         energy: 38.97219
#         action_share: 1
#         interpreted_energy: 38.97219
#         percentage: 98.73%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
# ...
#         num_destinations: 92
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 93
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 94
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 95
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 96
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 97
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 98
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 99
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 100
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 101
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 102
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 103
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 104
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 105
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 106
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 107
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 108
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 109
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 110
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 111
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 112
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 113
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 114
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 115
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 116
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 117
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 118
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 119
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 120
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 121
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 122
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 123
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 124
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 125
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 126
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 127
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#     - action_name: transfer_Inputs
#       arguments:
#         num_destinations: 128
#       energy: 0.4224
#       subaction_estimations:
#       - subcomponent_name: D2A_converter.DAC[0..7]
#         subaction_name: convert
#         arguments: null
#         energy: 0.0033
#         action_share: 16
#         interpreted_energy: 0.4224
#         percentage: 100.0%
#         estimator: table-based-plug-ins
#   - name: system_arch.chip.A2D_NoC
#     actions:
#     - name: transfer_Outputs
#       energy: 223.20768
#     primitive_estimation(s):
#     - action_name: transfer_Outputs
#       arguments:
#         num_destinations: 1
#       energy: 223.20768
#       subaction_estimations:
#       - subcomponent_name: A2D_converter.SH[0..7]
#         subaction_name: sample_and_hold
#         arguments: null
#         energy: 1.0e-05
#         action_share: 16
#         interpreted_energy: 0.00128
#         percentage: 0.0%
#         estimator: table-based-plug-ins
#       - subcomponent_name: A2D_converter.ADC
#         subaction_name: convert
#         arguments: null
#         energy: 1.66
#         action_share: 128
#         interpreted_energy: 212.48
#         percentage: 95.19%
#         estimator: table-based-plug-ins
#       - subcomponent_name: digital_accumulator.S_A
#         subaction_name: shift_and_add
#         arguments: null
#         energy: 0.0418
#         action_share: 128
#         interpreted_energy: 5.3504
#         percentage: 2.4%
#         estimator: table-based-plug-ins
#       - subcomponent_name: digital_accumulator.outputBuffer
#         subaction_name: read
#         arguments:
#           address_delta: 1
#           data_delta: 1
#         energy: 0.192
#         action_share: 14
#         interpreted_energy: 2.688
#         percentage: 1.2%
#         estimator: table-based-plug-ins
#       - subcomponent_name: digital_accumulator.outputBuffer
#         subaction_name: write
#         arguments:
#           address_delta: 1
#           data_delta: 1
#         energy: 0.192
#         action_share: 14
#         interpreted_energy: 2.688
#         percentage: 1.2%
#         estimator: table-based-plug-ins

# %%
vgg_layers = [
    ConfigRegistry.VGG01_LAYER1,
    ConfigRegistry.VGG01_LAYER2,
    ConfigRegistry.VGG01_LAYER3,
    ConfigRegistry.VGG01_LAYER4,
    ConfigRegistry.VGG01_LAYER5,
    ConfigRegistry.VGG01_LAYER6,
    ConfigRegistry.VGG01_LAYER7,
    ConfigRegistry.VGG01_LAYER8,
]

# %%
vgg_pim_layerwise_results = []

for i, layer in enumerate(vgg_layers):
    pim_results = run_timeloop_mapper(
        ConfigRegistry.PIM_ARCH,
        ConfigRegistry.PIM_COMPONENTS_DIR,
        pim_accelergy_result.art,
        pim_accelergy_result.ert,
        ConfigRegistry.PIM_CONSTRAINTS,
        ConfigRegistry.PIM_MAPPER,
        layer,
    )
    print(f"Layer: {i+1}")
    pim_results_stats, pim_results_loops = pim_results
    print(pim_results_loops)
    print(pim_results_stats)
    vgg_pim_layerwise_results.append(pim_results)
# Out:
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Found Accelergy ERT (energy reference table), replacing internal energy model.
# Found Accelergy ART (area reference table), replacing internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 2
#   Factorization options along problem dimension M = 7
#   Factorization options along problem dimension R = 2
#   Factorization options along problem dimension S = 2
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension P = 224
#   Factorization options along problem dimension Q = 224
# Mapspace Dimension [IndexFactorization] Size: 2809856
# Mapspace Dimension [LoopPermutation] Size: 152409600
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 351232 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# WARNING: no optimization metric(s) specified, using edp as default.
# [  0] Utilization = 0.00 | pJ/Compute =   92.050 | L3[IO] Q4 P56 - L2[IO] P2 S3 R3 M32 - L1[] Q28 P2 M2Y C3X - L0[W] Q2
# [  4] Utilization = 0.00 | pJ/Compute =   89.338 | L3[IO] Q4 P56 - L2[IO] P2 S3 R3 M16 - L1[] Q28 P2 M4Y C3X - L0[W] Q2
# [  6] Utilization = 0.00 | pJ/Compute =   87.982 | L3[IO] Q4 P56 - L2[IO] P2 S3 R3 M8 - L1[] Q28 P2 M8Y C3X - L0[W] Q2
# [  2] Utilization = 0.00 | pJ/Compute =   87.304 | L3[IO] Q4 P56 - L2[IO] P2 S3 R3 M4 - L1[] Q28 P2 M16Y C3X - L0[W] Q2
# [  5] Utilization = 0.00 | pJ/Compute =  252.128 | L3[IO] Q4 P56 - L2[IO] P2 S3 R3 M16 C3 - L1[] Q28 P2 M4Y - L0[W] Q2
# [  7] Utilization = 0.00 | pJ/Compute =  250.772 | L3[IO] Q4 P56 - L2[IO] P2 S3 R3 M8 C3 - L1[] Q28 P2 M8Y - L0[W] Q2
# [  1] Utilization = 0.00 | pJ/Compute =  254.840 | L3[IO] Q4 P56 - L2[IO] P2 S3 R3 M32 C3 - L1[] Q28 P2 M2Y - L0[W] Q2
# [  3] Utilization = 0.00 | pJ/Compute =  250.094 | L3[IO] Q4 P56 - L2[IO] P2 S3 R3 M4 C3 - L1[] Q28 P2 M16Y - L0[W] Q2
# [  0] Utilization = 0.00 | pJ/Compute =   33.714 | L3[IO] Q2 P28 - L2[IO] Q4 P4 S3 M8 - L1[] Q4 P2 M8Y C3X R3X - L0[W] Q7
# [  6] Utilization = 0.00 | pJ/Compute =   86.961 | L3[IO] Q2 P28 - L2[IO] Q4 P4 S3 R3 M2 - L1[] Q4 P2 M32Y C3X - L0[W] Q7
# [  2] Utilization = 0.00 | pJ/Compute =   86.791 | L3[IO] Q2 P28 - L2[IO] Q4 P4 S3 R3 - L1[] Q4 P2 M64Y C3X - L0[W] Q7
# [  0] Utilization = 0.01 | pJ/Compute =   14.953 | L3[IO] Q4 P14 - L2[IO] Q7 P4 M4 - L1[] Q1 M16Y C3X S3X R3X - L0[W] Q8 P4
# [  2] Utilization = 0.01 | pJ/Compute =   32.708 | L3[IO] Q7 P8 - L2[IO] P14 R3 M2 - L1[] Q16 M32Y C3X S3X - L0[W] Q2 P2
# [  2] Utilization = 0.00 | pJ/Compute =   16.987 | L3[IO] Q4 P14 - L2[IO] Q7 P4 M16 - L1[] Q1 M4Y C3X S3X R3X - L0[W] Q8 P4
# [  0] Utilization = 0.01 | pJ/Compute =   14.451 | L3[IO] Q7 P28 - L2[IO] Q4 P4 - L1[] Q4 M64Y C3X S3X R3X - L0[W] Q2 P2
# [  4] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  0] Utilization = 0.01 | pJ/Compute =   14.444 | L3[IO] Q4 P56 - L2[IO] P2 - L1[] P2 Q56 M64Y C3X S3X R3X - L0[W] Q1
# [  2] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  5] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  1] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  3] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  7] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  0] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  6] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# ===============================================
#                BEGIN DIAGNOSTICS
# -----------------------------------------------
# Fail class: Capacity
#
#   Level: shared_glb
#     Fail count: 195
#     Sample mapping that experienced this fail class:
#
#       DRAM [ Inputs:153228 (153228) Outputs:3211264 (3211264) ]
#       ---------------------------------------------------------
#       | for P in [0:7)
#
#       shared_glb [ Inputs:23052 (23052) Outputs:458752 (458752) ]
#       -----------------------------------------------------------
#       |   for P in [0:4)
#       |     for M in [0:4)
#
#       dummy_buffer [ ]
#       ----------------
#       |       for Q in [0:224)
#       |         for P in [0:8)
#       |           for M in [0:16) (Spatial-Y)
#       |             for C in [0:3) (Spatial-X)
#       |               for S in [0:3) (Spatial-X)
#       |                 for R in [0:3) (Spatial-X)
#
#       scratchpad [ Weights:1 (1) ]
#       ----------------------------
#       |                   for Q in [0:1)
#
#     Fail reason: mapped tile size 481804 exceeds buffer capacity 65536
#
# -----------------------------------------------
#                  END DIAGNOSTICS
# ===============================================
#
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.01 | pJ/Compute =   14.444
# Layer: 1
#
# DRAM [ Inputs:153228 (153228) Outputs:3211264 (3211264) ]
# ---------------------------------------------------------
# | for Q in [0:4)
# |   for P in [0:56)
#
# shared_glb [ Inputs:1044 (1044) Outputs:14336 (14336) ]
# -------------------------------------------------------
# |     for P in [0:2)
#
# dummy_buffer [ ]
# ----------------
# |       for P in [0:2)
# |         for Q in [0:56)
# |           for M in [0:64) (Spatial-Y)
# |             for C in [0:3) (Spatial-X)
# |               for S in [0:3) (Spatial-X)
# |                 for R in [0:3) (Spatial-X)
#
# scratchpad [ Weights:1 (1) ]
# ----------------------------
# |                   for Q in [0:1)
#
#
# Buffer and Arithmetic Levels
# ----------------------------
# Level 0
# -------
# === mac ===
#
#     SPECS
#     -----
#     Word bits             : 16
#     Instances             : 16384 (128*128)
#     Compute energy        : 0.23 pJ
#
#     STATS
#     -----
#     Utilized instances      : 1728
#     Computes (total)        : 86704128
#     Cycles                  : 50176
#     Energy (total)          : 20309574.94 pJ
#     Area (total)            : 200.54 um^2
#
# Level 1
# -------
# === scratchpad ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 1
#         Word bits                   : 16
#         Block size                  : 1
#         Cluster size                : 1
#         Instances                   : 16384 (128*128)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
#         Effective size              : 1
#         Min utilization             : 0.00
#         Vector access energy        : 0.00 pJ
#         Vector access energy source : ERT
#         Area                        : 0.00 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#
#     STATS
#     -----
#     Cycles               : 50176
#     Bandwidth throttling : 1.00
#     Weights:
#         Partition size                           : 1
#         Utilized capacity                        : 1
#         Utilized instances (max)                 : 1728
#         Utilized clusters (max)                  : 1728
#         Scalar reads (per-instance)              : 50176
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 50176
#         Energy (per-scalar-access)               : 0.00 pJ
#         Energy (per-instance)                    : 0.00 pJ
#         Energy (total)                           : 0.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 1.00 words/cycle
#         Shared Bandwidth (total)                 : 1728.00 words/cycle
#         Read Bandwidth (per-instance)            : 1.00 words/cycle
#         Read Bandwidth (total)                   : 1728.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.00 words/cycle
#
# Level 2
# -------
# === dummy_buffer ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 0
#         Word bits                   : 16
#         Block size                  : 1
#         Cluster size                : 1
#         Instances                   : 1 (1*1)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
#         Effective size              : 0
#         Min utilization             : 0.00
#         Vector access energy        : 0.00 pJ
#         Vector access energy source : ERT
#         Area                        : 0.00 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#
#     STATS
#     -----
#     Cycles               : 50176
#     Bandwidth throttling : 1.00
#
# Level 3
# -------
# === shared_glb ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 65536
#         Word bits                   : 16
#         Block size                  : 4
#         Cluster size                : 1
#         Instances                   : 1 (1*1)
#         Shared bandwidth            : -
#         Read bandwidth              : 16.00
#         Write bandwidth             : 16.00
#         Multiple buffering          : 1.00
#         Effective size              : 65536
#         Min utilization             : 0.00
#         Vector access energy        : 42.21 pJ
#         Vector access energy source : ERT
#         Area                        : 590948.00 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#
#     STATS
#     -----
#     Cycles               : 411239
#     Bandwidth throttling : 0.12
#     Inputs:
#         Partition size                           : 153228
#         Utilized capacity                        : 1044
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 1354752
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 157296
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 1512048
#         Energy (per-scalar-access)               : 10.44 pJ
#         Energy (per-instance)                    : 15783815.76 pJ
#         Energy (total)                           : 15783815.76 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 3.68 words/cycle
#         Shared Bandwidth (total)                 : 3.68 words/cycle
#         Read Bandwidth (per-instance)            : 3.29 words/cycle
#         Read Bandwidth (total)                   : 3.29 words/cycle
#         Write Bandwidth (per-instance)           : 0.38 words/cycle
#         Write Bandwidth (total)                  : 0.38 words/cycle
#     Outputs:
#         Partition size                           : 3211264
#         Utilized capacity                        : 14336
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 0
#         Scalar updates (per-instance)            : 3211264
#         Scalar fills (per-instance)              : 3211264
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 6422528
#         Energy (per-scalar-access)               : 10.55 pJ
#         Energy (per-instance)                    : 67771639.40 pJ
#         Energy (total)                           : 67771639.40 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 15.62 words/cycle
#         Shared Bandwidth (total)                 : 15.62 words/cycle
#         Read Bandwidth (per-instance)            : 0.00 words/cycle
#         Read Bandwidth (total)                   : 0.00 words/cycle
#         Write Bandwidth (per-instance)           : 15.62 words/cycle
#         Write Bandwidth (total)                  : 15.62 words/cycle
#
# Level 4
# -------
# === DRAM ===
#
#     SPECS
#     -----
#         Technology                  : DRAM
#         Size                        : -
#         Word bits                   : 16
#         Block size                  : 4
#         Cluster size                : 1
#         Instances                   : 1 (1*1)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
#         Effective size              : -
#         Min utilization             : 0.00
#         Vector access energy        : 512.00 pJ
#         Vector access energy source : ERT
#         Area                        : 0.00 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#
#     STATS
#     -----
#     Cycles               : 50176
#     Bandwidth throttling : 1.00
#     Inputs:
#         Partition size                           : 153228
#         Utilized capacity                        : 153228
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 157296
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 157296
#         Energy (per-scalar-access)               : 128.00 pJ
#         Energy (per-instance)                    : 20133888.00 pJ
#         Energy (total)                           : 20133888.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 3.13 words/cycle
#         Shared Bandwidth (total)                 : 3.13 words/cycle
#         Read Bandwidth (per-instance)            : 3.13 words/cycle
#         Read Bandwidth (total)                   : 3.13 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.00 words/cycle
#     Outputs:
#         Partition size                           : 3211264
#         Utilized capacity                        : 3211264
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 0
#         Scalar updates (per-instance)            : 3211264
#         Scalar fills (per-instance)              : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 3211264
#         Energy (per-scalar-access)               : 128.00 pJ
#         Energy (per-instance)                    : 411041792.00 pJ
#         Energy (total)                           : 411041792.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 64.00 words/cycle
#         Shared Bandwidth (total)                 : 64.00 words/cycle
#         Read Bandwidth (per-instance)            : 0.00 words/cycle
#         Read Bandwidth (total)                   : 0.00 words/cycle
#         Write Bandwidth (per-instance)           : 64.00 words/cycle
#         Write Bandwidth (total)                  : 64.00 words/cycle
#
# Networks
# --------
# Network 0
# ---------
# A2D_NoC
#
#     SPECS
#     -----
#         Type            : SimpleMulticast
#         ConnectionType  : 2
#         Word bits       : 16
#         Action Name       : transfer
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 0
#         Multicast factor                        : 0
#         Ingresses                               : 0.00
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#     Inputs:
#         Fanout                                  : 1
#         Multicast factor                        : 1
#         Ingresses                               : 1354752.00
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Multicast factor                        : 1
#         Ingresses                               : 3211264.00
#         Energy (per-instance)                   : 716778787.31 pJ
#         Energy (total)                          : 716778787.31 pJ
#
# Network 1
# ---------
# D2A_NoC
#
#     SPECS
#     -----
#         Type            : SimpleMulticast
#         ConnectionType  : 1
#         Word bits       : 16
#         Action Name       : transfer
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 0
#         Multicast factor                        : 0
#         Ingresses                               : 0.00
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#     Inputs:
#         Fanout                                  : 1
#         Multicast factor                        : 1
#         Ingresses                               : 1354752.00
#         Energy (per-instance)                   : 572247.24 pJ
#         Energy (total)                          : 572247.24 pJ
#     Outputs:
#         Fanout                                  : 1
#         Multicast factor                        : 1
#         Ingresses                               : 3211264.00
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#
# Network 2
# ---------
# DRAM <==> shared_glb
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 0
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 0
#         Ingresses                               : 0.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.00
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Inputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 157296.00
#             @multicast 1 @scatter 1: 157296.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 3211264.00
#             @multicast 1 @scatter 1: 3211264.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
# Network 3
# ---------
# dummy_buffer <==> scratchpad
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 0
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 0
#         Ingresses                               : 0.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.00
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Inputs:
#         Fanout                                  : 1728
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 64
#         Ingresses                               : 1354752.00
#             @multicast 64 @scatter 27: 1354752.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 344.64
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1728
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 27
#         Ingresses                               : 3211264.00
#             @multicast 27 @scatter 64: 3211264.00
#         Link transfers                          : 0
#         Spatial reductions                      : 83492864
#         Average number of hops                  : 226.69
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
# Network 4
# ---------
# scratchpad <==> mac
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 50176.00
#             @multicast 1 @scatter 1: 50176.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Inputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 50176.00
#             @multicast 1 @scatter 1: 50176.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 50176.00
#             @multicast 1 @scatter 1: 50176.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
#
# Operational Intensity Stats
# ---------------------------
#     Total elementwise ops                   : 86704128
#     Total reduction ops                     : 83492864
#     Total ops                               : 170196992
#     Total memory accesses required          : 3364493
#     Optimal Op per Byte                     : 25.29
#
# === scratchpad ===
#     Total scalar accesses                   : 86704128
#     Op per Byte                             : 0.98
# === dummy_buffer ===
# === shared_glb ===
#     Total scalar accesses                   : 7934576
#     Op per Byte                             : 10.73
# === DRAM ===
#     Total scalar accesses                   : 3368560
#     Op per Byte                             : 25.26
#
#
# Summary Stats
# -------------
# GFLOPs (@1GHz): 413.86
# Utilization: 0.01
# Cycles: 411239
# Energy: 1252.39 uJ
# EDP(J*cycle): 5.15e+02
# Area: 0.00 mm^2
#
# Computes = 86704128
# pJ/Compute
#     mac                          = 0.23
#     scratchpad                   = 0.00
#     dummy_buffer                 = 0.00
#     shared_glb                   = 0.96
#     DRAM                         = 4.97
#     A2D_NoC                      = 8.27
#     D2A_NoC                      = 0.01
#     DRAM <==> shared_glb         = 0.00
#     dummy_buffer <==> scratchpad = 0.00
#     scratchpad <==> mac          = 0.00
#     Total                        = 14.44
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Found Accelergy ERT (energy reference table), replacing internal energy model.
# Found Accelergy ART (area reference table), replacing internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 7
#   Factorization options along problem dimension M = 8
#   Factorization options along problem dimension R = 2
#   Factorization options along problem dimension S = 2
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension P = 140
#   Factorization options along problem dimension Q = 140
# Mapspace Dimension [IndexFactorization] Size: 4390400
# Mapspace Dimension [LoopPermutation] Size: 152409600
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 548800 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# WARNING: no optimization metric(s) specified, using edp as default.
# [  0] Utilization = 0.00 | pJ/Compute =   38.574 | L3[IO] Q7 P7 - L2[IO] P2 M128 C64 - L1[] Q4 P4 S3X R3X - L0[W] Q4 P2
# [  4] Utilization = 0.00 | pJ/Compute =   18.225 | L3[IO] Q7 P7 - L2[IO] P2 M128 C16 - L1[] Q4 P4 C4X S3X R3X - L0[W] Q4 P2
# [  5] Utilization = 0.00 | pJ/Compute =   14.834 | L3[IO] Q7 P7 - L2[IO] P2 M128 C8 - L1[] Q4 P4 C8X S3X R3X - L0[W] Q4 P2
# [  6] Utilization = 0.01 | pJ/Compute =    8.749 | L3[IO] Q14 P16 - L2[IO] P7 M16 C16 - L1[] Q1 M8Y C4X S3X R3X - L0[W] Q8
# [  2] Utilization = 0.00 | pJ/Compute =   25.008 | L3[IO] Q7 P7 - L2[IO] P2 M128 C32 - L1[] Q4 P4 C2X S3X R3X - L0[W] Q4 P2
# [  3] Utilization = 0.00 | pJ/Compute =   82.657 | L3[IO] Q2 P28 - L2[IO] Q8 P2 S3 M8 C64 - L1[] Q7 M16Y R3X - L0[W] P2
# [  1] Utilization = 0.00 | pJ/Compute =   13.470 | L3[IO] Q2 P28 - L2[IO] Q8 P2 S3 M32 C8 - L1[] Q7 M4Y C8X R3X - L0[W] P2
# [  7] Utilization = 0.01 | pJ/Compute =   27.896 | L3[IO] Q7 P7 - L2[IO] P2 M2 C64 - L1[] Q4 P4 M64Y S3X R3X - L0[W] Q4 P2
# [  4] Utilization = 0.01 | pJ/Compute =   15.532 | L3[IO] Q14 P16 - L2[IO] P7 M16 C32 - L1[] Q1 M8Y C2X S3X R3X - L0[W] Q8
# [  0] Utilization = 0.01 | pJ/Compute =    4.679 | L3[IO] Q14 P16 - L2[IO] P7 M8 C8 - L1[] Q1 M16Y C8X S3X R3X - L0[W] Q8
# [  5] Utilization = 0.00 | pJ/Compute =   41.959 | L3[IO] Q2 P28 - L2[IO] Q8 P2 S3 M8 C32 - L1[] Q7 M16Y C2X R3X - L0[W] P2
# [  2] Utilization = 0.00 | pJ/Compute =   29.097 | L3[IO] Q14 P16 - L2[IO] P7 M16 C64 - L1[] Q1 M8Y S3X R3X - L0[W] Q8
# [  6] Utilization = 0.01 | pJ/Compute =    6.349 | L3[IO] Q2 P28 - L2[IO] Q8 P2 S3 M8 C4 - L1[] Q7 M16Y C16X R3X - L0[W] P2
# [  7] Utilization = 0.01 | pJ/Compute =    5.357 | L3[IO] Q14 P16 - L2[IO] P7 M16 C8 - L1[] Q1 M8Y C8X S3X R3X - L0[W] Q8
# [  4] Utilization = 0.01 | pJ/Compute =    3.805 | L3[IO] Q2 P28 - L2[IO] Q8 P2 S3 M8 C2 - L1[] Q7 M16Y C32X R3X - L0[W] P2
# [  3] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  0] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  1] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  5] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  7] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  2] Utilization = 0.06 | pJ/Compute =    3.223 | L3[IO] Q7 P28 - L2[IO] R3 C2 - L1[] Q16 P4 M128Y C32X S3X - L0[W] Q1
# [  6] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  2] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  4] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# ===============================================
#                BEGIN DIAGNOSTICS
# -----------------------------------------------
# Fail class: Fanout
#
#   Level: dummy_buffer
#     Fail count: 3258
#     Sample mapping that experienced this fail class:
#
#       DRAM [ Inputs:831744 (831744) Outputs:1605632 (1605632) ]
#       ---------------------------------------------------------
#       | for P in [0:2)
#
#       shared_glb [ Inputs:423168 (423168) Outputs:802816 (802816) ]
#       -------------------------------------------------------------
#       |   for M in [0:4)
#       |     for C in [0:4)
#       |       for P in [0:2)
#       |         for Q in [0:2)
#
#       dummy_buffer [ ]
#       ----------------
#       |           for P in [0:7)
#       |             for Q in [0:14)
#       |               for M in [0:32) (Spatial-Y)
#       |                 for C in [0:16) (Spatial-X)
#       |                   for S in [0:3) (Spatial-X)
#       |                     for R in [0:3) (Spatial-X)
#
#       scratchpad [ Weights:1 (1) ]
#       ----------------------------
#       |                       for Q in [0:4)
#       |                         for P in [0:4)
#
#     Fail reason: mapped fanoutX 144 exceeds hardware fanoutX 128
#
# Fail class: Capacity
#
#   Level: shared_glb
#     Fail count: 99
#     Sample mapping that experienced this fail class:
#
#       DRAM [ Inputs:831744 (831744) Outputs:1605632 (1605632) ]
#       ---------------------------------------------------------
#       | for Q in [0:7)
#       |   for P in [0:2)
#
#       shared_glb [ Inputs:66816 (66816) Outputs:114688 (114688) ]
#       -----------------------------------------------------------
#       |     for Q in [0:8)
#       |       for M in [0:64)
#       |         for C in [0:32)
#
#       dummy_buffer [ ]
#       ----------------
#       |           for P in [0:2)
#       |             for M in [0:2) (Spatial-Y)
#       |               for C in [0:2) (Spatial-X)
#       |                 for S in [0:3) (Spatial-X)
#       |                   for R in [0:3) (Spatial-X)
#
#       scratchpad [ Weights:1 (1) ]
#       ----------------------------
#       |                     for Q in [0:2)
#       |                       for P in [0:28)
#
#     Fail reason: mapped tile size 181504 exceeds buffer capacity 65536
#
# -----------------------------------------------
#                  END DIAGNOSTICS
# ===============================================
#
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.06 | pJ/Compute =    3.223
# Layer: 2
#
# DRAM [ Inputs:831744 (831744) Outputs:1605632 (1605632) ]
# ---------------------------------------------------------
# | for Q in [0:7)
# |   for P in [0:28)
#
# shared_glb [ Inputs:6912 (6912) Outputs:8192 (8192) ]
# -----------------------------------------------------
# |     for R in [0:3)
# |       for C in [0:2)
#
# dummy_buffer [ ]
# ----------------
# |         for Q in [0:16)
# |           for P in [0:4)
# |             for M in [0:128) (Spatial-Y)
# |               for C in [0:32) (Spatial-X)
# |                 for S in [0:3) (Spatial-X)
#
# scratchpad [ Weights:1 (1) ]
# ----------------------------
# |                   for Q in [0:1)
#
#
# Buffer and Arithmetic Levels
# ----------------------------
# Level 0
# -------
# === mac ===
#
#     SPECS
#     -----
#     Word bits             : 16
#     Instances             : 16384 (128*128)
#     Compute energy        : 0.23 pJ
#
#     STATS
#     -----
#     Utilized instances      : 12288
#     Computes (total)        : 924844032
#     Cycles                  : 75264
#     Energy (total)          : 216635466.06 pJ
#     Area (total)            : 200.54 um^2
#
# Level 1
# -------
# === scratchpad ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 1
#         Word bits                   : 16
#         Block size                  : 1
#         Cluster size                : 1
#         Instances                   : 16384 (128*128)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
#         Effective size              : 1
#         Min utilization             : 0.00
#         Vector access energy        : 0.00 pJ
#         Vector access energy source : ERT
#         Area                        : 0.00 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#
#     STATS
#     -----
#     Cycles               : 75264
#     Bandwidth throttling : 1.00
#     Weights:
#         Partition size                           : 6
#         Utilized capacity                        : 1
#         Utilized instances (max)                 : 12288
#         Utilized clusters (max)                  : 12288
#         Scalar reads (per-instance)              : 75264
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 75264
#         Energy (per-scalar-access)               : 0.00 pJ
#         Energy (per-instance)                    : 0.00 pJ
#         Energy (total)                           : 0.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 1.00 words/cycle
#         Shared Bandwidth (total)                 : 12288.00 words/cycle
#         Read Bandwidth (per-instance)            : 1.00 words/cycle
#         Read Bandwidth (total)                   : 12288.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.00 words/cycle
#
# Level 2
# -------
# === dummy_buffer ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 0
#         Word bits                   : 16
#         Block size                  : 1
#         Cluster size                : 1
#         Instances                   : 1 (1*1)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
#         Effective size              : 0
#         Min utilization             : 0.00
#         Vector access energy        : 0.00 pJ
#         Vector access energy source : ERT
#         Area                        : 0.00 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#
#     STATS
#     -----
#     Cycles               : 75264
#     Bandwidth throttling : 1.00
#
# Level 3
# -------
# === shared_glb ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 65536
#         Word bits                   : 16
#         Block size                  : 4
#         Cluster size                : 1
#         Instances                   : 1 (1*1)
#         Shared bandwidth            : -
#         Read bandwidth              : 16.00
#         Write bandwidth             : 16.00
#         Multiple buffering          : 1.00
#         Effective size              : 65536
#         Min utilization             : 0.00
#         Vector access energy        : 42.21 pJ
#         Vector access energy source : ERT
#         Area                        : 590948.00 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#
#     STATS
#     -----
#     Cycles               : 953344
#     Bandwidth throttling : 0.08
#     Inputs:
#         Partition size                           : 831744
#         Utilized capacity                        : 6912
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 7225344
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 919296
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 8144640
#         Energy (per-scalar-access)               : 10.44 pJ
#         Energy (per-instance)                    : 85028576.77 pJ
#         Energy (total)                           : 85028576.77 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 8.54 words/cycle
#         Shared Bandwidth (total)                 : 8.54 words/cycle
#         Read Bandwidth (per-instance)            : 7.58 words/cycle
#         Read Bandwidth (total)                   : 7.58 words/cycle
#         Write Bandwidth (per-instance)           : 0.96 words/cycle
#         Write Bandwidth (total)                  : 0.96 words/cycle
#     Outputs:
#         Partition size                           : 1605632
#         Utilized capacity                        : 8192
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 8028160
#         Scalar updates (per-instance)            : 9633792
#         Scalar fills (per-instance)              : 1605632
#         Temporal reductions (per-instance)       : 8028160
#         Address generations (per-cluster)        : 11239424
#         Energy (per-scalar-access)               : 10.50 pJ
#         Energy (per-instance)                    : 202298151.73 pJ
#         Energy (total)                           : 202298151.73 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 20.21 words/cycle
#         Shared Bandwidth (total)                 : 20.21 words/cycle
#         Read Bandwidth (per-instance)            : 8.42 words/cycle
#         Read Bandwidth (total)                   : 8.42 words/cycle
#         Write Bandwidth (per-instance)           : 11.79 words/cycle
#         Write Bandwidth (total)                  : 11.79 words/cycle
#
# Level 4
# -------
# === DRAM ===
#
#     SPECS
#     -----
#         Technology                  : DRAM
#         Size                        : -
#         Word bits                   : 16
#         Block size                  : 4
#         Cluster size                : 1
#         Instances                   : 1 (1*1)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
#         Effective size              : -
#         Min utilization             : 0.00
#         Vector access energy        : 512.00 pJ
#         Vector access energy source : ERT
#         Area                        : 0.00 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#
#     STATS
#     -----
#     Cycles               : 75264
#     Bandwidth throttling : 1.00
#     Inputs:
#         Partition size                           : 831744
#         Utilized capacity                        : 831744
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 919296
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 919296
#         Energy (per-scalar-access)               : 128.00 pJ
#         Energy (per-instance)                    : 117669888.00 pJ
#         Energy (total)                           : 117669888.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 12.21 words/cycle
#         Shared Bandwidth (total)                 : 12.21 words/cycle
#         Read Bandwidth (per-instance)            : 12.21 words/cycle
#         Read Bandwidth (total)                   : 12.21 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.00 words/cycle
#     Outputs:
#         Partition size                           : 1605632
#         Utilized capacity                        : 1605632
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 0
#         Scalar updates (per-instance)            : 1605632
#         Scalar fills (per-instance)              : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 1605632
#         Energy (per-scalar-access)               : 128.00 pJ
#         Energy (per-instance)                    : 205520896.00 pJ
#         Energy (total)                           : 205520896.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 21.33 words/cycle
#         Shared Bandwidth (total)                 : 21.33 words/cycle
#         Read Bandwidth (per-instance)            : 0.00 words/cycle
#         Read Bandwidth (total)                   : 0.00 words/cycle
#         Write Bandwidth (per-instance)           : 21.33 words/cycle
#         Write Bandwidth (total)                  : 21.33 words/cycle
#
# Networks
# --------
# Network 0
# ---------
# A2D_NoC
#
#     SPECS
#     -----
#         Type            : SimpleMulticast
#         ConnectionType  : 2
#         Word bits       : 16
#         Action Name       : transfer
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 0
#         Multicast factor                        : 0
#         Ingresses                               : 0.00
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#     Inputs:
#         Fanout                                  : 1
#         Multicast factor                        : 1
#         Ingresses                               : 7225344.00
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Multicast factor                        : 1
#         Ingresses                               : 9633792.00
#         Energy (per-instance)                   : 2150336361.92 pJ
#         Energy (total)                          : 2150336361.92 pJ
#
# Network 1
# ---------
# D2A_NoC
#
#     SPECS
# ...
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#
# Network 2
# ---------
# DRAM <==> shared_glb
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 0
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 0
#         Ingresses                               : 0.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.00
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Inputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 919296.00
#             @multicast 1 @scatter 1: 919296.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 1605632.00
#             @multicast 1 @scatter 1: 1605632.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
# Network 3
# ---------
# dummy_buffer <==> scratchpad
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 0
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 0
#         Ingresses                               : 0.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.00
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Inputs:
#         Fanout                                  : 12288
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 128
#         Ingresses                               : 7225344.00
#             @multicast 128 @scatter 96: 7225344.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 1294.61
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 12288
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 96
#         Ingresses                               : 9633792.00
#             @multicast 96 @scatter 128: 9633792.00
#         Link transfers                          : 0
#         Spatial reductions                      : 915210240
#         Average number of hops                  : 1125.83
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
# Network 4
# ---------
# scratchpad <==> mac
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 75264.00
#             @multicast 1 @scatter 1: 75264.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Inputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 75264.00
#             @multicast 1 @scatter 1: 75264.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 75264.00
#             @multicast 1 @scatter 1: 75264.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
#
# Operational Intensity Stats
# ---------------------------
#     Total elementwise ops                   : 924844032
#     Total reduction ops                     : 923238400
#     Total ops                               : 1848082432
#     Total memory accesses required          : 2437377
#     Optimal Op per Byte                     : 379.11
#
# === scratchpad ===
#     Total scalar accesses                   : 924844032
#     Op per Byte                             : 1.00
# === dummy_buffer ===
# === shared_glb ===
#     Total scalar accesses                   : 27412224
#     Op per Byte                             : 33.71
# === DRAM ===
#     Total scalar accesses                   : 2524928
#     Op per Byte                             : 365.97
#
#
# Summary Stats
# -------------
# GFLOPs (@1GHz): 1938.53
# Utilization: 0.06
# Cycles: 953344
# Energy: 2980.54 uJ
# EDP(J*cycle): 2.84e+03
# Area: 0.00 mm^2
#
# Computes = 924844032
# pJ/Compute
#     mac                          = 0.23
#     scratchpad                   = 0.00
#     dummy_buffer                 = 0.00
#     shared_glb                   = 0.31
#     DRAM                         = 0.35
#     A2D_NoC                      = 2.33
#     D2A_NoC                      = 0.00
#     DRAM <==> shared_glb         = 0.00
#     dummy_buffer <==> scratchpad = 0.00
#     scratchpad <==> mac          = 0.00
#     Total                        = 3.22
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Found Accelergy ERT (energy reference table), replacing internal energy model.
# Found Accelergy ART (area reference table), replacing internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 8
#   Factorization options along problem dimension M = 9
#   Factorization options along problem dimension R = 2
#   Factorization options along problem dimension S = 2
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension P = 80
#   Factorization options along problem dimension Q = 80
# Mapspace Dimension [IndexFactorization] Size: 1843200
# Mapspace Dimension [LoopPermutation] Size: 152409600
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 230400 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# WARNING: no optimization metric(s) specified, using edp as default.
# [  1] Utilization = 0.00 | pJ/Compute =  245.954 | L3[IO] Q2 P28 - L2[IO] Q4 S3 R3 M32 C128 - L1[] Q1 M8Y - L0[W] Q7 P2
# [  7] Utilization = 0.00 | pJ/Compute =   32.291 | L3[IO] Q2 P28 - L2[IO] Q4 S3 R3 M32 C16 - L1[] Q1 M8Y C8X - L0[W] Q7 P2
# [  5] Utilization = 0.00 | pJ/Compute =   62.815 | L3[IO] Q2 P28 - L2[IO] Q4 S3 R3 M32 C32 - L1[] Q1 M8Y C4X - L0[W] Q7 P2
# [  3] Utilization = 0.00 | pJ/Compute =  123.861 | L3[IO] Q2 P28 - L2[IO] Q4 S3 R3 M32 C64 - L1[] Q1 M8Y C2X - L0[W] Q7 P2
# [  6] Utilization = 0.01 | pJ/Compute =   17.030 | L3[IO] Q2 P28 - L2[IO] Q4 S3 R3 M32 C8 - L1[] Q1 M8Y C16X - L0[W] Q7 P2
# [  4] Utilization = 0.01 | pJ/Compute =    9.399 | L3[IO] Q2 P28 - L2[IO] Q4 S3 R3 M32 C4 - L1[] Q1 M8Y C32X - L0[W] Q7 P2
# [  2] Utilization = 0.01 | pJ/Compute =    5.584 | L3[IO] Q2 P28 - L2[IO] Q4 S3 R3 M32 C2 - L1[] Q1 M8Y C64X - L0[W] Q7 P2
# [  0] Utilization = 0.01 | pJ/Compute =    3.676 | L3[IO] Q2 P28 - L2[IO] Q4 S3 R3 M32 - L1[] Q1 M8Y C128X - L0[W] Q7 P2
# [  1] Utilization = 0.00 | pJ/Compute =   83.174 | L3[IO] Q7 P14 - L2[IO] Q4 R3 M32 C128 - L1[] P2 M8Y S3X - L0[W] Q2 P2
# [  5] Utilization = 0.00 | pJ/Compute =   22.128 | L3[IO] Q7 P14 - L2[IO] Q4 R3 M32 C32 - L1[] P2 M8Y C4X S3X - L0[W] Q2 P2
# [  3] Utilization = 0.00 | pJ/Compute =   42.477 | L3[IO] Q7 P14 - L2[IO] Q4 R3 M32 C64 - L1[] P2 M8Y C2X S3X - L0[W] Q2 P2
# [  7] Utilization = 0.01 | pJ/Compute =   11.954 | L3[IO] Q7 P14 - L2[IO] Q4 R3 M32 C16 - L1[] P2 M8Y C8X S3X - L0[W] Q2 P2
# [  1] Utilization = 0.00 | pJ/Compute =   81.919 | L3[IO] Q14 P2 - L2[IO] Q4 P2 S3 M2 C128 - L1[] P2 M128Y R3X - L0[W] P7
# [  6] Utilization = 0.01 | pJ/Compute =    6.867 | L3[IO] Q7 P14 - L2[IO] Q4 R3 M32 C8 - L1[] P2 M8Y C16X S3X - L0[W] Q2 P2
# [  3] Utilization = 0.01 | pJ/Compute =   41.221 | L3[IO] Q14 P2 - L2[IO] Q4 P2 S3 M2 C64 - L1[] P2 M128Y C2X R3X - L0[W] P7
# [  5] Utilization = 0.01 | pJ/Compute =   20.872 | L3[IO] Q14 P2 - L2[IO] Q4 P2 S3 M2 C32 - L1[] P2 M128Y C4X R3X - L0[W] P7
# [  4] Utilization = 0.01 | pJ/Compute =    4.323 | L3[IO] Q7 P14 - L2[IO] Q4 R3 M32 C4 - L1[] P2 M8Y C32X S3X - L0[W] Q2 P2
# [  7] Utilization = 0.02 | pJ/Compute =   10.698 | L3[IO] Q14 P2 - L2[IO] Q4 P2 S3 M2 C16 - L1[] P2 M128Y C8X R3X - L0[W] P7
# [  0] Utilization = 0.01 | pJ/Compute =    3.011 | L3[IO] Q8 P7 - L2[IO] Q7 P8 S3 R3 M16 - L1[] Q1 M16Y C128X - L0[W] Q1
# [  2] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  1] Utilization = 0.00 | pJ/Compute =   81.892 | L3[IO] Q2 P56 - L2[IO] Q4 R3 M2 C128 - L1[] Q1 M128Y S3X - L0[W] Q7
# [  6] Utilization = 0.04 | pJ/Compute =    5.611 | L3[IO] Q14 P2 - L2[IO] Q4 P2 S3 M2 C8 - L1[] P2 M128Y C16X R3X - L0[W] P7
# [  1] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  3] Utilization = 0.01 | pJ/Compute =   41.195 | L3[IO] Q2 P56 - L2[IO] Q4 R3 M2 C64 - L1[] Q1 M128Y C2X S3X - L0[W] Q7
# [  3] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  5] Utilization = 0.01 | pJ/Compute =   20.846 | L3[IO] Q2 P56 - L2[IO] Q4 R3 M2 C32 - L1[] Q1 M128Y C4X S3X - L0[W] Q7
# [  5] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  4] Utilization = 0.06 | pJ/Compute =    3.067 | L3[IO] Q14 P2 - L2[IO] Q4 P2 S3 M2 C4 - L1[] P2 M128Y C32X R3X - L0[W] P7
# [  0] Utilization = 0.07 | pJ/Compute =    2.462 | L3[IO] Q28 P28 - L2[IO] S3 R3 M2 - L1[] Q2 M128Y C128X - L0[W] P2
# [  7] Utilization = 0.02 | pJ/Compute =   10.671 | L3[IO] Q2 P56 - L2[IO] Q4 R3 M2 C16 - L1[] Q1 M128Y C8X S3X - L0[W] Q7
# [  7] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  0] Utilization = 0.07 | pJ/Compute =    2.418 | L3[IO] Q8 P7 - L2[IO] Q7 P4 S3 R3 M2 - L1[] Q1 M128Y C128X - L0[W] P2
# [  6] Utilization = 0.04 | pJ/Compute =    5.584 | L3[IO] Q2 P56 - L2[IO] Q4 R3 M2 C8 - L1[] Q1 M128Y C16X S3X - L0[W] Q7
# [  6] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  4] Utilization = 0.06 | pJ/Compute =    3.041 | L3[IO] Q2 P56 - L2[IO] Q4 R3 M2 C4 - L1[] Q1 M128Y C32X S3X - L0[W] Q7
# [  4] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# Interrupt caught. Mapper threads will terminate after completing any ongoing evaluations.

# %%
for i, (stats, loops) in enumerate(vgg_pim_layerwise_results):
    print(f"Layer: {i+1}")
    log = False
    for line in stats.split("\n"):
        if "Summary Stats" in line:
            log = True
        if log:
            print(line)

# %%
total_cycles = 0
for i, (stats, loops) in enumerate(vgg_pim_layerwise_results):
    for line in stats.split("\n"):
        if "Cycles: " in line:
            cycles = int(line[len("Cycles: "):])
            total_cycles += cycles
            print(f"Cycles in layer {i+1}: {cycles}")
            break
print(f"Total cycles: {total_cycles}")

# %%
total_energy = 0
for i, (stats, loops) in enumerate(vgg_pim_layerwise_results):
    for line in stats.split("\n"):
        if "Energy: " in line:
            energy = float(line[len("Energy: "):].split(' uJ')[0])
            total_energy += energy
            print(f"Energy in layer {i+1}: {energy}")
            break
print(f"Total energy: {total_energy} uJ")
