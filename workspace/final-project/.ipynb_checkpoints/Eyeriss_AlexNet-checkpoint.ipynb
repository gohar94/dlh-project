# %%
import pandas as pd
import numpy as np
from loaders import *

# %%
alexnet_layers = [
    ConfigRegistry.ALEXNET_LAYER1,
    ConfigRegistry.ALEXNET_LAYER2,
    ConfigRegistry.ALEXNET_LAYER3,
    ConfigRegistry.ALEXNET_LAYER4,
    ConfigRegistry.ALEXNET_LAYER5,
]

# %%
eyeriss_accelergy_result = run_accelergy(
    ConfigRegistry.EYERISS_ARCH,
    ConfigRegistry.EYERISS_COMPONENTS_DIR
)
print(eyeriss_accelergy_result.ert_verbose)
# Out:
# ERT_summary:
#   version: 0.3
#   table_summary:
#   - name: system.eyeriss.PE[0..167].mac
#     actions:
#     - name: mac_random
#       energy: 2.20035
#     - name: mac_reused
#       energy: 1.87673
#     - name: mac_gated
#       energy: 0.10285
#     - name: idle
#       energy: 0.06595
#     primitive_estimation(s):
#     - system.eyeriss.PE[0..167].mac:
#         estimator: Aladdin_table
#   - name: system.eyeriss.DummyBuffer[0..13]
#     actions:
#     - name: read
#       average_energy: 0.10409
#       max_energy: 0.20203
#       min_energy: 0.00616
#     - name: write
#       average_energy: 0.10409
#       max_energy: 0.20203
#       min_energy: 0.00616
#     - name: idle
#       energy: 0.00616
#     primitive_estimation(s):
#     - system.eyeriss.DummyBuffer[0..13]:
#         estimator: Aladdin_table
#   - name: system.DRAM
#     actions:
#     - name: read
#       energy: 512
#     - name: write
#       energy: 512
#     - name: idle
#       energy: 0
#     primitive_estimation(s):
#     - system.DRAM:
#         estimator: Cacti
#   - name: system.eyeriss.PE[0..167].ifmap_spad
#     actions:
#     - name: write
#       average_energy: 0.14561
#       max_energy: 0.23632
#       min_energy: 0.0549
#     - name: read
#       average_energy: 0.14561
#       max_energy: 0.23632
#       min_energy: 0.0549
#     - name: idle
#       energy: 0.018
#     primitive_estimation(s):
#     - action_name: write
#       arguments:
#         address_delta: 0
#         data_delta: 0
#       energy: 0.0549
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 0
#           data_delta: 0
#         energy: 0.0061
#         action_share: 1
#         interpreted_energy: 0.0061
#         percentage: 11.11%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 78.05%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 10.84%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 0
#         data_delta: 1
#       energy: 0.19298
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 0
#           data_delta: 1
#         energy: 0.14418
#         action_share: 1
#         interpreted_energy: 0.14418
#         percentage: 74.71%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 22.2%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 3.08%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 1
#         data_delta: 0
#       energy: 0.09824
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 1
#           data_delta: 0
#         energy: 0.04944
#         action_share: 1
#         interpreted_energy: 0.04944
#         percentage: 50.33%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 43.62%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 6.06%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 1
#         data_delta: 1
#       energy: 0.23632
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 1
#           data_delta: 1
#         energy: 0.18752
#         action_share: 1
#         interpreted_energy: 0.18752
#         percentage: 79.35%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 18.13%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 2.52%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 0
#         data_delta: 0
#       energy: 0.0549
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 0
#           data_delta: 0
#         energy: 0.0061
#         action_share: 1
#         interpreted_energy: 0.0061
#         percentage: 11.11%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 78.05%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 10.84%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 0
#         data_delta: 1
#       energy: 0.19298
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 0
#           data_delta: 1
#         energy: 0.14418
#         action_share: 1
#         interpreted_energy: 0.14418
#         percentage: 74.71%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 22.2%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 3.08%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 1
#         data_delta: 0
#       energy: 0.09824
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 1
#           data_delta: 0
#         energy: 0.04944
#         action_share: 1
#         interpreted_energy: 0.04944
#         percentage: 50.33%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 43.62%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 6.06%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 1
#         data_delta: 1
#       energy: 0.23632
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 1
#           data_delta: 1
#         energy: 0.18752
#         action_share: 1
#         interpreted_energy: 0.18752
#         percentage: 79.35%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 18.13%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 2.52%
#         estimator: Aladdin_table
#     - action_name: idle
#       arguments: null
#       energy: 0.018
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: idle
#         arguments: null
#         energy: 0.0061
#         action_share: 1
#         interpreted_energy: 0.0061
#         percentage: 33.89%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0..1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.0119
#         percentage: 66.11%
#         estimator: Aladdin_table
#   - name: system.eyeriss.PE[0..167].weights_spad
#     actions:
#     - name: write
#       average_energy: 0.82303
#       max_energy: 1.58552
#       min_energy: 0.06053
#     - name: read
#       average_energy: 0.82303
#       max_energy: 1.58552
#       min_energy: 0.06053
#     - name: idle
#       energy: 0.02363
#     primitive_estimation(s):
#     - action_name: write
#       arguments:
#         address_delta: 0
#         data_delta: 0
#       energy: 0.06053
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 0
#           data_delta: 0
#         energy: 0.01173
#         action_share: 1
#         interpreted_energy: 0.01173
#         percentage: 19.38%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 70.79%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 9.83%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 0
#         data_delta: 1
#       energy: 0.19861
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 0
#           data_delta: 1
#         energy: 0.14981
#         action_share: 1
#         interpreted_energy: 0.14981
#         percentage: 75.43%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 21.57%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 3.0%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 1
#         data_delta: 0
#       energy: 1.44744
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 1
#           data_delta: 0
#         energy: 1.39864
#         action_share: 1
#         interpreted_energy: 1.39864
#         percentage: 96.63%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 2.96%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.41%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 1
#         data_delta: 1
#       energy: 1.58552
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 1
#           data_delta: 1
#         energy: 1.53672
#         action_share: 1
#         interpreted_energy: 1.53672
#         percentage: 96.92%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 2.7%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.38%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 0
#         data_delta: 0
#       energy: 0.06053
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 0
#           data_delta: 0
#         energy: 0.01173
#         action_share: 1
#         interpreted_energy: 0.01173
#         percentage: 19.38%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 70.79%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 9.83%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 0
#         data_delta: 1
#       energy: 0.19861
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 0
#           data_delta: 1
#         energy: 0.14981
#         action_share: 1
#         interpreted_energy: 0.14981
#         percentage: 75.43%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 21.57%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 3.0%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 1
#         data_delta: 0
#       energy: 1.44744
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 1
#           data_delta: 0
#         energy: 1.39864
#         action_share: 1
#         interpreted_energy: 1.39864
#         percentage: 96.63%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 2.96%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.41%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 1
#         data_delta: 1
#       energy: 1.58552
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 1
#           data_delta: 1
#         energy: 1.53672
#         action_share: 1
#         interpreted_energy: 1.53672
#         percentage: 96.92%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 2.7%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.38%
#         estimator: Aladdin_table
#     - action_name: idle
#       arguments: null
#       energy: 0.02363
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: idle
#         arguments: null
#         energy: 0.01173
#         action_share: 1
#         interpreted_energy: 0.01173
#         percentage: 49.64%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0..1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.0119
#         percentage: 50.36%
#         estimator: Aladdin_table
#   - name: system.eyeriss.PE[0..167].psum_spad
#     actions:
#     - name: write
#       average_energy: 0.1529
#       max_energy: 0.25083
#       min_energy: 0.05496
#     - name: read
#       average_energy: 0.1529
#       max_energy: 0.25083
#       min_energy: 0.05496
#     - name: idle
#       energy: 0.01806
#     primitive_estimation(s):
#     - action_name: write
#       arguments:
#         address_delta: 0
#         data_delta: 0
#       energy: 0.05496
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 0
#           data_delta: 0
#         energy: 0.00616
#         action_share: 1
#         interpreted_energy: 0.00616
#         percentage: 11.21%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 77.97%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 10.83%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 0
#         data_delta: 1
#       energy: 0.19304
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 0
#           data_delta: 1
#         energy: 0.14424
#         action_share: 1
#         interpreted_energy: 0.14424
#         percentage: 74.72%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 22.2%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 3.08%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 1
#         data_delta: 0
#       energy: 0.11275
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 1
#           data_delta: 0
#         energy: 0.06395
#         action_share: 1
#         interpreted_energy: 0.06395
#         percentage: 56.72%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 38.0%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 5.28%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 1
#         data_delta: 1
#       energy: 0.25083
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 1
#           data_delta: 1
#         energy: 0.20203
#         action_share: 1
#         interpreted_energy: 0.20203
#         percentage: 80.54%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 17.08%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 2.37%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 0
#         data_delta: 0
#       energy: 0.05496
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 0
#           data_delta: 0
#         energy: 0.00616
#         action_share: 1
#         interpreted_energy: 0.00616
#         percentage: 11.21%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 77.97%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 10.83%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 0
#         data_delta: 1
#       energy: 0.19304
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 0
#           data_delta: 1
#         energy: 0.14424
#         action_share: 1
#         interpreted_energy: 0.14424
#         percentage: 74.72%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 22.2%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 3.08%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 1
#         data_delta: 0
#       energy: 0.11275
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 1
#           data_delta: 0
#         energy: 0.06395
#         action_share: 1
#         interpreted_energy: 0.06395
#         percentage: 56.72%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 38.0%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 5.28%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 1
#         data_delta: 1
#       energy: 0.25083
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 1
#           data_delta: 1
#         energy: 0.20203
#         action_share: 1
#         interpreted_energy: 0.20203
#         percentage: 80.54%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 17.08%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 2.37%
#         estimator: Aladdin_table
#     - action_name: idle
#       arguments: null
#       energy: 0.01806
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: idle
#         arguments: null
#         energy: 0.00616
#         action_share: 1
#         interpreted_energy: 0.00616
#         percentage: 34.11%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0..1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.0119
#         percentage: 65.89%
#         estimator: Aladdin_table
#   - name: system.eyeriss.shared_glb
#     actions:
#     - name: write
#       average_energy: 37.63497
#       max_energy: 75.2148
#       min_energy: 0.05514
#     - name: read
#       average_energy: 37.09967
#       max_energy: 74.1442
#       min_energy: 0.05514
#     - name: idle
#       energy: 0.01824
#     primitive_estimation(s):
#     - action_name: write
#       arguments:
#         address_delta: 0
#         data_delta: 0
#       energy: 0.05514
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 0
#           data_delta: 0
#         energy: 0.00634
#         action_share: 1
#         interpreted_energy: 0.00634
#         percentage: 11.5%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 77.71%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 10.79%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 0
#         data_delta: 1
#       energy: 52.6669
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 0
#           data_delta: 1
#         energy: 52.6181
#         action_share: 1
#         interpreted_energy: 52.6181
#         percentage: 99.91%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.08%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.01%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 1
#         data_delta: 0
#       energy: 0.75976
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 1
#           data_delta: 0
#         energy: 0.71096
#         action_share: 1
#         interpreted_energy: 0.71096
#         percentage: 93.58%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 5.64%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.78%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 1
#         data_delta: 1
#       energy: 53.37152
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 1
#           data_delta: 1
#         energy: 53.32272
#         action_share: 1
#         interpreted_energy: 53.32272
#         percentage: 99.91%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.08%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.01%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 2
#         data_delta: 0
#       energy: 1.46438
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 2
#           data_delta: 0
#         energy: 1.41558
#         action_share: 1
#         interpreted_energy: 1.41558
#         percentage: 96.67%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 2.93%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.41%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 2
#         data_delta: 1
#       energy: 54.07615
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 2
#           data_delta: 1
#         energy: 54.02735
#         action_share: 1
#         interpreted_energy: 54.02735
#         percentage: 99.91%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.08%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.01%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 3
#         data_delta: 0
#       energy: 2.16901
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 3
#           data_delta: 0
#         energy: 2.12021
#         action_share: 1
#         interpreted_energy: 2.12021
#         percentage: 97.75%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 1.98%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.27%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 3
#         data_delta: 1
#       energy: 54.78077
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 3
#           data_delta: 1
#         energy: 54.73197
#         action_share: 1
#         interpreted_energy: 54.73197
#         percentage: 99.91%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.08%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.01%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 4
#         data_delta: 0
#       energy: 2.87363
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 4
#           data_delta: 0
#         energy: 2.82483
#         action_share: 1
#         interpreted_energy: 2.82483
#         percentage: 98.3%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 1.49%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.21%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 4
#         data_delta: 1
#       energy: 55.48539
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 4
#           data_delta: 1
#         energy: 55.43659
#         action_share: 1
#         interpreted_energy: 55.43659
#         percentage: 99.91%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.08%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.01%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 5
#         data_delta: 0
#       energy: 3.57825
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 5
#           data_delta: 0
#         energy: 3.52945
#         action_share: 1
#         interpreted_energy: 3.52945
#         percentage: 98.64%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 1.2%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.17%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 5
#         data_delta: 1
#       energy: 56.19001
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 5
#           data_delta: 1
#         energy: 56.14121
#         action_share: 1
#         interpreted_energy: 56.14121
#         percentage: 99.91%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.08%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.01%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 6
#         data_delta: 0
#       energy: 4.28287
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 6
#           data_delta: 0
#         energy: 4.23407
#         action_share: 1
#         interpreted_energy: 4.23407
#         percentage: 98.86%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 1.0%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.14%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 6
#         data_delta: 1
#       energy: 56.89463
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 6
#           data_delta: 1
#         energy: 56.84583
#         action_share: 1
#         interpreted_energy: 56.84583
#         percentage: 99.91%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.08%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.01%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 7
#         data_delta: 0
#       energy: 4.98749
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 7
#           data_delta: 0
#         energy: 4.93869
#         action_share: 1
#         interpreted_energy: 4.93869
#         percentage: 99.02%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.86%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.12%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 7
#         data_delta: 1
#       energy: 57.59925
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 7
#           data_delta: 1
#         energy: 57.55045
#         action_share: 1
#         interpreted_energy: 57.55045
#         percentage: 99.92%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.07%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.01%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 8
#         data_delta: 0
#       energy: 5.69211
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 8
#           data_delta: 0
#         energy: 5.64331
#         action_share: 1
#         interpreted_energy: 5.64331
#         percentage: 99.14%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.75%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.1%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 8
#         data_delta: 1
#       energy: 58.30388
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 8
#           data_delta: 1
#         energy: 58.25508
#         action_share: 1
#         interpreted_energy: 58.25508
#         percentage: 99.92%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.07%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.01%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 9
#         data_delta: 0
#       energy: 6.39674
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 9
#           data_delta: 0
#         energy: 6.34794
#         action_share: 1
#         interpreted_energy: 6.34794
#         percentage: 99.24%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.67%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.09%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 9
#         data_delta: 1
#       energy: 59.0085
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 9
#           data_delta: 1
#         energy: 58.9597
#         action_share: 1
#         interpreted_energy: 58.9597
#         percentage: 99.92%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.07%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.01%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 10
#         data_delta: 0
#       energy: 7.10136
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 10
#           data_delta: 0
#         energy: 7.05256
#         action_share: 1
#         interpreted_energy: 7.05256
#         percentage: 99.31%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.6%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.08%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 10
#         data_delta: 1
#       energy: 59.71312
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 10
#           data_delta: 1
#         energy: 59.66432
#         action_share: 1
#         interpreted_energy: 59.66432
#         percentage: 99.92%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.07%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.01%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 11
#         data_delta: 0
#       energy: 7.80598
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 11
#           data_delta: 0
#         energy: 7.75718
#         action_share: 1
#         interpreted_energy: 7.75718
#         percentage: 99.37%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.55%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.08%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 11
#         data_delta: 1
#       energy: 60.41774
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 11
#           data_delta: 1
#         energy: 60.36894
#         action_share: 1
#         interpreted_energy: 60.36894
#         percentage: 99.92%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.07%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.01%
#         estimator: Aladdin_table
#     - action_name: write
#       arguments:
#         address_delta: 12
#         data_delta: 0
#       energy: 8.5106
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: write
#         arguments:
#           address_delta: 12
#           data_delta: 0
#         energy: 8.4618
#         action_share: 1
#         interpreted_energy: 8.4618
#         percentage: 99.43%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0]
#         subaction_name: count
#         arguments: null
#         energy: 0.04285
# ...
#         percentage: 0.04%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 24
#         data_delta: 1
#       energy: 68.58752
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 24
#           data_delta: 1
#         energy: 68.53872
#         action_share: 1
#         interpreted_energy: 68.53872
#         percentage: 99.93%
#         estimator: Cacti
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.06%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.01%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 25
#         data_delta: 0
#       energy: 17.41976
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 25
#           data_delta: 0
#         energy: 17.37096
#         action_share: 1
#         interpreted_energy: 17.37096
#         percentage: 99.72%
#         estimator: Cacti
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.25%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.03%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 25
#         data_delta: 1
#       energy: 69.28211
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 25
#           data_delta: 1
#         energy: 69.23331
#         action_share: 1
#         interpreted_energy: 69.23331
#         percentage: 99.93%
#         estimator: Cacti
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.06%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.01%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 26
#         data_delta: 0
#       energy: 18.11435
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 26
#           data_delta: 0
#         energy: 18.06555
#         action_share: 1
#         interpreted_energy: 18.06555
#         percentage: 99.73%
#         estimator: Cacti
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.24%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.03%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 26
#         data_delta: 1
#       energy: 69.97669
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 26
#           data_delta: 1
#         energy: 69.92789
#         action_share: 1
#         interpreted_energy: 69.92789
#         percentage: 99.93%
#         estimator: Cacti
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.06%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.01%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 27
#         data_delta: 0
#       energy: 18.80893
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 27
#           data_delta: 0
#         energy: 18.76013
#         action_share: 1
#         interpreted_energy: 18.76013
#         percentage: 99.74%
#         estimator: Cacti
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.23%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.03%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 27
#         data_delta: 1
#       energy: 70.67128
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 27
#           data_delta: 1
#         energy: 70.62248
#         action_share: 1
#         interpreted_energy: 70.62248
#         percentage: 99.93%
#         estimator: Cacti
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.06%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.01%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 28
#         data_delta: 0
#       energy: 19.50352
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 28
#           data_delta: 0
#         energy: 19.45472
#         action_share: 1
#         interpreted_energy: 19.45472
#         percentage: 99.75%
#         estimator: Cacti
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.22%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.03%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 28
#         data_delta: 1
#       energy: 71.36586
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 28
#           data_delta: 1
#         energy: 71.31706
#         action_share: 1
#         interpreted_energy: 71.31706
#         percentage: 99.93%
#         estimator: Cacti
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.06%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.01%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 29
#         data_delta: 0
#       energy: 20.1981
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 29
#           data_delta: 0
#         energy: 20.1493
#         action_share: 1
#         interpreted_energy: 20.1493
#         percentage: 99.76%
#         estimator: Cacti
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.21%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.03%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 29
#         data_delta: 1
#       energy: 72.06045
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 29
#           data_delta: 1
#         energy: 72.01165
#         action_share: 1
#         interpreted_energy: 72.01165
#         percentage: 99.93%
#         estimator: Cacti
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.06%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.01%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 30
#         data_delta: 0
#       energy: 20.89269
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 30
#           data_delta: 0
#         energy: 20.84389
#         action_share: 1
#         interpreted_energy: 20.84389
#         percentage: 99.77%
#         estimator: Cacti
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.21%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.03%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 30
#         data_delta: 1
#       energy: 72.75503
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 30
#           data_delta: 1
#         energy: 72.70623
#         action_share: 1
#         interpreted_energy: 72.70623
#         percentage: 99.93%
#         estimator: Cacti
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.06%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.01%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 31
#         data_delta: 0
#       energy: 21.58727
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 31
#           data_delta: 0
#         energy: 21.53847
#         action_share: 1
#         interpreted_energy: 21.53847
#         percentage: 99.77%
#         estimator: Cacti
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.2%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.03%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 31
#         data_delta: 1
#       energy: 73.44962
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 31
#           data_delta: 1
#         energy: 73.40082
#         action_share: 1
#         interpreted_energy: 73.40082
#         percentage: 99.93%
#         estimator: Cacti
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.06%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.01%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 32
#         data_delta: 0
#       energy: 22.28186
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 32
#           data_delta: 0
#         energy: 22.23306
#         action_share: 1
#         interpreted_energy: 22.23306
#         percentage: 99.78%
#         estimator: Cacti
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.19%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.03%
#         estimator: Aladdin_table
#     - action_name: read
#       arguments:
#         address_delta: 32
#         data_delta: 1
#       energy: 74.1442
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: read
#         arguments:
#           address_delta: 32
#           data_delta: 1
#         energy: 74.0954
#         action_share: 1
#         interpreted_energy: 74.0954
#         percentage: 99.93%
#         estimator: Cacti
#       - subcomponent_name: address_generators[1]
#         subaction_name: add
#         arguments: null
#         energy: 0.04285
#         action_share: 1
#         interpreted_energy: 0.04285
#         percentage: 0.06%
#         estimator: Aladdin_table
#       - subcomponent_name: address_generators[0]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.00595
#         percentage: 0.01%
#         estimator: Aladdin_table
#     - action_name: idle
#       arguments: null
#       energy: 0.01824
#       subaction_estimations:
#       - subcomponent_name: storage
#         subaction_name: idle
#         arguments: null
#         energy: 0.00634
#         action_share: 1
#         interpreted_energy: 0.00634
#         percentage: 34.76%
#         estimator: Cacti
#       - subcomponent_name: address_generators[0..1]
#         subaction_name: idle
#         arguments: null
#         energy: 0.00595
#         action_share: 1
#         interpreted_energy: 0.0119
#         percentage: 65.24%
#         estimator: Aladdin_table

# %%
alexnet_eyeriss_layerwise_results = []

for i, layer in enumerate(alexnet_layers):
    eyeriss_results = run_timeloop_mapper(
        ConfigRegistry.EYERISS_ARCH,
        ConfigRegistry.EYERISS_COMPONENTS_DIR,
        eyeriss_accelergy_result.art,
        eyeriss_accelergy_result.ert,
        ConfigRegistry.EYERISS_ARCH_CONSTRAINTS,
        ConfigRegistry.EYERISS_MAP_CONSTRAINTS,
        ConfigRegistry.EYERISS_MAPPER,
        layer,
    )
    print(f"Layer: {i+1}")
    eyeriss_results_stats, eyeriss_results_loops = eyeriss_results
    print(eyeriss_results_loops)
    print(eyeriss_results_stats)
    alexnet_eyeriss_layerwise_results.append(eyeriss_results)
# Out:
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Found Accelergy ERT (energy reference table), replacing internal energy model.
# Found Accelergy ART (area reference table), replacing internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 4
#   Factorization options along problem dimension M = 630
#   Factorization options along problem dimension R = 1
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension P = 1
#   Factorization options along problem dimension Q = 4
# Mapspace Dimension [IndexFactorization] Size: 10080
# Mapspace Dimension [LoopPermutation] Size: 1
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 1260 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# [  2] Utilization = 0.13 | pJ/Compute =  136.327 | L5[WIO] Q55 M6 - L4[IO] P55 C3 M2X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M8
# [  2] Utilization = 0.19 | pJ/Compute =   27.830 | L5[WIO] Q5 M4 - L4[IO] M12 P55 C3 Q11X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M2
# [  3] Utilization = 0.13 | pJ/Compute =   11.445 | L5[WIO] Q55 M6 C3 - L4[IO] P55 M2X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M8
# [  3] Utilization = 0.13 | pJ/Compute =   11.061 | L5[WIO] Q55 M3 C3 - L4[IO] M8 P55 M2X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M2
# [  3] Utilization = 0.25 | pJ/Compute =   35.701 | L5[WIO] Q5 M96 C3 - L4[IO] P55 Q11X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] Q1
# [  7] Utilization = 0.65 | pJ/Compute =    7.416 | L5[WIO] Q11 M4 C3 - L4[IO] M2 P55 M2X Q5X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M6
# [  6] Utilization = 0.65 | pJ/Compute =   34.031 | L5[WIO] Q11 M4 - L4[IO] M2 P55 C3 M2X Q5X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M6
# [  2] Utilization = 0.39 | pJ/Compute =  138.465 | L5[WIO] Q55 M8 - L4[IO] M2 P55 C3 M6X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] Q1
# [  3] Utilization = 0.49 | pJ/Compute =    9.930 | L5[WIO] Q5 M4 C3 - L4[IO] M12 P55 Q11X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M2
# [  3] Utilization = 0.49 | pJ/Compute =    9.447 | L5[WIO] Q5 M2 C3 - L4[IO] M24 P55 Q11X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M2
# [  2] Utilization = 0.57 | pJ/Compute =   35.615 | L5[WIO] Q11 M2 - L4[IO] M8 P55 C3 M2X Q5X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M3
# [  3] Utilization = 0.65 | pJ/Compute =    7.447 | L5[WIO] Q11 M2 C3 - L4[IO] M8 P55 M2X Q5X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M3
# [  2] Utilization = 0.65 | pJ/Compute =   33.239 | L5[WIO] Q11 M2 - L4[IO] M2 P55 C3 M2X Q5X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M12
# [  2] Utilization = 0.79 | pJ/Compute =  136.920 | L5[WIO] Q55 M4 - L4[IO] M2 P55 C3 M12X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] Q1
# [  6] Utilization = 0.72 | pJ/Compute =   20.790 | L5[WIO] Q5 M4 - L4[IO] M3 P55 C3 Q11X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M8
# [  2] Utilization = 0.79 | pJ/Compute =  135.671 | L5[WIO] Q55 - L4[IO] M4 P55 C3 M12X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M2
# [  7] Utilization = 0.65 | pJ/Compute =    7.150 | L5[WIO] Q11 M2 C3 - L4[IO] M6 P55 M2X Q5X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M4
# [  6] Utilization = 0.72 | pJ/Compute =   20.008 | L5[WIO] Q5 M4 - L4[IO] M2 P55 C3 Q11X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M12
# [  3] Utilization = 0.65 | pJ/Compute =    6.556 | L5[WIO] Q11 M2 C3 - L4[IO] M2 P55 M2X Q5X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M12
# [  7] Utilization = 0.72 | pJ/Compute =    7.289 | L5[WIO] Q5 M4 C3 - L4[IO] M3 P55 Q11X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M8
# [  3] Utilization = 0.79 | pJ/Compute =   10.520 | L5[WIO] Q55 M4 C3 - L4[IO] M2 P55 M12X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] Q1
# [  3] Utilization = 0.79 | pJ/Compute =    8.465 | L5[WIO] Q55 C3 - L4[IO] M4 P55 M12X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M2
# [  7] Utilization = 0.72 | pJ/Compute =    6.996 | L5[WIO] Q5 M4 C3 - L4[IO] M2 P55 Q11X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M12
# [  7] Utilization = 0.72 | pJ/Compute =    6.806 | L5[WIO] Q5 M2 C3 - L4[IO] M6 P55 Q11X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M8
# [  1] STATEMENT: 15000 invalid mappings (15000 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  4] STATEMENT: 15000 invalid mappings (12883 fanout, 2117 capacity) found since the last valid mapping, terminating search.
# [  2] Utilization = 0.79 | pJ/Compute =  135.226 | L5[WIO] Q55 - L4[IO] M2 P55 C3 M12X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M4
# [  0] STATEMENT: 15000 invalid mappings (12697 fanout, 2303 capacity) found since the last valid mapping, terminating search.
# [  3] Utilization = 0.79 | pJ/Compute =    8.298 | L5[WIO] Q55 C3 - L4[IO] M2 P55 M12X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M4
# [  6] Utilization = 0.79 | pJ/Compute =  135.003 | L5[WIO] Q55 - L4[IO] P55 C3 M12X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M8
# [  7] Utilization = 0.79 | pJ/Compute =    8.214 | L5[WIO] Q55 C3 - L4[IO] P55 M12X - L3[] Q1 S11Y - L2[I] Q1 - L1[W] R11 - L0[O] M8
# [  5] STATEMENT: 15000 invalid mappings (15000 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  7] STATEMENT: 3000 suboptimal mappings found since the last upgrade, terminating search.
# [  6] STATEMENT: 3000 suboptimal mappings found since the last upgrade, terminating search.
# [  3] STATEMENT: 3000 suboptimal mappings found since the last upgrade, terminating search.
# [  2] STATEMENT: 3000 suboptimal mappings found since the last upgrade, terminating search.
# ===============================================
#                BEGIN DIAGNOSTICS
# -----------------------------------------------
# Fail class: Fanout
#
#   Level: DummyBuffer
#     Fail count: 109183
#     Sample mapping that experienced this fail class:
#
#       DRAM [ Weights:34848 (34848) Inputs:154587 (154587) Outputs:290400 (290400) ]
#       -----------------------------------------------------------------------------
#       | for Q in [0:11)
#       |   for M in [0:2)
#
#       shared_glb [ Inputs:18387 (18387) Outputs:13200 (13200) ]
#       ---------------------------------------------------------
#       |     for P in [0:55)
#       |       for M in [0:4) (Spatial-X)
#       |         for Q in [0:5) (Spatial-X)
#
#       DummyBuffer [ ]
#       ---------------
#       |           for Q in [0:1)
#       |             for M in [0:4) (Spatial-Y)
#       |               for S in [0:11) (Spatial-Y)
#
#       ifmap_spad [ Inputs:33 (33) ]
#       -----------------------------
#       |                 for Q in [0:1)
#
#       weights_spad [ Weights:99 (99) ]
#       --------------------------------
#       |                   for R in [0:11)
#       |                     for C in [0:3)
#
#       psum_spad [ Outputs:3 (3) ]
#       ---------------------------
#       |                       for M in [0:3)
#
#     Fail reason: mapped fanoutY 44 exceeds hardware fanoutY 12
#
#
#   Level: shared_glb
#     Fail count: 82030
#     Sample mapping that experienced this fail class:
#
#       DRAM [ Weights:34848 (34848) Inputs:154587 (154587) Outputs:290400 (290400) ]
#       -----------------------------------------------------------------------------
#       | for Q in [0:11)
#       |   for M in [0:2)
#
#       shared_glb [ Inputs:18387 (18387) Outputs:13200 (13200) ]
#       ---------------------------------------------------------
#       |     for M in [0:12)
#       |       for P in [0:55)
#       |         for M in [0:4) (Spatial-X)
#       |           for Q in [0:5) (Spatial-X)
#
#       DummyBuffer [ ]
#       ---------------
#       |             for Q in [0:1)
#       |               for S in [0:11) (Spatial-Y)
#
#       ifmap_spad [ Inputs:33 (33) ]
#       -----------------------------
#       |                 for Q in [0:1)
#
#       weights_spad [ Weights:33 (33) ]
#       --------------------------------
#       |                   for R in [0:11)
#       |                     for C in [0:3)
#
#       psum_spad [ Outputs:1 (1) ]
#       ---------------------------
#       |                       for Q in [0:1)
#
#     Fail reason: mapped fanoutX 20 exceeds hardware fanoutX 14
#
# Fail class: Capacity
#
#   Level: psum_spad
#     Fail count: 1497
#     Sample mapping that experienced this fail class:
#
#       DRAM [ Weights:34848 (34848) Inputs:154587 (154587) Outputs:290400 (290400) ]
#       -----------------------------------------------------------------------------
#       | for Q in [0:5)
#
#       shared_glb [ Inputs:34731 (34731) Outputs:58080 (58080) ]
#       ---------------------------------------------------------
#       |   for M in [0:4)
#       |     for P in [0:55)
#       |       for Q in [0:11) (Spatial-X)
#
#       DummyBuffer [ ]
#       ---------------
#       |         for Q in [0:1)
#       |           for S in [0:11) (Spatial-Y)
#
#       ifmap_spad [ Inputs:33 (33) ]
#       -----------------------------
#       |             for Q in [0:1)
#
#       weights_spad [ Weights:792 (792) ]
#       ----------------------------------
#       |               for R in [0:11)
#       |                 for C in [0:3)
#
#       psum_spad [ Outputs:24 (24) ]
#       -----------------------------
#       |                   for M in [0:24)
#
#     Fail reason: mapped tile size 24 exceeds buffer capacity 16
#
#
#   Level: weights_spad
#     Fail count: 2678
#     Sample mapping that experienced this fail class:
#
#       DRAM [ Weights:34848 (34848) Inputs:154587 (154587) Outputs:290400 (290400) ]
#       -----------------------------------------------------------------------------
#       | for Q in [0:11)
#       |   for M in [0:8)
#
#       shared_glb [ Inputs:18387 (18387) Outputs:3300 (3300) ]
#       -------------------------------------------------------
#       |     for P in [0:55)
#       |       for M in [0:2) (Spatial-X)
#       |         for Q in [0:5) (Spatial-X)
#
#       DummyBuffer [ ]
#       ---------------
#       |           for Q in [0:1)
#       |             for S in [0:11) (Spatial-Y)
#
#       ifmap_spad [ Inputs:33 (33) ]
#       -----------------------------
#       |               for Q in [0:1)
#
#       weights_spad [ Weights:198 (198) ]
#       ----------------------------------
#       |                 for R in [0:11)
#       |                   for C in [0:3)
#
#       psum_spad [ Outputs:6 (6) ]
#       ---------------------------
#       |                     for M in [0:6)
#
#     Fail reason: mapped tile size 198 exceeds buffer capacity 192
#
#
#   Level: ifmap_spad
#     Fail count: 4421
#     Sample mapping that experienced this fail class:
#
#       DRAM [ Weights:34848 (34848) Inputs:154587 (154587) Outputs:290400 (290400) ]
#       -----------------------------------------------------------------------------
#       | for Q in [0:5)
#
#       shared_glb [ Inputs:34731 (34731) Outputs:58080 (58080) ]
#       ---------------------------------------------------------
#       |   for M in [0:24)
#       |     for P in [0:55)
#       |       for Q in [0:11) (Spatial-X)
#
#       DummyBuffer [ ]
#       ---------------
#       |         for Q in [0:1)
#       |           for S in [0:11) (Spatial-Y)
#
#       ifmap_spad [ Inputs:33 (33) ]
#       -----------------------------
#       |             for Q in [0:1)
#
#       weights_spad [ Weights:132 (132) ]
#       ----------------------------------
#       |               for R in [0:11)
#       |                 for C in [0:3)
#
#       psum_spad [ Outputs:4 (4) ]
#       ---------------------------
#       |                   for M in [0:4)
#
#     Fail reason: mapped tile size 33 exceeds buffer capacity 12
#
#
#   Level: shared_glb
#     Fail count: 570
#     Sample mapping that experienced this fail class:
#
#       DRAM [ Weights:34848 (34848) Inputs:154587 (154587) Outputs:290400 (290400) ]
#       -----------------------------------------------------------------------------
#       | for Q in [0:5)
#
#       shared_glb [ Inputs:34731 (34731) Outputs:58080 (58080) ]
#       ---------------------------------------------------------
#       |   for M in [0:4)
#       |     for P in [0:55)
#       |       for Q in [0:11) (Spatial-X)
#
#       DummyBuffer [ ]
#       ---------------
#       |         for Q in [0:1)
#       |           for S in [0:11) (Spatial-Y)
#
#       ifmap_spad [ Inputs:33 (33) ]
#       -----------------------------
#       |             for Q in [0:1)
#
#       weights_spad [ Weights:792 (792) ]
#       ----------------------------------
#       |               for R in [0:11)
#       |                 for C in [0:3)
#
#       psum_spad [ Outputs:24 (24) ]
#       -----------------------------
#       |                   for M in [0:24)
#
#     Fail reason: mapped tile size 92811 exceeds buffer capacity 65536
#
# -----------------------------------------------
#                  END DIAGNOSTICS
# ===============================================
#
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.79 | pJ/Compute =    8.214
# Layer: 1
#
# DRAM [ Weights:34848 (34848) Inputs:154587 (154587) Outputs:290400 (290400) ]
# -----------------------------------------------------------------------------
# | for Q in [0:55)
# |   for C in [0:3)
#
# shared_glb [ Inputs:2497 (2497) Outputs:5280 (5280) ]
# -----------------------------------------------------
# |     for P in [0:55)
# |       for M in [0:12) (Spatial-X)
#
# DummyBuffer [ ]
# ---------------
# |         for Q in [0:1)
# |           for S in [0:11) (Spatial-Y)
#
# ifmap_spad [ Inputs:11 (11) ]
# -----------------------------
# |             for Q in [0:1)
#
# weights_spad [ Weights:88 (88) ]
# --------------------------------
# |               for R in [0:11)
#
# psum_spad [ Outputs:8 (8) ]
# ---------------------------
# |                 for M in [0:8)
#
#
# Buffer and Arithmetic Levels
# ----------------------------
# Level 0
# -------
# === mac ===
#
#     SPECS
#     -----
#     Word bits             : 16
#     Instances             : 168 (14*12)
#     Compute energy        : 2.20 pJ
#
#     STATS
#     -----
#     Utilized instances      : 132
#     Computes (total)        : 105415200
#     Cycles                  : 798600
#     Energy (total)          : 231950335.32 pJ
#     Area (total)            : 208236.00 um^2
#
# Level 1
# -------
# === psum_spad ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 16
#         Word bits                   : 16
#         Block size                  : 1
#         Cluster size                : 1
#         Instances                   : 168 (14*12)
#         Shared bandwidth            : -
#         Read bandwidth              : 2.00
#         Write bandwidth             : 2.00
#         Multiple buffering          : 1.00
#         Effective size              : 16
#         Min utilization             : 0.00
#         Vector access energy        : 0.25 pJ
#         Vector access energy source : ERT
#         Area                        : 414.68 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#       for M in [0:8)
#
#     STATS
#     -----
#     Cycles               : 798600
#     Bandwidth throttling : 1.00
#     Outputs:
#         Partition size                           : 24200
#         Utilized capacity                        : 8
#         Utilized instances (max)                 : 132
#         Utilized clusters (max)                  : 132
#         Scalar reads (per-instance)              : 774400
#         Scalar updates (per-instance)            : 798600
#         Scalar fills (per-instance)              : 72600
#         Temporal reductions (per-instance)       : 774400
#         Address generations (per-cluster)        : 871200
#         Energy (per-scalar-access)               : 0.25 pJ
#         Energy (per-instance)                    : 412765.85 pJ
#         Energy (total)                           : 54485091.94 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 2.06 words/cycle
#         Shared Bandwidth (total)                 : 272.00 words/cycle
#         Read Bandwidth (per-instance)            : 0.97 words/cycle
#         Read Bandwidth (total)                   : 128.00 words/cycle
#         Write Bandwidth (per-instance)           : 1.09 words/cycle
#         Write Bandwidth (total)                  : 144.00 words/cycle
#
# Level 2
# -------
# === weights_spad ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 192
#         Word bits                   : 16
#         Block size                  : 1
#         Cluster size                : 1
#         Instances                   : 168 (14*12)
#         Shared bandwidth            : -
#         Read bandwidth              : 2.00
#         Write bandwidth             : 2.00
#         Multiple buffering          : 1.00
#         Effective size              : 192
#         Min utilization             : 0.00
#         Vector access energy        : 1.59 pJ
#         Vector access energy source : ERT
#         Area                        : 3634.68 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#       for R in [0:11)
#
#     STATS
#     -----
#     Cycles               : 798600
#     Bandwidth throttling : 1.00
#     Weights:
#         Partition size                           : 264
#         Utilized capacity                        : 88
#         Utilized instances (max)                 : 132
#         Utilized clusters (max)                  : 132
#         Scalar reads (per-instance)              : 798600
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 14520
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 813120
#         Energy (per-scalar-access)               : 1.59 pJ
#         Energy (per-instance)                    : 1289218.02 pJ
#         Energy (total)                           : 170176778.96 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 1.02 words/cycle
#         Shared Bandwidth (total)                 : 134.40 words/cycle
#         Read Bandwidth (per-instance)            : 1.00 words/cycle
#         Read Bandwidth (total)                   : 132.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.02 words/cycle
#         Write Bandwidth (total)                  : 2.40 words/cycle
#
# Level 3
# -------
# === ifmap_spad ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 12
#         Word bits                   : 16
#         Block size                  : 1
#         Cluster size                : 1
#         Instances                   : 168 (14*12)
#         Shared bandwidth            : -
#         Read bandwidth              : 2.00
#         Write bandwidth             : 2.00
#         Multiple buffering          : 1.00
#         Effective size              : 12
#         Min utilization             : 0.00
#         Vector access energy        : 0.24 pJ
#         Vector access energy source : ERT
#         Area                        : 379.68 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#
#     STATS
#     -----
#     Cycles               : 798600
#     Bandwidth throttling : 1.00
#     Inputs:
#         Partition size                           : 14053
#         Utilized capacity                        : 11
#         Utilized instances (max)                 : 132
#         Utilized clusters (max)                  : 132
#         Scalar reads (per-instance)              : 798600
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 37455
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 836055
#         Energy (per-scalar-access)               : 0.24 pJ
#         Energy (per-instance)                    : 197576.52 pJ
#         Energy (total)                           : 26080100.32 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 1.05 words/cycle
#         Shared Bandwidth (total)                 : 138.19 words/cycle
#         Read Bandwidth (per-instance)            : 1.00 words/cycle
#         Read Bandwidth (total)                   : 132.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.05 words/cycle
#         Write Bandwidth (total)                  : 6.19 words/cycle
#
# Level 4
# -------
# === DummyBuffer ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 16
#         Word bits                   : 16
#         Block size                  : 1
#         Cluster size                : 1
#         Instances                   : 14 (14*1)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
#         Effective size              : 16
#         Min utilization             : 0.00
#         Vector access energy        : 0.20 pJ
#         Vector access energy source : ERT
#         Area                        : 235.68 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#       for S in [0:11) (Spatial-Y)
#
#     STATS
#     -----
#     Cycles               : 798600
#     Bandwidth throttling : 1.00
#
# Level 5
# -------
# === shared_glb ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 65536
#         Word bits                   : 16
#         Block size                  : 4
#         Cluster size                : 1
#         Instances                   : 1 (1*1)
#         Shared bandwidth            : -
#         Read bandwidth              : 16.00
#         Write bandwidth             : 16.00
#         Multiple buffering          : 1.00
#         Effective size              : 65536
#         Min utilization             : 0.00
#         Vector access energy        : 75.21 pJ
#         Vector access energy source : ERT
#         Area                        : 1162549.00 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#       for P in [0:55)
#         for M in [0:12) (Spatial-X)
#
#     STATS
#     -----
#     Cycles               : 798600
#     Bandwidth throttling : 1.00
#     Inputs:
#         Partition size                           : 154587
#         Utilized capacity                        : 2497
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 412005
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 412005
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 824010
#         Energy (per-scalar-access)               : 18.67 pJ
#         Energy (per-instance)                    : 15384275.72 pJ
#         Energy (total)                           : 15384275.72 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 1.03 words/cycle
#         Shared Bandwidth (total)                 : 1.03 words/cycle
#         Read Bandwidth (per-instance)            : 0.52 words/cycle
#         Read Bandwidth (total)                   : 0.52 words/cycle
#         Write Bandwidth (per-instance)           : 0.52 words/cycle
#         Write Bandwidth (total)                  : 0.52 words/cycle
#     Outputs:
#         Partition size                           : 290400
#         Utilized capacity                        : 5280
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 580800
#         Scalar updates (per-instance)            : 871200
#         Scalar fills (per-instance)              : 290400
#         Temporal reductions (per-instance)       : 580800
#         Address generations (per-cluster)        : 1161600
#         Energy (per-scalar-access)               : 18.71 pJ
#         Energy (per-instance)                    : 32608115.76 pJ
#         Energy (total)                           : 32608115.76 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 2.18 words/cycle
#         Shared Bandwidth (total)                 : 2.18 words/cycle
#         Read Bandwidth (per-instance)            : 0.73 words/cycle
#         Read Bandwidth (total)                   : 0.73 words/cycle
#         Write Bandwidth (per-instance)           : 1.45 words/cycle
#         Write Bandwidth (total)                  : 1.45 words/cycle
#
# Level 6
# -------
# === DRAM ===
#
#     SPECS
#     -----
#         Technology                  : DRAM
#         Size                        : -
#         Word bits                   : 16
#         Block size                  : 4
#         Cluster size                : 1
#         Instances                   : 1 (1*1)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
#         Effective size              : -
#         Min utilization             : 0.00
#         Vector access energy        : 512.00 pJ
#         Vector access energy source : ERT
#         Area                        : 0.00 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#       for Q in [0:55)
#         for C in [0:3)
#
#     STATS
#     -----
#     Cycles               : 798600
#     Bandwidth throttling : 1.00
#     Weights:
#         Partition size                           : 34848
#         Utilized capacity                        : 34848
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 1916640
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 1916640
#         Energy (per-scalar-access)               : 128.00 pJ
#         Energy (per-instance)                    : 245329920.00 pJ
#         Energy (total)                           : 245329920.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 2.40 words/cycle
#         Shared Bandwidth (total)                 : 2.40 words/cycle
#         Read Bandwidth (per-instance)            : 2.40 words/cycle
#         Read Bandwidth (total)                   : 2.40 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.00 words/cycle
#     Inputs:
#         Partition size                           : 154587
#         Utilized capacity                        : 154587
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 412005
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 412005
#         Energy (per-scalar-access)               : 128.00 pJ
#         Energy (per-instance)                    : 52737024.00 pJ
#         Energy (total)                           : 52737024.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 0.52 words/cycle
#         Shared Bandwidth (total)                 : 0.52 words/cycle
#         Read Bandwidth (per-instance)            : 0.52 words/cycle
#         Read Bandwidth (total)                   : 0.52 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.00 words/cycle
#     Outputs:
#         Partition size                           : 290400
#         Utilized capacity                        : 290400
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 0
#         Scalar updates (per-instance)            : 290400
#         Scalar fills (per-instance)              : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 290400
#         Energy (per-scalar-access)               : 128.00 pJ
#         Energy (per-instance)                    : 37171200.00 pJ
#         Energy (total)                           : 37171200.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 0.36 words/cycle
#         Shared Bandwidth (total)                 : 0.36 words/cycle
#         Read Bandwidth (per-instance)            : 0.00 words/cycle
#         Read Bandwidth (total)                   : 0.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.36 words/cycle
#         Write Bandwidth (total)                  : 0.36 words/cycle
#
# Networks
# --------
# Network 0
# ---------
# DRAM <==> shared_glb
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 1916640.00
#             @multicast 1 @scatter 1: 1916640.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Inputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 412005.00
#             @multicast 1 @scatter 1: 412005.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 290400.00
#             @multicast 1 @scatter 1: 290400.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
# Network 1
# ---------
# DummyBuffer <==> ifmap_spad
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 11
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 159720.00
#             @multicast 1 @scatter 11: 159720.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 1.66
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Inputs:
#         Fanout                                  : 11
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 412005.00
#             @multicast 1 @scatter 11: 412005.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 1.66
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 11
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 11
#         Ingresses                               : 72600.00
#             @multicast 11 @scatter 1: 72600.00
#         Link transfers                          : 0
#         Spatial reductions                      : 726000
#         Average number of hops                  : 10.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
# Network 2
# ---------
# ifmap_spad <==> weights_spad
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 14520.00
#             @multicast 1 @scatter 1: 14520.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Inputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 798600.00
#             @multicast 1 @scatter 1: 798600.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 72600.00
#             @multicast 1 @scatter 1: 72600.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
# Network 3
# ---------
# psum_spad <==> mac
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 798600.00
#             @multicast 1 @scatter 1: 798600.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Inputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 798600.00
#             @multicast 1 @scatter 1: 798600.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 798600.00
#             @multicast 1 @scatter 1: 798600.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
# Network 4
# ---------
# shared_glb <==> DummyBuffer
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 12
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 1916640.00
#             @multicast 1 @scatter 12: 1916640.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 1.73
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Inputs:
#         Fanout                                  : 12
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 12
#         Ingresses                               : 412005.00
#             @multicast 12 @scatter 1: 412005.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 11.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 12
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 871200.00
#             @multicast 1 @scatter 12: 871200.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 1.73
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
# Network 5
# ---------
# weights_spad <==> psum_spad
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 798600.00
#             @multicast 1 @scatter 1: 798600.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Inputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 798600.00
#             @multicast 1 @scatter 1: 798600.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 72600.00
#             @multicast 1 @scatter 1: 72600.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
#
# Operational Intensity Stats
# ---------------------------
#     Total elementwise ops                   : 105415200
# ...
# ---------
# DummyBuffer <==> ifmap_spad
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 12
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 884736.00
#             @multicast 1 @scatter 12: 884736.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 1.73
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Inputs:
#         Fanout                                  : 12
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 276480.00
#             @multicast 1 @scatter 12: 276480.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 1.73
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 12
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 12
#         Ingresses                               : 79872.00
#             @multicast 12 @scatter 1: 79872.00
#         Link transfers                          : 0
#         Spatial reductions                      : 878592
#         Average number of hops                  : 11.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
# Network 2
# ---------
# ifmap_spad <==> weights_spad
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 73728.00
#             @multicast 1 @scatter 1: 73728.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Inputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 958464.00
#             @multicast 1 @scatter 1: 958464.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 79872.00
#             @multicast 1 @scatter 1: 79872.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
# Network 3
# ---------
# psum_spad <==> mac
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 958464.00
#             @multicast 1 @scatter 1: 958464.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Inputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 958464.00
#             @multicast 1 @scatter 1: 958464.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 958464.00
#             @multicast 1 @scatter 1: 958464.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
# Network 4
# ---------
# shared_glb <==> DummyBuffer
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 13
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 13
#         Ingresses                               : 884736.00
#             @multicast 13 @scatter 1: 884736.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 12.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Inputs:
#         Fanout                                  : 13
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 3594240.00
#             @multicast 1 @scatter 13: 3594240.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 1.80
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 13
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 1038336.00
#             @multicast 1 @scatter 13: 1038336.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 1.80
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
# Network 5
# ---------
# weights_spad <==> psum_spad
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Weights:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 958464.00
#             @multicast 1 @scatter 1: 958464.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Inputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 958464.00
#             @multicast 1 @scatter 1: 958464.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 79872.00
#             @multicast 1 @scatter 1: 79872.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
#
# Operational Intensity Stats
# ---------------------------
#     Total elementwise ops                   : 149520384
#     Total reduction ops                     : 149477120
#     Total ops                               : 298997504
#     Total memory accesses required          : 1014400
#     Optimal Op per Byte                     : 147.38
#
# === psum_spad ===
#     Total scalar accesses                   : 310981632
#     Op per Byte                             : 0.48
# === weights_spad ===
#     Total scalar accesses                   : 161021952
#     Op per Byte                             : 0.93
# === ifmap_spad ===
#     Total scalar accesses                   : 153114624
#     Op per Byte                             : 0.98
# === DummyBuffer ===
# === shared_glb ===
#     Total scalar accesses                   : 5757312
#     Op per Byte                             : 25.97
# === DRAM ===
#     Total scalar accesses                   : 1014400
#     Op per Byte                             : 147.38
#
#
# Summary Stats
# -------------
# GFLOPs (@1GHz): 311.95
# Utilization: 0.93
# Cycles: 958464
# Energy: 935.36 uJ
# EDP(J*cycle): 8.97e+02
# Area: 0.00 mm^2
#
# Computes = 149520384
# pJ/Compute
#     mac                          = 2.20
#     psum_spad                    = 0.52
#     weights_spad                 = 1.71
#     ifmap_spad                   = 0.24
#     DummyBuffer                  = 0.00
#     shared_glb                   = 0.72
#     DRAM                         = 0.87
#     DRAM <==> shared_glb         = 0.00
#     DummyBuffer <==> ifmap_spad  = 0.00
#     ifmap_spad <==> weights_spad = 0.00
#     psum_spad <==> mac           = 0.00
#     shared_glb <==> DummyBuffer  = 0.00
#     weights_spad <==> psum_spad  = 0.00
#     Total                        = 6.26

# %%
for i, (stats, loops) in enumerate(alexnet_eyeriss_layerwise_results):
    print(f"Layer: {i+1}")
    log = False
    for line in stats.split("\n"):
        if "Summary Stats" in line:
            log = True
        if log:
            print(line)
# Out:
# Layer: 1
# Summary Stats
# -------------
# GFLOPs (@1GHz): 263.64
# Utilization: 0.79
# Cycles: 798600
# Energy: 865.92 uJ
# EDP(J*cycle): 6.92e+02
# Area: 0.00 mm^2
#
# Computes = 105415200
# pJ/Compute
#     mac                          = 2.20
#     psum_spad                    = 0.52
#     weights_spad                 = 1.61
#     ifmap_spad                   = 0.25
#     DummyBuffer                  = 0.00
#     shared_glb                   = 0.46
#     DRAM                         = 3.18
#     DRAM <==> shared_glb         = 0.00
#     DummyBuffer <==> ifmap_spad  = 0.00
#     ifmap_spad <==> weights_spad = 0.00
#     psum_spad <==> mac           = 0.00
#     shared_glb <==> DummyBuffer  = 0.00
#     weights_spad <==> psum_spad  = 0.00
#     Total                        = 8.21
#
#
# Layer: 2
# Summary Stats
# -------------
# GFLOPs (@1GHz): 239.95
# Utilization: 0.71
# Cycles: 3732480
# Energy: 3021.09 uJ
# EDP(J*cycle): 1.13e+04
# Area: 0.00 mm^2
#
# Computes = 447897600
# pJ/Compute
#     mac                          = 2.20
#     psum_spad                    = 0.53
#     weights_spad                 = 1.64
#     ifmap_spad                   = 0.24
#     DummyBuffer                  = 0.00
#     shared_glb                   = 0.45
#     DRAM                         = 1.69
#     DRAM <==> shared_glb         = 0.00
#     DummyBuffer <==> ifmap_spad  = 0.00
#     ifmap_spad <==> weights_spad = 0.00
#     psum_spad <==> mac           = 0.00
#     shared_glb <==> DummyBuffer  = 0.00
#     weights_spad <==> psum_spad  = 0.00
#     Total                        = 6.75
#
#
# Layer: 3
# Summary Stats
# -------------
# GFLOPs (@1GHz): 311.93
# Utilization: 0.93
# Cycles: 958464
# Energy: 942.30 uJ
# EDP(J*cycle): 9.03e+02
# Area: 0.00 mm^2
#
# Computes = 149520384
# pJ/Compute
#     mac                          = 2.20
#     psum_spad                    = 0.52
#     weights_spad                 = 1.71
#     ifmap_spad                   = 0.24
#     DummyBuffer                  = 0.00
#     shared_glb                   = 0.72
#     DRAM                         = 0.91
#     DRAM <==> shared_glb         = 0.00
#     DummyBuffer <==> ifmap_spad  = 0.00
#     ifmap_spad <==> weights_spad = 0.00
#     psum_spad <==> mac           = 0.00
#     shared_glb <==> DummyBuffer  = 0.00
#     weights_spad <==> psum_spad  = 0.00
#     Total                        = 6.30
#
#
# Layer: 4
# Summary Stats
# -------------
# GFLOPs (@1GHz): 311.95
# Utilization: 0.93
# Cycles: 1437696
# Energy: 1422.07 uJ
# EDP(J*cycle): 2.04e+03
# Area: 0.00 mm^2
#
# Computes = 224280576
# pJ/Compute
#     mac                          = 2.20
#     psum_spad                    = 0.52
#     weights_spad                 = 1.71
#     ifmap_spad                   = 0.24
#     DummyBuffer                  = 0.00
#     shared_glb                   = 0.73
#     DRAM                         = 0.94
#     DRAM <==> shared_glb         = 0.00
#     DummyBuffer <==> ifmap_spad  = 0.00
#     ifmap_spad <==> weights_spad = 0.00
#     psum_spad <==> mac           = 0.00
#     shared_glb <==> DummyBuffer  = 0.00
#     weights_spad <==> psum_spad  = 0.00
#     Total                        = 6.34
#
#
# Layer: 5
# Summary Stats
# -------------
# GFLOPs (@1GHz): 311.95
# Utilization: 0.93
# Cycles: 958464
# Energy: 935.36 uJ
# EDP(J*cycle): 8.97e+02
# Area: 0.00 mm^2
#
# Computes = 149520384
# pJ/Compute
#     mac                          = 2.20
#     psum_spad                    = 0.52
#     weights_spad                 = 1.71
#     ifmap_spad                   = 0.24
#     DummyBuffer                  = 0.00
#     shared_glb                   = 0.72
#     DRAM                         = 0.87
#     DRAM <==> shared_glb         = 0.00
#     DummyBuffer <==> ifmap_spad  = 0.00
#     ifmap_spad <==> weights_spad = 0.00
#     psum_spad <==> mac           = 0.00
#     shared_glb <==> DummyBuffer  = 0.00
#     weights_spad <==> psum_spad  = 0.00
#     Total                        = 6.26

# %%
total_cycles = 0
for i, (stats, loops) in enumerate(alexnet_eyeriss_layerwise_results):
    for line in stats.split("\n"):
        if "Cycles: " in line:
            cycles = int(line[len("Cycles: "):])
            total_cycles += cycles
            print(f"Cycles in layer {i+1}: {cycles}")
            break
print(f"Eyeriss total cycles: {total_cycles}")
# Out:
# Cycles in layer 0: 798600
# Cycles in layer 1: 3732480
# Cycles in layer 2: 958464
# Cycles in layer 3: 1437696
# Cycles in layer 4: 958464
# Total cycles: 7885704

# %%
total_energy = 0
for i, (stats, loops) in enumerate(alexnet_eyeriss_layerwise_results):
    for line in stats.split("\n"):
        if "Energy: " in line:
            energy = float(line[len("Energy: "):].split(' uJ')[0])
            total_energy += energy
            print(f"Energy in layer {i+1}: {energy}")
            break
print(f"Total energy: {total_energy} uJ")
# Out:
# Energy in layer 1: 865.92
# Energy in layer 2: 3021.09
# Energy in layer 3: 942.3
# Energy in layer 4: 1422.07
# Energy in layer 5: 935.36
# Total energy: 7186.74 uJ
